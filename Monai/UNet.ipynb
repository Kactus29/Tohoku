# %% [markdown]
# # 1) Imports

# %% [markdown]
# #### PyTorch

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, OneCycleLR

# %%
print('PyTorch version', torch.__version__)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# PyTorch version 2.9.1+cu128
# Device: cuda

# %% [markdown]
# #### General

# %%
import os
import json
import math
import time
import random
from pathlib import Path
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from tqdm import tqdm

from sklearn.metrics import roc_auc_score

# %% [markdown]
# #### Monai

# %%
import monai
print(monai.__version__)
# Out:
# 1.5.1

# %%
from monai.networks.nets import UNet as MonaiUNet
from monai.losses import DiceCELoss
from monai.utils import set_determinism
from monai.transforms import (
    Compose,
    RandFlipd,
    RandRotate90d,
    RandZoomd,
    RandAffined,
    RandGaussianNoised,
    RandShiftIntensityd,
    RandScaleIntensityd,
    EnsureTyped,
)

# %% [markdown]
# # 2) Parameters

# %% [markdown]
# #### 2.1) Directories for the images

# %%
train_images_dir = "/home/usrs/hnoel/SPLIT_RAVIR/Train/Images"
train_masks_dir  = "/home/usrs/hnoel/SPLIT_RAVIR/Train/Masks"

val_images_dir   = "/home/usrs/hnoel/SPLIT_RAVIR/Val/Images"
val_masks_dir    = "/home/usrs/hnoel/SPLIT_RAVIR/Val/Masks"

test_images_dir  = "/home/usrs/hnoel/SPLIT_RAVIR/Test/Images"
test_masks_dir   = "/home/usrs/hnoel/SPLIT_RAVIR/Test/Masks"

# %%
IMG_HEIGHT = 768
IMG_WIDTH  = 768

BATCH_SIZE = 6
print('Batch size:', BATCH_SIZE)

EPOCHS = 200
print('Number of epochs:', EPOCHS)

LR = 1e-3
print('Initial learning rate:', LR)

"""
0 : background (black)
1 : arteries (white)
2 : veins (gray)
"""
NUM_CLASSES = 3

COLOR_TO_LABEL = {
    (0,   0,   0)  : 0,  # background
    (255, 255, 255): 1,  # artery
    (128, 128, 128): 2,  # vein
}

BACKGROUND_IDX  = 0
ARTERY_CLASS = 1
VEIN_CLASS   = 2

VESSEL_CLASSES  = [1, 2]  # artery + vein
# Out:
# Batch size: 6
# Number of epochs: 200
# Initial learning rate: 0.001

# %% [markdown]
# #### 2.2) Seed

# %%
SEED = 42

# Python
random.seed(SEED)

# NumPy
np.random.seed(SEED)

# PyTorch
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Monai
set_determinism(seed=SEED)

print(f"Seed fixed to {SEED}")
# Out:
# Seed fixed to 42

# %% [markdown]
# # 3) DataLoaders

# %% [markdown]
# #### 3.1) Data augmentation

# %%
train_transforms = Compose([
    # --- Géométriques (image + label) ---
    RandFlipd(keys=["image", "label"], prob=0.4, spatial_axis=0),
    RandFlipd(keys=["image", "label"], prob=0.4, spatial_axis=1),
    RandRotate90d(keys=["image", "label"], prob=0.3, max_k=3),

    RandZoomd(
        keys=["image", "label"],
        prob=0.3,
        min_zoom=0.9,
        max_zoom=1.1,
        mode=("bilinear", "nearest"),  # image / mask
        keep_size=True,
    ),

    RandAffined(
        keys=["image", "label"],
        prob=0.2,
        rotate_range=(0.15, 0.15),      # ~8.5 degrés
        shear_range=(0.05, 0.05),
        translate_range=(8, 8),
        scale_range=(0.05, 0.05),
        mode=("bilinear", "nearest"),   # bilinear pour image, nearest pour mask
        padding_mode="zeros",
    ),

    # --- Intensité (image seule) ---
    RandGaussianNoised(keys=["image"], prob=0.1, std=0.01),
    RandShiftIntensityd(keys=["image"], prob=0.1, offsets=0.1),
    RandScaleIntensityd(keys=["image"], prob=0.1, factors=0.1),

    # S'assure que tout est bien en tensors PyTorch
    EnsureTyped(keys=["image", "label"]),
])

# Pas d'augmentation sur la validation
val_transforms = None

# %% [markdown]
# #### 3.2) Create the class for the dataset images

# %%
class RAVIRDataset(Dataset):
    def __init__(self, img_dir, mask_dir, img_size=(IMG_HEIGHT, IMG_WIDTH), transforms=None):
        self.img_paths = sorted(list(Path(img_dir).glob("*.png")))
        self.mask_dir = Path(mask_dir)
        self.img_size = img_size
        self.transforms = transforms   # ← pipeline MONAI (ou None)

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_path = self.img_paths[idx]
        mask_path = self.mask_dir / img_path.name

        # --- Image ---
        img = Image.open(img_path).convert("RGB").resize(self.img_size, Image.BILINEAR)
        img = np.array(img, dtype=np.float32) / 255.0
        img = np.transpose(img, (2, 0, 1))           # (C,H,W)
        img_t = torch.from_numpy(img).float()

        # --- Mask ---
        m = Image.open(mask_path).convert("RGB").resize(self.img_size, Image.NEAREST)
        m = np.array(m, dtype=np.uint8)

        label = np.zeros((self.img_size[1], self.img_size[0]), dtype=np.uint8)
        for color, lab in COLOR_TO_LABEL.items():
            mask = np.all(m == np.array(color), axis=-1)
            label[mask] = lab

        label_t = torch.from_numpy(label).long()   # (H,W)
        label_t = label_t.unsqueeze(0)             # (1,H,W) pour MONAI

        # ========= Application des transforms MONAI (si fournies) =========
        if self.transforms is not None:
            sample = {"image": img_t, "label": label_t}
            sample = self.transforms(sample)
            img_t  = sample["image"]
            label_t = sample["label"]

        return img_t, label_t

# %%
train_ds = RAVIRDataset(
    train_images_dir,
    train_masks_dir,
    (IMG_WIDTH, IMG_HEIGHT),
    transforms=train_transforms,   # ← augmentation activée
)

val_ds = RAVIRDataset(
    val_images_dir,
    val_masks_dir,
    (IMG_WIDTH, IMG_HEIGHT),
    transforms=val_transforms,     # ← None → pas d’augmentation
)

test_ds = RAVIRDataset(
    test_images_dir,
    test_masks_dir,
    (IMG_WIDTH, IMG_HEIGHT)
)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %% [markdown]
# # 4) UNet Model

# %%
model = MonaiUNet(
    spatial_dims=2,                             # UNet in 2D
    in_channels=3,                              # images RGB => 3 channels
    out_channels=NUM_CLASSES,                   # 3 classes: background, artery, vein
    channels=(64, 128, 256, 512, 1024),         # number of feature channels at each level
    strides=(2, 2, 2, 2),                       # 4 steps of downsampling (implicite max-pool 2x2)
    kernel_size=3,                              # conv 3x3
    up_kernel_size=3,                           # up-conv 3x3
    num_res_units=0,                            # no residual units -> simple blocs conv+ReLU
    act="RELU",                                 # Use ReLU, defaults is PReLU 
    norm="instance",                                  # no normalization in the 2015 article
    dropout=0.0,                                # No dropout here
).to(device)

# %%
print(model.__class__.__name__, "initialized on", device)
# Out:
# UNet initialized on cuda

# %% [markdown]
# # 5) Optimizer

# %%
optimizer = optim.AdamW(
    model.parameters(),
    lr=LR,
    betas=(0.9, 0.999),
    eps=1e-8,
    weight_decay=1e-2
    )

# %% [markdown]
# # 6) Scheduler

# %%
scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=50,   # tous les 50 epochs
    gamma=0.5       # LR = LR * 0.5
)

# %% [markdown]
# # 7) Loss function

# %%
percentage = [0.872, 0.054, 0.073]
inverse_percentage = [round((1/p), 2) for p in percentage]
print("Inverse class frequencies:", inverse_percentage)

weights = torch.tensor(inverse_percentage).to(device)
# Out:
# Inverse class frequencies: [1.15, 18.52, 13.7]

# %%
loss_function = DiceCELoss(
    include_background=False,
    to_onehot_y=True,
    softmax=True,
    weight=weights,
    lambda_dice=1.0,
    lambda_ce=1.0
)

# %% [markdown]
# # 8) History and metrics

# %%
best_val_loss = float("inf")
best_val_dice = -float("inf")

model_name = "Monai_DiceCE_v5"
save_dir = Path("UNet") / model_name

save_dir.mkdir(parents=True, exist_ok=True)
last_epoch_save = 0

# %%
# ===========================================
#   DICTIONNAIRES STOCRAGE (MEAN ONLY)
# ===========================================

train_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        [],
    "lr":         [],
    "alpha":      []
}

val_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        []
}

# %%
def init_confmat_sums(num_classes=NUM_CLASSES):
    """
    Agrégats TP/FP/FN/TN sur l'ensemble du dataset.
    """
    sums = {
        "TP": np.zeros(num_classes, dtype=np.int64),
        "FP": np.zeros(num_classes, dtype=np.int64),
        "FN": np.zeros(num_classes, dtype=np.int64),
        "TN": np.zeros(num_classes, dtype=np.int64),
        "N":  0
    }
    return sums


def init_auc_buffers(include_classes=VESSEL_CLASSES):
    """
    Buffers pour calculer l'AUC par classe (artery / vein).
    """
    return {c: {"y_true": [], "y_score": []} for c in include_classes}

# %%
def update_confmat_sums(sums, preds, targets, num_classes=NUM_CLASSES):
    """
    Met à jour les compteurs TP/FP/FN/TN pour chaque classe.
    preds, targets: tensors (N,H,W)
    """
    with torch.no_grad():
        for c in range(num_classes):
            p = (preds == c)
            t = (targets == c)

            tp = (p & t).sum().item()
            fp = (p & ~t).sum().item()
            fn = (~p & t).sum().item()
            tn = (~p & ~t).sum().item()

            sums["TP"][c] += tp
            sums["FP"][c] += fp
            sums["FN"][c] += fn
            sums["TN"][c] += tn

        sums["N"] += targets.numel()

# %%
def update_auc_buffers(buffers, logits, targets):
    """
    Stocke y_true / y_score pour calculer l'AUC par classe ensuite.
    - logits: (N,C,H,W)
    - targets: (N,H,W)
    """
    with torch.no_grad():
        probs = F.softmax(logits, dim=1)  # (N,C,H,W)

        # flatten (N,H,W,C) -> (N*H*W, C)
        flat_probs = probs.permute(0, 2, 3, 1).reshape(-1, probs.shape[1])
        flat_t     = targets.reshape(-1)

        for c in buffers.keys():
            y_true  = (flat_t == c).cpu().numpy().astype(np.uint8)
            y_score = flat_probs[:, c].cpu().numpy()
            buffers[c]["y_true"].append(y_true)
            buffers[c]["y_score"].append(y_score)

# %%
def compute_scalar_metrics_from_confmat(sums, include_classes):
    """
    Calcule accuracy / precision / recall / specificity / dice / IoU
    en moyenne sur les classes listées (par ex. artery+vein).
    """
    TP, FP, FN, TN = sums["TP"], sums["FP"], sums["FN"], sums["TN"]
    eps = 1e-7

    acc_c  = (TP + TN) / np.maximum(TP + TN + FP + FN, eps)
    prec_c = TP / np.maximum(TP + FP, eps)
    rec_c  = TP / np.maximum(TP + FN, eps)
    spec_c = TN / np.maximum(TN + FP, eps)
    dice_c = (2 * TP) / np.maximum(2 * TP + FP + FN, eps)
    iou_c  = TP / np.maximum(TP + FP + FN, eps)

    idx = np.array(include_classes, dtype=int)
    return {
        "accuracy":    float(np.mean(acc_c[idx])),
        "precision":   float(np.mean(prec_c[idx])),
        "recall":      float(np.mean(rec_c[idx])),
        "specificity": float(np.mean(spec_c[idx])),
        "dice":        float(np.mean(dice_c[idx])),
        "iou":         float(np.mean(iou_c[idx])),
    }

# %%
def compute_mean_auc(buffers):
    """
    Calcule l'AUC moyenne sur les classes présentes dans 'buffers'.
    Ignore les cas où la classe n'apparaît jamais.
    """
    aucs = []
    for c, pack in buffers.items():
        if len(pack["y_true"]) == 0:
            continue
        y_true  = np.concatenate(pack["y_true"])
        y_score = np.concatenate(pack["y_score"])

        pos = (y_true == 1).sum()
        neg = (y_true == 0).sum()
        if pos == 0 or neg == 0:
            continue

        try:
            aucs.append(roc_auc_score(y_true, y_score))
        except Exception:
            pass

    if len(aucs) == 0:
        return float("nan")
    return float(np.mean(aucs))

# %% [markdown]
# # 9) Training

# %%
for epoch in range(EPOCHS):

    # =========================
    #        TRAIN
    # =========================
    model.train()

    running_loss = 0.0
    conf_sums = init_confmat_sums()
    auc_buf   = init_auc_buffers()

    for imgs, masks in train_loader:
        imgs  = imgs.to(device, non_blocking=True)
        masks = masks.to(device, non_blocking=True)

        optimizer.zero_grad()

        outputs = model(imgs)  # (N,C,H,W)
        loss    = loss_function(outputs, masks)  # Dice + CE (MONAI)

        loss.backward()
        optimizer.step()

        batch_size = imgs.size(0)
        running_loss += loss.item() * batch_size

        preds = outputs.argmax(dim=1)
        update_confmat_sums(conf_sums, preds, masks, NUM_CLASSES)
        update_auc_buffers(auc_buf, outputs, masks)

    train_loss   = running_loss / len(train_ds)
    train_metrics = compute_scalar_metrics_from_confmat(conf_sums, VESSEL_CLASSES)
    train_auc     = compute_mean_auc(auc_buf)

    current_lr = optimizer.param_groups[0]["lr"]

    train_history["loss"].append(train_loss)
    train_history["accuracy"].append(train_metrics["accuracy"])
    train_history["dice"].append(train_metrics["dice"])
    train_history["iou"].append(train_metrics["iou"])
    train_history["precision"].append(train_metrics["precision"])
    train_history["recall"].append(train_metrics["recall"])
    train_history["specificity"].append(train_metrics["specificity"])
    train_history["auc"].append(train_auc)
    train_history["lr"].append(current_lr)

    # =========================
    #       VALIDATION
    # =========================
    model.eval()

    val_running_loss = 0.0
    conf_sums_val = init_confmat_sums()
    auc_buf_val   = init_auc_buffers()

    with torch.no_grad():
        for imgs, masks in val_loader:
            imgs  = imgs.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)

            outputs = model(imgs)
            loss    = loss_function(outputs, masks)

            batch_size = imgs.size(0)
            val_running_loss += loss.item() * batch_size

            preds = outputs.argmax(dim=1)
            update_confmat_sums(conf_sums_val, preds, masks, NUM_CLASSES)
            update_auc_buffers(auc_buf_val, outputs, masks)

    val_loss    = val_running_loss / len(val_ds)
    val_metrics = compute_scalar_metrics_from_confmat(conf_sums_val, VESSEL_CLASSES)
    val_auc     = compute_mean_auc(auc_buf_val)

    val_history["loss"].append(val_loss)
    val_history["accuracy"].append(val_metrics["accuracy"])
    val_history["dice"].append(val_metrics["dice"])
    val_history["iou"].append(val_metrics["iou"])
    val_history["precision"].append(val_metrics["precision"])
    val_history["recall"].append(val_metrics["recall"])
    val_history["specificity"].append(val_metrics["specificity"])
    val_history["auc"].append(val_auc)

    # =========================
    #        LOGS
    # =========================
    print("-" * 40)
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"  Train Loss: {train_loss:.4f}")
    print(f"  Val   Loss: {val_loss:.4f}")
    print(f"  Train Dice: {train_metrics['dice']:.4f} | Val Dice: {val_metrics['dice']:.4f}")
    print(f"  Current LR: {current_lr:.6f}")

    # =========================
    #   SAVE BEST MODELS
    # =========================
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), str(save_dir / "loss_best_model_state_dict.pth"))
        torch.save(model,              str(save_dir / "loss_best_model_full.pth"))
        print("✅ New best model (loss) saved")

    if val_metrics["dice"] > best_val_dice:
        best_val_dice = val_metrics["dice"]
        torch.save(model.state_dict(), str(save_dir / "dice_best_model_state_dict.pth"))
        torch.save(model,              str(save_dir / "dice_best_model_full.pth"))
        print("✅ New best model (dice) saved")

    # =========================
    #   SCHEDULER STEP
    # =========================
    scheduler.step()

# =========================
#     SAVE LAST MODEL
# =========================
torch.save(model.state_dict(), str(save_dir / f"epoch{EPOCHS}_model_state_dict.pth"))
torch.save(model,              str(save_dir / f"epoch{EPOCHS}_model_full.pth"))
print("✅ Last model saved")
# Out:
# ----------------------------------------
# Epoch 1/200
#   Train Loss: 15.3490
#   Val   Loss: 14.5079
#   Train Dice: 0.1093 | Val Dice: 0.1195
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 2/200
#   Train Loss: 14.5238
#   Val   Loss: 13.8725
#   Train Dice: 0.1145 | Val Dice: 0.1260
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 3/200
#   Train Loss: 13.9437
#   Val   Loss: 13.2532
#   Train Dice: 0.1149 | Val Dice: 0.1394
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 4/200
#   Train Loss: 13.4767
#   Val   Loss: 12.7660
#   Train Dice: 0.1219 | Val Dice: 0.1506
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 5/200
#   Train Loss: 12.9568
#   Val   Loss: 12.2918
#   Train Dice: 0.1296 | Val Dice: 0.1574
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 6/200
#   Train Loss: 12.5549
#   Val   Loss: 11.8153
#   Train Dice: 0.1308 | Val Dice: 0.1644
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 7/200
#   Train Loss: 11.9680
#   Val   Loss: 11.5035
#   Train Dice: 0.1343 | Val Dice: 0.1649
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 8/200
#   Train Loss: 11.6223
#   Val   Loss: 11.1641
#   Train Dice: 0.1374 | Val Dice: 0.1669
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 9/200
#   Train Loss: 11.3296
#   Val   Loss: 11.0263
#   Train Dice: 0.1387 | Val Dice: 0.1673
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 10/200
#   Train Loss: 11.2330
#   Val   Loss: 10.6475
#   Train Dice: 0.1355 | Val Dice: 0.1695
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 11/200
#   Train Loss: 10.5814
#   Val   Loss: 10.3932
#   Train Dice: 0.1423 | Val Dice: 0.1719
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 12/200
#   Train Loss: 10.4474
#   Val   Loss: 10.2917
#   Train Dice: 0.1406 | Val Dice: 0.1718
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 13/200
#   Train Loss: 10.2745
#   Val   Loss: 10.2456
#   Train Dice: 0.1410 | Val Dice: 0.1697
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 14/200
#   Train Loss: 10.0200
#   Val   Loss: 10.0190
#   Train Dice: 0.1431 | Val Dice: 0.1723
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 15/200
#   Train Loss: 9.8990
#   Val   Loss: 9.8044
#   Train Dice: 0.1452 | Val Dice: 0.1743
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 16/200
#   Train Loss: 9.5062
#   Val   Loss: 9.7837
#   Train Dice: 0.1467 | Val Dice: 0.1756
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 17/200
#   Train Loss: 9.4487
#   Val   Loss: 9.7686
#   Train Dice: 0.1468 | Val Dice: 0.1755
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 18/200
#   Train Loss: 9.3505
#   Val   Loss: 9.4403
#   Train Dice: 0.1493 | Val Dice: 0.1796
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 19/200
#   Train Loss: 9.3642
#   Val   Loss: 9.3936
#   Train Dice: 0.1463 | Val Dice: 0.1788
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 20/200
#   Train Loss: 9.1549
#   Val   Loss: 9.2798
#   Train Dice: 0.1470 | Val Dice: 0.1801
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 21/200
#   Train Loss: 9.0700
#   Val   Loss: 9.1848
#   Train Dice: 0.1490 | Val Dice: 0.1816
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 22/200
#   Train Loss: 9.0392
#   Val   Loss: 9.3935
#   Train Dice: 0.1502 | Val Dice: 0.1807
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 23/200
#   Train Loss: 9.1237
#   Val   Loss: 9.2224
#   Train Dice: 0.1487 | Val Dice: 0.1824
#   Current LR: 0.001000
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 24/200
#   Train Loss: 8.5698
#   Val   Loss: 9.2159
#   Train Dice: 0.1568 | Val Dice: 0.1831
#   Current LR: 0.001000
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 25/200
#   Train Loss: 8.8061
#   Val   Loss: 9.1040
#   Train Dice: 0.1548 | Val Dice: 0.1813
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 26/200
#   Train Loss: 8.8150
#   Val   Loss: 9.3345
#   Train Dice: 0.1510 | Val Dice: 0.1807
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 27/200
#   Train Loss: 8.6440
#   Val   Loss: 9.1231
#   Train Dice: 0.1572 | Val Dice: 0.1814
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 28/200
#   Train Loss: 8.4948
#   Val   Loss: 8.8617
#   Train Dice: 0.1542 | Val Dice: 0.1883
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 29/200
#   Train Loss: 8.6242
#   Val   Loss: 8.8423
#   Train Dice: 0.1559 | Val Dice: 0.1864
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 30/200
#   Train Loss: 8.4181
#   Val   Loss: 8.8773
#   Train Dice: 0.1539 | Val Dice: 0.1867
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 31/200
#   Train Loss: 8.2253
#   Val   Loss: 8.7781
#   Train Dice: 0.1608 | Val Dice: 0.1884
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 32/200
#   Train Loss: 7.9514
#   Val   Loss: 8.7513
#   Train Dice: 0.1608 | Val Dice: 0.1886
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 33/200
#   Train Loss: 8.2265
#   Val   Loss: 8.6056
#   Train Dice: 0.1597 | Val Dice: 0.1914
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 34/200
#   Train Loss: 7.8995
#   Val   Loss: 8.6130
#   Train Dice: 0.1625 | Val Dice: 0.1934
#   Current LR: 0.001000
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 35/200
#   Train Loss: 7.9056
#   Val   Loss: 8.8504
#   Train Dice: 0.1610 | Val Dice: 0.1877
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 36/200
#   Train Loss: 7.7424
#   Val   Loss: 8.5797
#   Train Dice: 0.1622 | Val Dice: 0.1913
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 37/200
#   Train Loss: 7.4792
#   Val   Loss: 8.5076
#   Train Dice: 0.1652 | Val Dice: 0.1907
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 38/200
#   Train Loss: 7.6763
#   Val   Loss: 8.5930
#   Train Dice: 0.1642 | Val Dice: 0.1910
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 39/200
#   Train Loss: 7.2768
#   Val   Loss: 8.5857
#   Train Dice: 0.1662 | Val Dice: 0.1911
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 40/200
#   Train Loss: 7.4177
#   Val   Loss: 8.6033
#   Train Dice: 0.1644 | Val Dice: 0.1910
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 41/200
#   Train Loss: 7.4230
#   Val   Loss: 8.3327
#   Train Dice: 0.1637 | Val Dice: 0.1931
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 42/200
#   Train Loss: 7.1806
#   Val   Loss: 8.4397
#   Train Dice: 0.1700 | Val Dice: 0.1945
#   Current LR: 0.001000
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 43/200
#   Train Loss: 7.1120
#   Val   Loss: 8.4133
#   Train Dice: 0.1679 | Val Dice: 0.1964
#   Current LR: 0.001000
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 44/200
#   Train Loss: 7.1869
#   Val   Loss: 8.3215
#   Train Dice: 0.1662 | Val Dice: 0.1957
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 45/200
#   Train Loss: 6.8816
#   Val   Loss: 8.3101
#   Train Dice: 0.1689 | Val Dice: 0.1954
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 46/200
#   Train Loss: 6.8922
#   Val   Loss: 8.3426
#   Train Dice: 0.1712 | Val Dice: 0.1934
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 47/200
#   Train Loss: 6.7716
#   Val   Loss: 8.5086
#   Train Dice: 0.1719 | Val Dice: 0.1940
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 48/200
#   Train Loss: 6.6977
#   Val   Loss: 8.3263
#   Train Dice: 0.1721 | Val Dice: 0.1975
#   Current LR: 0.001000
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 49/200
#   Train Loss: 6.8719
#   Val   Loss: 8.3952
#   Train Dice: 0.1703 | Val Dice: 0.1936
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 50/200
#   Train Loss: 6.9681
#   Val   Loss: 8.3329
#   Train Dice: 0.1692 | Val Dice: 0.1939
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 51/200
#   Train Loss: 6.9028
#   Val   Loss: 8.1499
#   Train Dice: 0.1715 | Val Dice: 0.1976
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 52/200
#   Train Loss: 6.1529
#   Val   Loss: 7.9246
#   Train Dice: 0.1798 | Val Dice: 0.2006
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 53/200
#   Train Loss: 6.5482
#   Val   Loss: 8.0738
#   Train Dice: 0.1742 | Val Dice: 0.1996
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 54/200
#   Train Loss: 6.5640
#   Val   Loss: 8.0644
#   Train Dice: 0.1729 | Val Dice: 0.1980
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 55/200
#   Train Loss: 6.3357
#   Val   Loss: 7.9933
#   Train Dice: 0.1772 | Val Dice: 0.1993
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 56/200
#   Train Loss: 6.2424
#   Val   Loss: 8.0054
#   Train Dice: 0.1774 | Val Dice: 0.1992
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 57/200
#   Train Loss: 6.3878
#   Val   Loss: 7.9732
#   Train Dice: 0.1784 | Val Dice: 0.2018
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 58/200
#   Train Loss: 6.3584
#   Val   Loss: 7.9268
#   Train Dice: 0.1771 | Val Dice: 0.2027
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 59/200
#   Train Loss: 6.0233
#   Val   Loss: 7.8694
#   Train Dice: 0.1843 | Val Dice: 0.2024
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 60/200
#   Train Loss: 5.9222
#   Val   Loss: 7.9735
#   Train Dice: 0.1828 | Val Dice: 0.2013
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 61/200
#   Train Loss: 5.8169
#   Val   Loss: 7.9086
#   Train Dice: 0.1823 | Val Dice: 0.2014
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 62/200
#   Train Loss: 6.0672
#   Val   Loss: 7.9205
#   Train Dice: 0.1789 | Val Dice: 0.2020
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 63/200
#   Train Loss: 5.5945
#   Val   Loss: 7.9906
#   Train Dice: 0.1839 | Val Dice: 0.2010
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 64/200
#   Train Loss: 5.8712
#   Val   Loss: 7.8880
#   Train Dice: 0.1812 | Val Dice: 0.2026
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 65/200
#   Train Loss: 5.5123
#   Val   Loss: 7.9754
#   Train Dice: 0.1871 | Val Dice: 0.2016
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 66/200
#   Train Loss: 5.5452
#   Val   Loss: 7.9302
#   Train Dice: 0.1865 | Val Dice: 0.2020
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 67/200
#   Train Loss: 5.5943
#   Val   Loss: 8.0418
#   Train Dice: 0.1828 | Val Dice: 0.2010
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 68/200
#   Train Loss: 5.6824
#   Val   Loss: 7.8553
#   Train Dice: 0.1838 | Val Dice: 0.2009
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 69/200
#   Train Loss: 6.0297
#   Val   Loss: 7.9324
#   Train Dice: 0.1793 | Val Dice: 0.2030
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 70/200
#   Train Loss: 5.7403
#   Val   Loss: 7.8181
#   Train Dice: 0.1839 | Val Dice: 0.2032
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 71/200
#   Train Loss: 5.5461
#   Val   Loss: 7.8241
#   Train Dice: 0.1830 | Val Dice: 0.2041
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 72/200
#   Train Loss: 5.7370
#   Val   Loss: 7.7636
#   Train Dice: 0.1832 | Val Dice: 0.2039
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 73/200
#   Train Loss: 5.5510
#   Val   Loss: 7.9569
#   Train Dice: 0.1848 | Val Dice: 0.2011
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 74/200
#   Train Loss: 5.3329
#   Val   Loss: 7.9117
#   Train Dice: 0.1886 | Val Dice: 0.2026
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 75/200
#   Train Loss: 5.2248
#   Val   Loss: 7.9663
#   Train Dice: 0.1851 | Val Dice: 0.2016
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 76/200
#   Train Loss: 5.4461
#   Val   Loss: 7.8370
#   Train Dice: 0.1867 | Val Dice: 0.2045
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 77/200
#   Train Loss: 5.4422
#   Val   Loss: 8.0211
#   Train Dice: 0.1866 | Val Dice: 0.2007
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 78/200
#   Train Loss: 5.3604
#   Val   Loss: 7.7877
#   Train Dice: 0.1887 | Val Dice: 0.2051
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 79/200
#   Train Loss: 5.1242
#   Val   Loss: 7.9057
#   Train Dice: 0.1902 | Val Dice: 0.2030
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 80/200
#   Train Loss: 5.1879
#   Val   Loss: 7.9806
#   Train Dice: 0.1880 | Val Dice: 0.2046
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 81/200
#   Train Loss: 5.3197
#   Val   Loss: 7.9024
#   Train Dice: 0.1852 | Val Dice: 0.2031
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 82/200
#   Train Loss: 5.2602
#   Val   Loss: 7.8346
#   Train Dice: 0.1850 | Val Dice: 0.2034
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 83/200
#   Train Loss: 5.4908
#   Val   Loss: 7.9819
#   Train Dice: 0.1849 | Val Dice: 0.2016
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 84/200
#   Train Loss: 5.1692
#   Val   Loss: 8.0506
#   Train Dice: 0.1860 | Val Dice: 0.2004
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 85/200
#   Train Loss: 5.0257
#   Val   Loss: 7.9795
#   Train Dice: 0.1878 | Val Dice: 0.2041
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 86/200
#   Train Loss: 5.2202
#   Val   Loss: 8.0446
#   Train Dice: 0.1880 | Val Dice: 0.2015
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 87/200
#   Train Loss: 5.4196
#   Val   Loss: 7.8569
#   Train Dice: 0.1878 | Val Dice: 0.2023
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 88/200
#   Train Loss: 5.0764
#   Val   Loss: 7.9241
#   Train Dice: 0.1897 | Val Dice: 0.2041
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 89/200
#   Train Loss: 4.9044
#   Val   Loss: 7.7439
#   Train Dice: 0.1905 | Val Dice: 0.2067
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 90/200
#   Train Loss: 4.9870
#   Val   Loss: 8.1430
#   Train Dice: 0.1892 | Val Dice: 0.2030
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 91/200
#   Train Loss: 4.7229
#   Val   Loss: 7.9429
#   Train Dice: 0.1940 | Val Dice: 0.2045
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 92/200
#   Train Loss: 4.9426
#   Val   Loss: 7.8348
#   Train Dice: 0.1921 | Val Dice: 0.2043
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 93/200
#   Train Loss: 4.7181
#   Val   Loss: 7.8786
#   Train Dice: 0.1955 | Val Dice: 0.2036
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 94/200
#   Train Loss: 4.7099
#   Val   Loss: 8.0367
#   Train Dice: 0.1936 | Val Dice: 0.2039
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 95/200
#   Train Loss: 4.8535
#   Val   Loss: 7.8877
#   Train Dice: 0.1916 | Val Dice: 0.2038
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 96/200
#   Train Loss: 4.8780
#   Val   Loss: 7.8375
#   Train Dice: 0.1920 | Val Dice: 0.2056
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 97/200
#   Train Loss: 4.8337
#   Val   Loss: 7.7062
#   Train Dice: 0.1956 | Val Dice: 0.2069
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 98/200
#   Train Loss: 4.8588
#   Val   Loss: 7.8112
#   Train Dice: 0.1914 | Val Dice: 0.2044
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 99/200
#   Train Loss: 4.6430
#   Val   Loss: 8.0428
#   Train Dice: 0.1940 | Val Dice: 0.2025
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 100/200
#   Train Loss: 4.5620
#   Val   Loss: 7.8497
#   Train Dice: 0.1929 | Val Dice: 0.2040
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 101/200
#   Train Loss: 4.4874
#   Val   Loss: 7.7319
#   Train Dice: 0.1928 | Val Dice: 0.2059
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 102/200
#   Train Loss: 4.4402
#   Val   Loss: 7.7773
#   Train Dice: 0.1965 | Val Dice: 0.2063
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 103/200
#   Train Loss: 4.5873
#   Val   Loss: 7.7901
#   Train Dice: 0.1928 | Val Dice: 0.2061
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 104/200
#   Train Loss: 4.4220
#   Val   Loss: 7.7446
#   Train Dice: 0.1977 | Val Dice: 0.2064
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 105/200
#   Train Loss: 4.4547
#   Val   Loss: 7.8098
#   Train Dice: 0.1944 | Val Dice: 0.2054
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 106/200
#   Train Loss: 4.3023
#   Val   Loss: 7.9089
#   Train Dice: 0.1956 | Val Dice: 0.2040
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 107/200
#   Train Loss: 4.3592
#   Val   Loss: 7.9338
#   Train Dice: 0.1937 | Val Dice: 0.2037
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 108/200
#   Train Loss: 4.3352
#   Val   Loss: 7.8368
#   Train Dice: 0.1967 | Val Dice: 0.2051
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 109/200
#   Train Loss: 4.1767
#   Val   Loss: 7.8279
#   Train Dice: 0.1968 | Val Dice: 0.2052
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 110/200
#   Train Loss: 4.1538
#   Val   Loss: 7.7824
#   Train Dice: 0.1980 | Val Dice: 0.2055
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 111/200
#   Train Loss: 4.3540
#   Val   Loss: 7.6972
#   Train Dice: 0.1952 | Val Dice: 0.2064
#   Current LR: 0.000250
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 112/200
#   Train Loss: 4.2125
#   Val   Loss: 7.7178
#   Train Dice: 0.1954 | Val Dice: 0.2064
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 113/200
#   Train Loss: 4.2019
#   Val   Loss: 7.7837
#   Train Dice: 0.2001 | Val Dice: 0.2061
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 114/200
#   Train Loss: 4.0453
#   Val   Loss: 7.7849
#   Train Dice: 0.1994 | Val Dice: 0.2062
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 115/200
#   Train Loss: 4.0267
#   Val   Loss: 7.7891
#   Train Dice: 0.2004 | Val Dice: 0.2062
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 116/200
#   Train Loss: 4.1716
#   Val   Loss: 7.6885
#   Train Dice: 0.1991 | Val Dice: 0.2071
#   Current LR: 0.000250
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 117/200
#   Train Loss: 4.1053
#   Val   Loss: 7.6326
#   Train Dice: 0.1966 | Val Dice: 0.2078
#   Current LR: 0.000250
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 118/200
#   Train Loss: 3.9771
#   Val   Loss: 7.6829
#   Train Dice: 0.2030 | Val Dice: 0.2079
#   Current LR: 0.000250
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 119/200
#   Train Loss: 4.0002
#   Val   Loss: 7.7114
#   Train Dice: 0.1991 | Val Dice: 0.2071
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 120/200
#   Train Loss: 3.9513
#   Val   Loss: 7.8010
#   Train Dice: 0.2007 | Val Dice: 0.2059
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 121/200
#   Train Loss: 4.0213
#   Val   Loss: 7.8203
#   Train Dice: 0.2042 | Val Dice: 0.2060
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 122/200
#   Train Loss: 3.9053
#   Val   Loss: 7.8328
#   Train Dice: 0.2010 | Val Dice: 0.2070
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 123/200
#   Train Loss: 4.0529
#   Val   Loss: 7.7939
#   Train Dice: 0.1998 | Val Dice: 0.2067
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 124/200
#   Train Loss: 3.9181
#   Val   Loss: 7.8620
#   Train Dice: 0.2023 | Val Dice: 0.2053
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 125/200
#   Train Loss: 3.8972
#   Val   Loss: 7.8697
#   Train Dice: 0.1977 | Val Dice: 0.2056
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 126/200
#   Train Loss: 3.8519
#   Val   Loss: 7.8016
#   Train Dice: 0.2015 | Val Dice: 0.2064
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 127/200
#   Train Loss: 3.8860
#   Val   Loss: 7.8291
#   Train Dice: 0.2019 | Val Dice: 0.2055
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 128/200
#   Train Loss: 3.9120
#   Val   Loss: 7.7919
#   Train Dice: 0.2017 | Val Dice: 0.2061
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 129/200
#   Train Loss: 3.8488
#   Val   Loss: 7.8467
#   Train Dice: 0.1988 | Val Dice: 0.2056
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 130/200
#   Train Loss: 3.7861
#   Val   Loss: 7.8217
#   Train Dice: 0.2034 | Val Dice: 0.2065
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 131/200
#   Train Loss: 3.8467
#   Val   Loss: 7.8437
#   Train Dice: 0.1993 | Val Dice: 0.2064
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 132/200
#   Train Loss: 3.8445
#   Val   Loss: 7.9049
#   Train Dice: 0.2042 | Val Dice: 0.2051
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 133/200
#   Train Loss: 3.7454
#   Val   Loss: 7.8980
#   Train Dice: 0.2016 | Val Dice: 0.2044
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 134/200
#   Train Loss: 3.6157
#   Val   Loss: 7.8837
#   Train Dice: 0.2048 | Val Dice: 0.2051
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 135/200
#   Train Loss: 3.6953
#   Val   Loss: 7.8190
#   Train Dice: 0.2035 | Val Dice: 0.2064
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 136/200
#   Train Loss: 3.6203
#   Val   Loss: 7.7869
#   Train Dice: 0.2041 | Val Dice: 0.2073
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 137/200
#   Train Loss: 3.5886
#   Val   Loss: 7.8638
#   Train Dice: 0.2036 | Val Dice: 0.2064
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 138/200
#   Train Loss: 3.7363
#   Val   Loss: 7.8678
#   Train Dice: 0.1989 | Val Dice: 0.2065
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 139/200
#   Train Loss: 3.5553
#   Val   Loss: 7.9317
#   Train Dice: 0.2022 | Val Dice: 0.2053
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 140/200
#   Train Loss: 3.5011
#   Val   Loss: 7.9049
#   Train Dice: 0.2032 | Val Dice: 0.2059
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 141/200
#   Train Loss: 3.5017
#   Val   Loss: 7.8661
#   Train Dice: 0.2054 | Val Dice: 0.2069
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 142/200
#   Train Loss: 3.4180
#   Val   Loss: 7.8937
#   Train Dice: 0.2034 | Val Dice: 0.2065
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 143/200
#   Train Loss: 3.6542
#   Val   Loss: 7.9846
#   Train Dice: 0.2040 | Val Dice: 0.2051
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 144/200
#   Train Loss: 3.4848
#   Val   Loss: 7.8971
#   Train Dice: 0.2056 | Val Dice: 0.2059
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 145/200
#   Train Loss: 3.4647
#   Val   Loss: 7.8799
#   Train Dice: 0.2035 | Val Dice: 0.2068
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 146/200
#   Train Loss: 3.5510
#   Val   Loss: 7.9053
#   Train Dice: 0.2028 | Val Dice: 0.2057
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 147/200
#   Train Loss: 3.5172
#   Val   Loss: 7.9065
#   Train Dice: 0.2067 | Val Dice: 0.2055
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 148/200
#   Train Loss: 3.6935
#   Val   Loss: 7.8965
#   Train Dice: 0.2016 | Val Dice: 0.2060
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 149/200
#   Train Loss: 3.4692
#   Val   Loss: 7.9598
#   Train Dice: 0.2063 | Val Dice: 0.2051
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 150/200
#   Train Loss: 3.5997
#   Val   Loss: 7.9941
#   Train Dice: 0.2068 | Val Dice: 0.2058
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 151/200
#   Train Loss: 3.5425
#   Val   Loss: 7.9381
#   Train Dice: 0.2040 | Val Dice: 0.2060
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 152/200
#   Train Loss: 3.3741
#   Val   Loss: 7.9354
#   Train Dice: 0.2067 | Val Dice: 0.2056
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 153/200
#   Train Loss: 3.3934
#   Val   Loss: 7.9356
#   Train Dice: 0.2048 | Val Dice: 0.2050
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 154/200
#   Train Loss: 3.2788
#   Val   Loss: 7.9286
#   Train Dice: 0.2089 | Val Dice: 0.2050
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 155/200
#   Train Loss: 3.3493
#   Val   Loss: 7.9536
#   Train Dice: 0.2062 | Val Dice: 0.2057
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 156/200
#   Train Loss: 3.3285
#   Val   Loss: 7.9664
#   Train Dice: 0.2070 | Val Dice: 0.2058
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 157/200
#   Train Loss: 3.3641
#   Val   Loss: 7.9419
#   Train Dice: 0.2041 | Val Dice: 0.2059
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 158/200
#   Train Loss: 3.3099
#   Val   Loss: 7.9561
#   Train Dice: 0.2070 | Val Dice: 0.2052
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 159/200
#   Train Loss: 3.2469
#   Val   Loss: 7.9436
#   Train Dice: 0.2081 | Val Dice: 0.2057
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 160/200
#   Train Loss: 3.3193
#   Val   Loss: 7.8872
#   Train Dice: 0.2056 | Val Dice: 0.2064
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 161/200
#   Train Loss: 3.3064
#   Val   Loss: 7.8768
#   Train Dice: 0.2078 | Val Dice: 0.2062
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 162/200
#   Train Loss: 3.3256
#   Val   Loss: 7.9237
#   Train Dice: 0.2051 | Val Dice: 0.2058
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 163/200
#   Train Loss: 3.1981
#   Val   Loss: 7.9666
#   Train Dice: 0.2064 | Val Dice: 0.2053
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 164/200
#   Train Loss: 3.1927
#   Val   Loss: 7.9382
#   Train Dice: 0.2057 | Val Dice: 0.2061
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 165/200
#   Train Loss: 3.1902
#   Val   Loss: 7.9273
#   Train Dice: 0.2096 | Val Dice: 0.2064
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 166/200
#   Train Loss: 3.2340
#   Val   Loss: 7.8958
#   Train Dice: 0.2042 | Val Dice: 0.2068
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 167/200
#   Train Loss: 3.1961
#   Val   Loss: 7.9187
#   Train Dice: 0.2064 | Val Dice: 0.2066
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 168/200
#   Train Loss: 3.3498
#   Val   Loss: 7.9046
#   Train Dice: 0.2054 | Val Dice: 0.2067
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 169/200
#   Train Loss: 3.2789
#   Val   Loss: 7.9355
#   Train Dice: 0.2052 | Val Dice: 0.2060
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 170/200
#   Train Loss: 3.1751
#   Val   Loss: 7.9662
#   Train Dice: 0.2111 | Val Dice: 0.2058
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 171/200
#   Train Loss: 3.1895
#   Val   Loss: 7.9731
#   Train Dice: 0.2053 | Val Dice: 0.2057
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 172/200
#   Train Loss: 3.2193
#   Val   Loss: 7.9594
#   Train Dice: 0.2072 | Val Dice: 0.2057
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 173/200
#   Train Loss: 3.2315
#   Val   Loss: 7.9235
#   Train Dice: 0.2056 | Val Dice: 0.2064
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 174/200
#   Train Loss: 3.2344
#   Val   Loss: 7.9825
#   Train Dice: 0.2050 | Val Dice: 0.2055
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 175/200
#   Train Loss: 3.1649
#   Val   Loss: 8.0224
#   Train Dice: 0.2062 | Val Dice: 0.2048
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 176/200
#   Train Loss: 3.1048
#   Val   Loss: 7.9180
#   Train Dice: 0.2120 | Val Dice: 0.2062
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 177/200
#   Train Loss: 3.0717
#   Val   Loss: 7.9470
#   Train Dice: 0.2070 | Val Dice: 0.2062
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 178/200
#   Train Loss: 3.0667
#   Val   Loss: 7.9822
#   Train Dice: 0.2116 | Val Dice: 0.2059
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 179/200
#   Train Loss: 3.0545
#   Val   Loss: 8.0042
#   Train Dice: 0.2065 | Val Dice: 0.2053
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 180/200
#   Train Loss: 3.1625
#   Val   Loss: 7.9857
#   Train Dice: 0.2075 | Val Dice: 0.2049
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 181/200
#   Train Loss: 3.1782
#   Val   Loss: 7.9372
#   Train Dice: 0.2065 | Val Dice: 0.2065
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 182/200
#   Train Loss: 3.1550
#   Val   Loss: 7.9676
#   Train Dice: 0.2056 | Val Dice: 0.2062
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 183/200
#   Train Loss: 3.1169
#   Val   Loss: 8.0455
#   Train Dice: 0.2062 | Val Dice: 0.2044
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 184/200
#   Train Loss: 3.0152
#   Val   Loss: 8.0443
#   Train Dice: 0.2113 | Val Dice: 0.2047
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 185/200
#   Train Loss: 3.1263
#   Val   Loss: 7.9985
#   Train Dice: 0.2064 | Val Dice: 0.2054
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 186/200
#   Train Loss: 3.0407
#   Val   Loss: 7.9525
#   Train Dice: 0.2085 | Val Dice: 0.2058
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 187/200
#   Train Loss: 2.9841
#   Val   Loss: 7.9577
#   Train Dice: 0.2094 | Val Dice: 0.2060
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 188/200
#   Train Loss: 3.0731
#   Val   Loss: 8.0054
#   Train Dice: 0.2094 | Val Dice: 0.2056
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 189/200
#   Train Loss: 3.0002
#   Val   Loss: 8.0065
#   Train Dice: 0.2072 | Val Dice: 0.2054
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 190/200
#   Train Loss: 2.9446
#   Val   Loss: 7.9891
#   Train Dice: 0.2084 | Val Dice: 0.2056
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 191/200
#   Train Loss: 3.0680
#   Val   Loss: 8.0403
#   Train Dice: 0.2083 | Val Dice: 0.2049
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 192/200
#   Train Loss: 3.0005
#   Val   Loss: 8.0319
#   Train Dice: 0.2097 | Val Dice: 0.2050
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 193/200
#   Train Loss: 3.0032
#   Val   Loss: 8.0137
#   Train Dice: 0.2079 | Val Dice: 0.2051
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 194/200
#   Train Loss: 3.0438
#   Val   Loss: 8.0123
#   Train Dice: 0.2085 | Val Dice: 0.2055
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 195/200
#   Train Loss: 2.9859
#   Val   Loss: 7.9965
#   Train Dice: 0.2076 | Val Dice: 0.2057
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 196/200
#   Train Loss: 2.9516
#   Val   Loss: 7.9746
#   Train Dice: 0.2089 | Val Dice: 0.2063
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 197/200
#   Train Loss: 3.0030
#   Val   Loss: 8.0047
#   Train Dice: 0.2095 | Val Dice: 0.2056
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 198/200
#   Train Loss: 2.9144
#   Val   Loss: 8.0782
#   Train Dice: 0.2101 | Val Dice: 0.2043
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 199/200
#   Train Loss: 2.9957
#   Val   Loss: 8.0830
#   Train Dice: 0.2078 | Val Dice: 0.2046
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 200/200
#   Train Loss: 2.9981
#   Val   Loss: 8.0274
#   Train Dice: 0.2100 | Val Dice: 0.2059
#   Current LR: 0.000125
# ✅ Last model saved

# %%
with open(save_dir / "UNet_train_history.json", "w") as f:
    json.dump(train_history, f, indent=4)

with open(save_dir / "UNet_val_history.json", "w") as f:
    json.dump(val_history, f, indent=4)

print("Historiques sauvegardés en JSON")
# Out:
# Historiques sauvegardés en JSON

# %% [markdown]
# # 10) Loading of the model

# %%
model.load_state_dict(torch.load(save_dir / "dice_best_model_state_dict.pth", map_location=device, weights_only=True))
model.eval()
# Out:
# UNet(
#   (model): Sequential(
#     (0): Convolution(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (adn): ADN(
#         (N): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#         (D): Dropout(p=0.0, inplace=False)
#         (A): ReLU()
#       )
#     )
#     (1): SkipConnection(
#       (submodule): Sequential(
#         (0): Convolution(
#           (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (adn): ADN(
#             (N): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (D): Dropout(p=0.0, inplace=False)
#             (A): ReLU()
#           )
#         )
#         (1): SkipConnection(
#           (submodule): Sequential(
#             (0): Convolution(
#               (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#               (adn): ADN(
#                 (N): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#                 (D): Dropout(p=0.0, inplace=False)
#                 (A): ReLU()
#               )
#             )
#             (1): SkipConnection(
#               (submodule): Sequential(
#                 (0): Convolution(
#                   (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#                   (adn): ADN(
#                     (N): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#                     (D): Dropout(p=0.0, inplace=False)
#                     (A): ReLU()
#                   )
#                 )
#                 (1): SkipConnection(
#                   (submodule): Convolution(
#                     (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#                     (adn): ADN(
#                       (N): InstanceNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#                       (D): Dropout(p=0.0, inplace=False)
#                       (A): ReLU()
#                     )
#                   )
#                 )
#                 (2): Convolution(
#                   (conv): ConvTranspose2d(1536, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#                   (adn): ADN(
#                     (N): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#                     (D): Dropout(p=0.0, inplace=False)
#                     (A): ReLU()
#                   )
#                 )
#               )
#             )
#             (2): Convolution(
#               (conv): ConvTranspose2d(512, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#               (adn): ADN(
#                 (N): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#                 (D): Dropout(p=0.0, inplace=False)
#                 (A): ReLU()
#               )
#             )
#           )
#         )
#         (2): Convolution(
#           (conv): ConvTranspose2d(256, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#           (adn): ADN(
#             (N): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#             (D): Dropout(p=0.0, inplace=False)
#             (A): ReLU()
#           )
#         )
#       )
#     )
#     (2): Convolution(
#       (conv): ConvTranspose2d(128, 3, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#     )
#   )
# )

# %% [markdown]
# # 11) Validation tests

# %% [markdown]
# ### 11.1) Images

# %%
model.eval()
total_correct = 0
total_pixels = 0

# 📁 Dossier pour sauvegarder les prédictions
pred_dir = save_dir / "predictions"
pred_dir.mkdir(parents=True, exist_ok=True)

with torch.no_grad():
    img_index = 0  # compteur global des images

    for imgs, masks in test_loader:
        imgs = imgs.to(device)
        masks = masks.to(device)

        outputs = model(imgs)
        preds = torch.argmax(F.softmax(outputs, dim=1), dim=1)

        # Boucle sur chaque image du batch
        for i in range(len(imgs)):
            pred = preds[i]
            mask = masks[i]

            # ===== Calcul de l’accuracy de cette image =====
            correct_pixels = (pred == mask).sum().item()
            total_pixels_img = mask.numel()
            acc_img = correct_pixels / total_pixels_img

            print(f"🖼️ Image {img_index+1} — Accuracy : {acc_img:.4f}")

            # ===== Création de la figure =====
            fig, ax = plt.subplots(1, 3, figsize=(10, 4))
            ax[0].imshow(imgs[i].cpu().permute(1, 2, 0))
            ax[0].set_title("Original picture")
            ax[1].imshow(mask.cpu().squeeze(0), cmap="gray")
            ax[1].set_title("Real mask")
            ax[2].imshow(pred.cpu(), cmap="gray")
            ax[2].set_title("Predicted mask")
            for a in ax:
                a.axis("off")
            plt.tight_layout()

            # 📌 Sauvegarde dans Models/<model_name>/predictions/
            save_path = pred_dir / f"val_img_{img_index:03d}.png"
            plt.savefig(save_path, dpi=150, bbox_inches='tight')

            # ✅ Affichage immédiat dans notebook
            plt.show()

            # ===== Accumulateur global =====
            total_correct += correct_pixels
            total_pixels += total_pixels_img
            img_index += 1

# ===== Accuracy globale =====
val_acc = total_correct / total_pixels
print(f"\n✅ Accuracy moyenne sur le jeu de validation : {val_acc:.4f}")
# Out:
# 🖼️ Image 1 — Accuracy : 0.9382
# 🖼️ Image 2 — Accuracy : 0.9273
# 🖼️ Image 3 — Accuracy : 0.9273
# 🖼️ Image 4 — Accuracy : 0.8937
# 🖼️ Image 5 — Accuracy : 0.9002
# ✅ Accuracy moyenne sur le jeu de validation : 0.9173

# %% [markdown]
# ### 11.2) Curves

# %%
curves_dir = save_dir / "curves"
curves_dir.mkdir(parents=True, exist_ok=True)

# %%
def plot_metric(train_history, val_history, key, title=None, mark_best_on="val_loss", save_folder=curves_dir):
    """
    key: nom de la métrique dans les dicts (ex: "loss", "dice", "auc")

    mark_best_on:
        - "val_loss" → marquer l'epoch où val_loss est minimal
        - "val_<key>" → marquer la meilleure valeur validation pour cette métrique (max)
    """

    train = train_history.get(key, [])
    val   = val_history.get(key, [])

    if len(val) == 0:
        print(f"⚠️ Impossible de tracer '{key}' (aucune valeur de validation trouvée)")
        return

    epochs = range(1, len(val) + 1)

    plt.figure(figsize=(7, 5))
    plt.plot(epochs, train, label=f"Train {key}", linewidth=2)
    plt.plot(epochs, val,   label=f"Val {key}", linewidth=2)

    # ======== BEST POINT (scatter) =========
    if mark_best_on == "val_loss" and "loss" in val_history:
        # meilleur = minimum
        best_e = int(np.argmin(val_history["loss"])) + 1
        best_v = val[best_e - 1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")

    elif mark_best_on == f"val_{key}" and len(val) > 0:
        # meilleur = maximum
        best_e = int(np.nanargmax(val)) + 1
        best_v = val[best_e - 1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")

    plt.xlabel("Epoch")
    plt.ylabel(key)
    plt.title(title or f"{key} (train vs val)")
    plt.grid(True)
    plt.legend()

    save_path = save_folder / f"{key}.png"
    plt.savefig(save_path, dpi=200, bbox_inches="tight")
    print(f"💾 Courbe sauvegardée : {save_path}")

    plt.show()

# %%
# Loss totale, Dice, AUC : même type de visualisation que dans ton notebook

plot_metric(train_history, val_history, "loss",
            title="Loss (Dice + CE)", mark_best_on="val_loss")

plot_metric(train_history, val_history, "dice",
            title="Dice (artery+vein avg)", mark_best_on="val_dice")

plot_metric(train_history, val_history, "auc",
            title="AUC (artery+vein avg)", mark_best_on="val_auc")
# Out:
# 💾 Courbe sauvegardée : UNet/Monai_DiceCE_v5/curves/loss.png
# 💾 Courbe sauvegardée : UNet/Monai_DiceCE_v5/curves/dice.png
# 💾 Courbe sauvegardée : UNet/Monai_DiceCE_v5/curves/auc.png

# %%
# =========================
#   COURBE LEARNING RATE
# =========================

lr_values = train_history.get("lr", [])
epochs = np.arange(1, len(lr_values) + 1)

fig_lr, ax = plt.subplots(figsize=(8, 5))
ax.plot(epochs, lr_values, color="#ff7f0e", linewidth=2)
ax.set_title("Learning Rate Schedule")
ax.set_xlabel("Epoch", fontsize=11)
ax.set_ylabel("Learning rate", fontsize=11)
ax.grid(alpha=0.4)
ax.legend(["lr(t)"], loc="best")
plt.tight_layout()

lr_path = curves_dir / "lr_curve.png"
plt.savefig(lr_path, dpi=200, bbox_inches='tight')
print(f"✅ Courbe learning rate sauvegardée dans : {lr_path}")

plt.show()
# Out:
# ✅ Courbe learning rate sauvegardée dans : UNet/Monai_DiceCE_v5/curves/lr_curve.png

# %% [markdown]
# ### 11.3) Table of metrics

# %%
# =========================
#  UTILS: métriques par classe
# =========================
def compute_per_class_metrics_from_confmat(sums, c):
    TP, FP, FN, TN = sums["TP"][c], sums["FP"][c], sums["FN"][c], sums["TN"][c]
    eps = 1e-7

    acc  = (TP + TN) / max(TP + TN + FP + FN, eps)
    prec = TP / max(TP + FP, eps)
    rec  = TP / max(TP + FN, eps)
    spec = TN / max(TN + FP, eps)
    dice = (2 * TP) / max(2 * TP + FP + FN, eps)
    iou  = TP / max(TP + FP + FN, eps)

    return {
        "accuracy":   float(acc),
        "precision":  float(prec),
        "recall":     float(rec),      # Sensitivity
        "specificity":float(spec),
        "dice":       float(dice),
        "iou":        float(iou),
    }

def compute_auc_for_class(buffers, c):
    pack = buffers.get(c, None)
    if pack is None or len(pack["y_true"]) == 0:
        return float("nan")

    y_true  = np.concatenate(pack["y_true"])
    y_score = np.concatenate(pack["y_score"])

    pos = (y_true == 1).sum()
    neg = (y_true == 0).sum()
    if pos == 0 or neg == 0:
        return float("nan")

    try:
        return float(roc_auc_score(y_true, y_score))
    except:
        return float("nan")


# =========================
#   ÉVALUATION
# =========================
model.eval()
conf_sums_val = init_confmat_sums(num_classes=NUM_CLASSES)
auc_buf_val   = init_auc_buffers(include_classes=VESSEL_CLASSES)

with torch.no_grad():
    for imgs, masks in test_loader:
        imgs  = imgs.to(device)
        masks = masks.to(device)

        outputs = model(imgs)
        preds = outputs.argmax(dim=1)

        update_confmat_sums(conf_sums_val, preds, masks, NUM_CLASSES)
        update_auc_buffers(auc_buf_val, outputs, masks)


# =========================
#   MÉTRIQUES PAR CLASSE
# =========================
results = {}

for cls, name in zip(VESSEL_CLASSES, ["Artery", "Vein"]):
    m = compute_per_class_metrics_from_confmat(conf_sums_val, cls)
    m["auc"] = compute_auc_for_class(auc_buf_val, cls)
    results[name] = m


# =========================
#   MOYENNES ARTERY + VEIN
# =========================
avg_metrics = {metric: np.nanmean([results["Artery"][metric], results["Vein"][metric]])
               for metric in results["Artery"].keys()}

results["Average (A+V)"] = avg_metrics


# =========================
#   AFFICHAGE TABLEAU (4 décimales)
# =========================
df = pd.DataFrame(results).T
df = df.round(4)  # <= Arrondi propre à 4 décimales

print("\n=== Résultats de validation ===\n")
display(df.style.format("{:.4f}"))
# Out:
# === Résultats de validation ===
# <style type="text/css">
# </style>
# <table id="T_7a588">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a588_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_7a588_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_7a588_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_7a588_level0_col3" class="col_heading level0 col3" >specificity</th>
#       <th id="T_7a588_level0_col4" class="col_heading level0 col4" >dice</th>
#       <th id="T_7a588_level0_col5" class="col_heading level0 col5" >iou</th>
#       <th id="T_7a588_level0_col6" class="col_heading level0 col6" >auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a588_level0_row0" class="row_heading level0 row0" >Artery</th>
#       <td id="T_7a588_row0_col0" class="data row0 col0" >0.8901</td>
#       <td id="T_7a588_row0_col1" class="data row0 col1" >0.2552</td>
#       <td id="T_7a588_row0_col2" class="data row0 col2" >0.2292</td>
#       <td id="T_7a588_row0_col3" class="data row0 col3" >0.9447</td>
#       <td id="T_7a588_row0_col4" class="data row0 col4" >0.2415</td>
#       <td id="T_7a588_row0_col5" class="data row0 col5" >0.1373</td>
#       <td id="T_7a588_row0_col6" class="data row0 col6" >0.9045</td>
#     </tr>
#     <tr>
#       <th id="T_7a588_level0_row1" class="row_heading level0 row1" >Vein</th>
#       <td id="T_7a588_row1_col0" class="data row1 col0" >0.9138</td>
#       <td id="T_7a588_row1_col1" class="data row1 col1" >0.2077</td>
#       <td id="T_7a588_row1_col2" class="data row1 col2" >0.2033</td>
#       <td id="T_7a588_row1_col3" class="data row1 col3" >0.9550</td>
#       <td id="T_7a588_row1_col4" class="data row1 col4" >0.2055</td>
#       <td id="T_7a588_row1_col5" class="data row1 col5" >0.1145</td>
#       <td id="T_7a588_row1_col6" class="data row1 col6" >0.8977</td>
#     </tr>
#     <tr>
#       <th id="T_7a588_level0_row2" class="row_heading level0 row2" >Average (A+V)</th>
#       <td id="T_7a588_row2_col0" class="data row2 col0" >0.9019</td>
#       <td id="T_7a588_row2_col1" class="data row2 col1" >0.2314</td>
#       <td id="T_7a588_row2_col2" class="data row2 col2" >0.2163</td>
#       <td id="T_7a588_row2_col3" class="data row2 col3" >0.9499</td>
#       <td id="T_7a588_row2_col4" class="data row2 col4" >0.2235</td>
#       <td id="T_7a588_row2_col5" class="data row2 col5" >0.1259</td>
#       <td id="T_7a588_row2_col6" class="data row2 col6" >0.9011</td>
#     </tr>
#   </tbody>
# </table>

# %%
# =========================
#   PER-IMAGE METRIC HELPERS
# =========================
def dice_per_image(pred, target, cls):
    eps = 1e-7
    p = (pred == cls).float()
    t = (target == cls).float()
    inter = (p * t).sum()
    denom = p.sum() + t.sum()
    return float((2.0 * inter) / (denom + eps))

def iou_per_image(pred, target, cls):
    eps = 1e-7
    p = (pred == cls)
    t = (target == cls)
    inter = (p & t).sum().item()
    union = (p | t).sum().item()
    return float(inter / (union + eps))

def auc_per_image_from_logits(logits, target, cls):
    # logits: (C,H,W) for a single image
    probs = F.softmax(logits, dim=0)
    y_score = probs[cls].reshape(-1).cpu().numpy()
    y_true  = (target == cls).reshape(-1).cpu().numpy().astype(np.uint8)
    pos = (y_true == 1).sum()
    neg = (y_true == 0).sum()
    if pos == 0 or neg == 0:
        return float("nan")
    try:
        return float(roc_auc_score(y_true, y_score))
    except Exception:
        return float("nan")

# =========================
#   COLLECT PER-IMAGE METRICS
# =========================
model.eval()

artery_dice_list, vein_dice_list, avg_dice_list = [], [], []
artery_iou_list,  vein_iou_list,  avg_iou_list  = [], [], []
artery_auc_list,  vein_auc_list,  avg_auc_list  = [], [], []

with torch.no_grad():
    for imgs, masks in test_loader:
        imgs  = imgs.to(device)
        masks = masks.to(device)

        logits = model(imgs)          # (N,C,H,W)
        preds  = logits.argmax(dim=1) # (N,H,W)

        for i in range(imgs.size(0)):
            p   = preds[i]
            gt  = masks[i]
            log = logits[i]

            # Dice
            a_d = dice_per_image(p, gt, ARTERY_CLASS)
            v_d = dice_per_image(p, gt, VEIN_CLASS)
            artery_dice_list.append(a_d)
            vein_dice_list.append(v_d)
            avg_dice_list.append(np.nanmean([a_d, v_d]))

            # IoU
            a_i = iou_per_image(p, gt, ARTERY_CLASS)
            v_i = iou_per_image(p, gt, VEIN_CLASS)
            artery_iou_list.append(a_i)
            vein_iou_list.append(v_i)
            avg_iou_list.append(np.nanmean([a_i, v_i]))

            # AUC
            a_auc = auc_per_image_from_logits(log, gt, ARTERY_CLASS)
            v_auc = auc_per_image_from_logits(log, gt, VEIN_CLASS)
            artery_auc_list.append(a_auc)
            vein_auc_list.append(v_auc)
            avg_auc_list.append(np.nanmean([a_auc, v_auc]))

# =========================
#   BAR PLOTS (3 rows × 3 cols)
#   One bar per image; red dashed = mean
# =========================
def plot_bars_one_metric(ax, values, title):
    values = np.array(values, dtype=float)
    n = len(values)
    x = np.arange(1, n+1)

    ax.bar(x, values, color="#1f77b4", edgecolor="black", alpha=0.9)

    m = np.nanmean(values)
    ax.axhline(m, color="red", linestyle="--", linewidth=2, label=f"mean = {m:.3f}")

    ax.set_ylim(0, 1)            # metrics in [0,1]
    ax.set_xlim(0.5, n + 0.5)
    ax.set_xlabel("Validation image index")
    ax.set_ylabel("Score")
    ax.set_title(title)
    # lighten x ticks if many images
    if n > 30:
        ax.set_xticks(np.linspace(1, n, 10, dtype=int))
    ax.grid(axis="y", alpha=0.3)
    ax.legend(loc="upper right")

fig, axes = plt.subplots(3, 3, figsize=(20, 12), constrained_layout=True)

# Row 1: Dice
plot_bars_one_metric(axes[0,0], artery_dice_list, "Dice – Artery")
plot_bars_one_metric(axes[0,1], vein_dice_list,   "Dice – Vein")
plot_bars_one_metric(axes[0,2], avg_dice_list,    "Dice – Average (A+V)")

# Row 2: IoU
plot_bars_one_metric(axes[1,0], artery_iou_list, "IoU – Artery")
plot_bars_one_metric(axes[1,1], vein_iou_list,   "IoU – Vein")
plot_bars_one_metric(axes[1,2], avg_iou_list,    "IoU – Average (A+V)")

# Row 3: AUC
plot_bars_one_metric(axes[2,0], artery_auc_list, "AUC – Artery")
plot_bars_one_metric(axes[2,1], vein_auc_list,   "AUC – Vein")
plot_bars_one_metric(axes[2,2], avg_auc_list,    "AUC – Average (A+V)")

save_path = curves_dir / f"per_image_metrics_bars.png"
plt.savefig(save_path, dpi=200, bbox_inches='tight')
print(f"💾 Courbe sauvegardée : {save_path}")

plt.show()
# Out:
# 💾 Courbe sauvegardée : UNet/Monai_DiceCE_v4/curves/per_image_metrics_bars.png

# %% [markdown]
# #### 11.2) New shit

# %%
# =========================
# 11) Metric helper functions (artery / vein, no background)
# =========================

import numpy as np
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score

def confusion_binary(pred_bin: torch.Tensor, gt_bin: torch.Tensor):
    """
    pred_bin, gt_bin : tensors bool ou 0/1 de shape (H, W).
    Retourne TP, FP, FN, TN.
    """
    pred_bin = pred_bin.bool()
    gt_bin   = gt_bin.bool()

    TP = (pred_bin & gt_bin).sum().item()
    FP = (pred_bin & ~gt_bin).sum().item()
    FN = (~pred_bin & gt_bin).sum().item()
    TN = (~pred_bin & ~gt_bin).sum().item()
    return TP, FP, FN, TN


def metrics_from_confusion(TP, FP, FN, TN):
    """
    Calcule F1 (=Dice binaire), IoU, Accuracy, Sensitivity (SE), Specificity (SP)
    à partir d'une matrice de confusion binaire.
    """
    eps = 1e-8
    acc = (TP + TN) / (TP + TN + FP + FN + eps)
    se  = TP / (TP + FN + eps)               # Sensitivity / Recall
    sp  = TN / (TN + FP + eps)               # Specificity
    f1  = (2 * TP) / (2 * TP + FP + FN + eps)  # F1-score = Dice
    iou = TP / (TP + FP + FN + eps)

    return {
        "F1":  float(f1),
        "IoU": float(iou),
        "Acc": float(acc),
        "SE":  float(se),
        "SP":  float(sp),
    }


def metrics_for_class(pred_labels: torch.Tensor,
                      gt_labels: torch.Tensor,
                      cls: int):
    """
    pred_labels, gt_labels : (H, W) entiers dans {0,1,2}
    cls : ARTERY_CLASS ou VEIN_CLASS

    Retourne dict métriques (sans AUC).
    """
    pred_c = (pred_labels == cls)
    gt_c   = (gt_labels == cls)
    TP, FP, FN, TN = confusion_binary(pred_c, gt_c)
    return metrics_from_confusion(TP, FP, FN, TN)


def auc_from_logits_one_class(logits: torch.Tensor,
                              gt_labels: torch.Tensor,
                              cls: int):
    """
    logits : (C, H, W) pour une image
    gt_labels : (H, W) entiers
    cls : ARTERY_CLASS ou VEIN_CLASS

    AUC ROC binaire pour la classe 'cls'.
    """
    # Probabilités softmax pour la classe d'intérêt
    with torch.no_grad():
        probs = F.softmax(logits, dim=0)[cls]    # (H, W)
        y_score = probs.detach().cpu().flatten().numpy()
        y_true  = (gt_labels == cls).detach().cpu().flatten().numpy().astype(int)

    # Cas dégénérés : que des 0 ou que des 1
    if y_true.max() == y_true.min():
        return float("nan")

    try:
        return float(roc_auc_score(y_true, y_score))
    except Exception:
        return float("nan")

# %%
# =========================
# 11.1) Test set: metrics + images + barplots
# =========================

model.eval()

# 📁 Dossier pour sauvegarder les triptyques (original / GT / pred)
pred_dir = save_dir / "predictions_test"
pred_dir.mkdir(parents=True, exist_ok=True)

# Stockage des métriques par image et par classe
metric_names = ["F1", "IoU", "Acc", "SE", "SP", "AUC"]

artery_scores = {m: [] for m in metric_names}
vein_scores   = {m: [] for m in metric_names}

# Pour les barplots "Average (A+V)" sur F1 / IoU / AUC
avg_F1_list  = []
avg_IoU_list = []
avg_AUC_list = []

img_index = 0

with torch.no_grad():
    for imgs, masks in test_loader:
        imgs   = imgs.to(device)          # (B, 3, H, W)
        masks  = masks.to(device)         # (B, 1, H, W)
        logits = model(imgs)              # (B, C, H, W)
        preds  = logits.argmax(dim=1)     # (B, H, W)
        targets = masks.squeeze(1)        # (B, H, W)

        for i in range(imgs.size(0)):
            img = imgs[i].cpu()
            pred = preds[i]
            gt   = targets[i]
            log  = logits[i]

            # ======= Metrics pour ARTERY & VEIN (sans background) =======
            art_metrics  = metrics_for_class(pred, gt, ARTERY_CLASS)
            vein_metrics = metrics_for_class(pred, gt, VEIN_CLASS)

            # AUC
            art_auc  = auc_from_logits_one_class(log, gt, ARTERY_CLASS)
            vein_auc = auc_from_logits_one_class(log, gt, VEIN_CLASS)
            art_metrics["AUC"]  = art_auc
            vein_metrics["AUC"] = vein_auc

            # Stockage pour chaque métrique
            for m in metric_names:
                artery_scores[m].append(art_metrics[m])
                vein_scores[m].append(vein_metrics[m])

            # Moyennes par image (A+V) pour F1 / IoU / AUC
            avg_F1_list.append(0.5 * (art_metrics["F1"]  + vein_metrics["F1"]))
            avg_IoU_list.append(0.5 * (art_metrics["IoU"] + vein_metrics["IoU"]))
            avg_AUC_list.append(0.5 * (art_metrics["AUC"] + vein_metrics["AUC"]))

            # ======= Log console par image (optionnel) =======
            print(
                f"[Image {img_index+1:03d}] "
                f"F1: artery={art_metrics['F1']:.3f}, vein={vein_metrics['F1']:.3f} | "
                f"IoU: artery={art_metrics['IoU']:.3f}, vein={vein_metrics['IoU']:.3f}"
            )

            # ======= Triptyque : original / GT / pred =======
            fig, ax = plt.subplots(1, 3, figsize=(10, 4))

            # Image originale
            ax[0].imshow(img.permute(1, 2, 0))
            ax[0].set_title("Original picture")

            # Masque ground truth
            ax[1].imshow(gt.cpu(), cmap="gray")
            ax[1].set_title("Ground truth mask")

            # Masque prédit
            ax[2].imshow(pred.cpu(), cmap="gray")
            ax[2].set_title("Predicted mask")

            for a in ax:
                a.axis("off")
            plt.tight_layout()

            # Sauvegarde
            save_path = pred_dir / f"test_img_{img_index:03d}.png"
            plt.savefig(save_path, dpi=150, bbox_inches="tight")
            plt.show()

            img_index += 1

# =========================
#  RÉSUMÉ GLOBAL : TABLEAU DES MÉTRIQUES
# =========================

results = {}

# Moyennes sur toutes les images pour chaque classe
artery_mean = {m: float(np.nanmean(artery_scores[m])) for m in metric_names}
vein_mean   = {m: float(np.nanmean(vein_scores[m]))   for m in metric_names}

results["Artery"] = artery_mean
results["Vein"]   = vein_mean

# Moyenne (A+V)
results["Average (A+V)"] = {
    m: float(np.nanmean([artery_mean[m], vein_mean[m]])) for m in metric_names
}

df_test = pd.DataFrame(results).T
df_test = df_test[metric_names]  # ordre des colonnes
df_test = df_test.round(4)

print("\n=== Test set metrics (artery / vein / average, no background) ===\n")
display(df_test)


# =========================
#  MATRICE DE BARPLOTS (comme avant)
#  Row 1: F1 (Dice), Row 2: IoU, Row 3: AUC
# =========================

def plot_bars_one_metric(ax, values, title):
    values = np.array(values, dtype=float)
    n = len(values)
    x = np.arange(1, n + 1)

    ax.bar(x, values, color="#1f77b4", edgecolor="black", alpha=0.9)

    m = np.nanmean(values)
    ax.axhline(m, color="red", linestyle="--", linewidth=2, label=f"mean = {m:.3f}")

    ax.set_ylim(0, 1)
    ax.set_xlim(0.5, n + 0.5)
    ax.set_xlabel("Test image index")
    ax.set_ylabel("Score")
    ax.set_title(title)
    if n > 30:
        ax.set_xticks(np.linspace(1, n, 10, dtype=int))
    ax.grid(axis="y", alpha=0.3)
    ax.legend(loc="upper right")


fig, axes = plt.subplots(3, 3, figsize=(20, 12), constrained_layout=True)

# Row 1 : F1 (= Dice binaire)
plot_bars_one_metric(axes[0, 0], artery_scores["F1"], "F1 (Dice) – Artery")
plot_bars_one_metric(axes[0, 1], vein_scores["F1"],   "F1 (Dice) – Vein")
plot_bars_one_metric(axes[0, 2], avg_F1_list,         "F1 (Dice) – Average (A+V)")

# Row 2 : IoU
plot_bars_one_metric(axes[1, 0], artery_scores["IoU"], "IoU – Artery")
plot_bars_one_metric(axes[1, 1], vein_scores["IoU"],   "IoU – Vein")
plot_bars_one_metric(axes[1, 2], avg_IoU_list,         "IoU – Average (A+V)")

# Row 3 : AUC
plot_bars_one_metric(axes[2, 0], artery_scores["AUC"], "AUC – Artery")
plot_bars_one_metric(axes[2, 1], vein_scores["AUC"],   "AUC – Vein")
plot_bars_one_metric(axes[2, 2], avg_AUC_list,         "AUC – Average (A+V)")

bars_path = save_dir / "per_image_metrics_test.png"
plt.savefig(bars_path, dpi=200, bbox_inches="tight")
print(f"\n💾 Matrice de barplots sauvegardée : {bars_path}")

plt.show()
# Out:
# [Image 001] F1: artery=0.710, vein=0.627 | IoU: artery=0.550, vein=0.456
# [Image 002] F1: artery=0.681, vein=0.612 | IoU: artery=0.516, vein=0.441
# [Image 003] F1: artery=0.620, vein=0.611 | IoU: artery=0.450, vein=0.440
# [Image 004] F1: artery=0.616, vein=0.478 | IoU: artery=0.445, vein=0.314
# [Image 005] F1: artery=0.563, vein=0.478 | IoU: artery=0.392, vein=0.314
# === Test set metrics (artery / vein / average, no background) ===
#                    F1     IoU     Acc      SE      SP     AUC
# Artery         0.6380  0.4705  0.9472  0.5998  0.9774  0.9114
# Vein           0.5612  0.3931  0.9525  0.5513  0.9764  0.9057
# Average (A+V)  0.5996  0.4318  0.9498  0.5755  0.9769  0.9086
# 💾 Matrice de barplots sauvegardée : UNet/Monai_DiceCE_v5/per_image_metrics_test.png
