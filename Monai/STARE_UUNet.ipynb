# %% [markdown]
# # 1) Imports

# %% [markdown]
# #### PyTorch

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, OneCycleLR

# %%
print('PyTorch version', torch.__version__)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# PyTorch version 2.9.1+cu128
# Device: cuda

# %% [markdown]
# #### General

# %%
import os
import json
import math
import time
import random
from pathlib import Path
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from tqdm import tqdm

from sklearn.metrics import roc_auc_score

# %% [markdown]
# #### Monai

# %%
import monai
print("MONAI version:", monai.__version__)
# Out:
# MONAI version: 1.5.1

# %%
from monai.networks.nets import BasicUNetPlusPlus
from monai.losses import DiceCELoss
from monai.utils import set_determinism
from monai.transforms import (
    Compose,
    ScaleIntensityd,
    RandFlipd,
    RandRotated,
    RandAffined,
    Resized,
    EnsureTyped,
)

# %% [markdown]
# # 2) Parameters

# %% [markdown]
# #### 2.1) Directories

# %%
drive_root = Path("/home/usrs/hnoel/STARE_704")

# TRAIN
train_images_dir = drive_root / "training" / "images"
train_manual_dir = drive_root / "training" / "masks"         

# TEST 
test_images_dir  = drive_root / "test" / "images"
test_manual_dir  = drive_root / "test" / "masks"

# %% [markdown]
# #### 2.2) Hyperparameters

# %%
# Image sizes
IMG_HEIGHT = 704
IMG_WIDTH  = 704

# Batch size
BATCH_SIZE = 1

# Number of epochs
EPOCHS = 200

# Learning rate
LR = 1e-3

# Classes
NUM_CLASSES = 2
BACKGROUND_IDX = 0
VESSEL_CLASS = 1

# %% [markdown]
# #### 2.3) Seed

# %%
SEED = 42

# Python
random.seed(SEED)

# NumPy
np.random.seed(SEED)

# PyTorch
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Monai
set_determinism(seed=SEED)

print(f"Seed fixed to {SEED}")
# Out:
# Seed fixed to 42

# %% [markdown]
# #### 2.4) Save directories

# %%
model_name = "UUNET_STARE_v2"

# Courbes, JSON, figures, etc.
data_dir = Path("/home/usrs/hnoel/Tohoku/Monai/UUNET") / model_name
data_dir.mkdir(parents=True, exist_ok=True)

# Poids de modèles
models_dir = Path("/home/usrs/hnoel/MODELS/UUNET") / model_name
models_dir.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # 3) DataLoaders

# %% [markdown]
# #### 3.1) Data augmentation

# %%
final_size = (IMG_HEIGHT, IMG_WIDTH)   # (704, 704) maintenant

train_transforms = Compose([
    ScaleIntensityd(keys=["image"]),

    # ---- AUGMENTATIONS ----
    RandFlipd(keys=["image", "label"], spatial_axis=0, prob=0.6),
    RandFlipd(keys=["image", "label"], spatial_axis=1, prob=0.6),

    RandRotated(
        keys=["image", "label"],
        range_x=np.pi/8,        # ±22.5°
        prob=0.3,
        mode=("bilinear", "nearest"),
    ),

    RandAffined(
        keys=["image", "label"],
        prob=0.3,
        rotate_range=(-np.pi/12, np.pi/12),
        translate_range=(20, 20),
        scale_range=(0.05, 0.05),
        mode=("bilinear", "nearest"),
    ),

    Resized(
        keys=["image", "label"],
        spatial_size=final_size,
        mode=("bilinear", "nearest"),
    ),

    EnsureTyped(keys=["image", "label"]),
])

val_transforms = Compose([
    ScaleIntensityd(keys=["image"]),
    Resized(
        keys=["image", "label"],
        spatial_size=final_size,
        mode=("bilinear", "nearest"),
    ),
    EnsureTyped(keys=["image", "label"]),
])

# %% [markdown]
# #### 3.2) Create the class fot the STARE datset images

# %%
class StareDataset(Dataset):
    def __init__(self, img_dir, manual_dir,
                 img_size=(IMG_HEIGHT, IMG_WIDTH),
                 transforms=None,
                 indices=None):

        self.img_paths = sorted(list(Path(img_dir).glob("*.png")))
        self.manual_dir = Path(manual_dir)
        self.H, self.W = img_size
        self.transforms = transforms
        self.indices = indices

    def __len__(self):
        if self.indices is None:
            return len(self.img_paths)
        return len(self.indices)

    def _get_paths(self, idx):
        if self.indices is not None:
            idx = self.indices[idx]

        img_path = self.img_paths[idx]

        # base = "im0082"
        base = img_path.stem

        # mask = "im0082_masks.png"
        manual_path = self.manual_dir / f"{base}_mask.png"

        if not manual_path.exists():
            raise FileNotFoundError(f"Mask not found: {manual_path}")

        return img_path, manual_path

    def __getitem__(self, idx):
        img_path, manual_path = self._get_paths(idx)

        H, W = self.H, self.W

        # === Image RGB ===
        img = Image.open(img_path).convert("RGB")
        img = img.resize((W, H), Image.BILINEAR)
        img_np = np.array(img).astype(np.float32) / 255.0
        img_t = torch.from_numpy(img_np).permute(2, 0, 1)

        # === Ground truth (binary) ===
        gt = Image.open(manual_path).convert("L")
        gt = gt.resize((W, H), Image.NEAREST)
        gt_np = np.array(gt)

        label_np = np.zeros_like(gt_np, dtype=np.int64)
        label_np[gt_np > 0] = VESSEL_CLASS
        label_t = torch.from_numpy(label_np).long().unsqueeze(0)

        sample = {"image": img_t, "label": label_t}

        if self.transforms is not None:
            sample = self.transforms(sample)

        return sample

# %%
# ========= Préparation des indices train / val pour STARE (10 images) =========
train_img_paths_all = sorted(list(Path(train_images_dir).glob("*.png")))
n_total = len(train_img_paths_all)      # normalement 10

indices_all = list(range(n_total))
train_indices = indices_all[:8]
val_indices   = indices_all[8:]         # 2 dernières

print("Train indices:", train_indices)
print("Val indices:  ", val_indices)
# Out:
# Train indices: [0, 1, 2, 3, 4, 5, 6, 7]
# Val indices:   [8, 9]

# %%
train_ds = StareDataset(
    train_images_dir,
    train_manual_dir,
    img_size=(IMG_HEIGHT, IMG_WIDTH),
    transforms=train_transforms,
    indices=train_indices,
)

val_ds = StareDataset(
    train_images_dir,
    train_manual_dir,
    img_size=(IMG_HEIGHT, IMG_WIDTH),
    transforms=val_transforms,
    indices=val_indices,
)

test_ds = StareDataset(
    test_images_dir,
    test_manual_dir,
    img_size=(IMG_HEIGHT, IMG_WIDTH),
    transforms=val_transforms,
    indices=None,
)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False)

print("Train / Val / Test sizes:", len(train_ds), len(val_ds), len(test_ds))
# Out:
# Train / Val / Test sizes: 8 2 10

# %% [markdown]
# # 4) UNet Model

# %%
# -------------------------
# Basic building blocks
# -------------------------
class ConvBNReLU(nn.Module):
    def __init__(self, in_ch: int, out_ch: int, k: int = 3, p: int = 1):
        super().__init__()
        self.conv = nn.Conv2d(in_ch, out_ch, kernel_size=k, padding=p, bias=False)
        self.bn   = nn.BatchNorm2d(out_ch)
        self.act  = nn.ReLU(inplace=True)

    def forward(self, x):
        return self.act(self.bn(self.conv(x)))


class DoubleConv(nn.Module):
    def __init__(self, in_ch: int, out_ch: int):
        super().__init__()
        self.block = nn.Sequential(
            ConvBNReLU(in_ch, out_ch),
            ConvBNReLU(out_ch, out_ch),
        )

    def forward(self, x):
        return self.block(x)


def center_crop_to(x, ref):
    if x.shape[-2:] == ref.shape[-2:]:
        return x
    dh = x.shape[-2] - ref.shape[-2]
    dw = x.shape[-1] - ref.shape[-1]
    return x[:, :, dh // 2 : dh // 2 + ref.shape[-2], dw // 2 : dw // 2 + ref.shape[-1]]


class UpBlock(nn.Module):
    def __init__(self, in_ch: int, skip_ch: int, out_ch: int):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_ch, out_ch, kernel_size=2, stride=2, bias=False)
        self.conv = DoubleConv(out_ch + skip_ch, out_ch)

    def forward(self, x, skip):
        x = self.up(x)
        skip = center_crop_to(skip, x)
        x = torch.cat([skip, x], dim=1)
        return self.conv(x)


# -------------------------
# Asymmetric mini-U-Net block (fixed)
# -------------------------
class AsymUNetBlock(nn.Module):
    """
    Descend from start_level to level 4, then ascend to target_level.
    Uses:
      - internal skips for levels >= start_level (created during this block's descent)
      - global skips for levels < start_level (created elsewhere, e.g., phase A)
    """
    def __init__(self, channels, start_level: int, target_level: int):
        super().__init__()
        assert 0 <= start_level <= 3
        assert 0 <= target_level <= 3
        self.channels = list(channels)
        self.start = start_level
        self.target = target_level

        self.pool = nn.MaxPool2d(2)

        # Down: map C_l -> C_{l+1} for l=start..3
        self.down_convs = nn.ModuleList([
            DoubleConv(self.channels[l], self.channels[l + 1])
            for l in range(start_level, 4)
        ])

        self.bottom = DoubleConv(self.channels[4], self.channels[4])

        # Up: 4 -> target, needing skips at levels 3..target
        self.up_blocks = nn.ModuleList([
            UpBlock(in_ch=self.channels[l], skip_ch=self.channels[l - 1], out_ch=self.channels[l - 1])
            for l in range(4, target_level, -1)
        ])

    def forward(self, x, global_skips: dict):
        # Build internal skips during descent
        internal_skips = {self.start: x}  # feature at start level

        cur = x
        for idx, l in enumerate(range(self.start, 4)):
            # go to level l+1
            cur = self.pool(cur)
            cur = self.down_convs[idx](cur)
            internal_skips[l + 1] = cur

        cur = self.bottom(cur)  # still level 4

        # Ascend to target level
        level = 4
        for up in self.up_blocks:
            next_level = level - 1

            # Prefer internal skips (available for >= start), otherwise global skips
            skip = internal_skips.get(next_level, None)
            if skip is None:
                skip = global_skips.get(next_level, None)

            if skip is None:
                raise KeyError(
                    f"Missing skip for level {next_level}. "
                    f"Internal: {sorted(internal_skips.keys())}, "
                    f"Global: {sorted(global_skips.keys())}"
                )

            cur = up(cur, skip)
            level = next_level

        return cur  # at level self.target


class DownToBottleneck(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.pool = nn.MaxPool2d(2)
        self.to4  = DoubleConv(channels[3], channels[4])
        self.bot  = DoubleConv(channels[4], channels[4])

    def forward(self, x3):
        x4 = self.pool(x3)
        x4 = self.to4(x4)
        x4 = self.bot(x4)
        return x4


# -------------------------
# UU-Net (your schedule)
# -------------------------
class UUNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=2, channels=(64, 128, 256, 512, 1024)):
        super().__init__()
        self.channels = list(channels)

        self.stem = DoubleConv(in_channels, self.channels[0])

        # Phase A
        self.a0 = AsymUNetBlock(self.channels, start_level=0, target_level=1)
        self.a1 = AsymUNetBlock(self.channels, start_level=1, target_level=2)
        self.a2 = AsymUNetBlock(self.channels, start_level=2, target_level=3)
        self.a3 = DownToBottleneck(self.channels)

        # Phase B
        self.up4_to_3 = UpBlock(in_ch=self.channels[4], skip_ch=self.channels[3], out_ch=self.channels[3])
        self.b3 = AsymUNetBlock(self.channels, start_level=3, target_level=2)
        self.b2 = AsymUNetBlock(self.channels, start_level=2, target_level=1)
        self.b1 = AsymUNetBlock(self.channels, start_level=1, target_level=0)

        self.out_conv = nn.Conv2d(self.channels[0], out_channels, kernel_size=1)

    def forward(self, x):
        global_skips = {}

        # level 0
        x0 = self.stem(x)
        global_skips[0] = x0

        # Phase A progressively builds reference features at levels 1..3
        x1 = self.a0(x0, global_skips)
        global_skips[1] = x1

        x2 = self.a1(x1, global_skips)
        global_skips[2] = x2

        x3 = self.a2(x2, global_skips)
        global_skips[3] = x3

        x4 = self.a3(x3)  # level 4

        # Phase B
        y3 = self.up4_to_3(x4, global_skips[3])  # 4->3

        y2 = self.b3(y3, global_skips)  # needs global skip at level 2
        y1 = self.b2(y2, global_skips)  # needs global skip at level 1
        y0 = self.b1(y1, global_skips)  # needs global skip at level 0

        return self.out_conv(y0)


# -------------------------
# Sanity check
# -------------------------
if __name__ == "__main__":
    model = UUNet(in_channels=3, out_channels=2).to(device)
    x = torch.randn(2, 3, 608, 608).to(device)
    y = model(x)
    print("output:", y.shape)  # (2, 2, 608, 608)
# Out:
# output: torch.Size([2, 2, 608, 608])

# %%
print(model.__class__.__name__, "initialized on", device)
# Out:
# UUNet initialized on cuda

# %% [markdown]
# # 5) Optimizer

# %%
optimizer = optim.AdamW(
    model.parameters(),
    lr=LR,
    betas=(0.9, 0.999),
    eps=1e-8,
    weight_decay=1e-2
    )

# %% [markdown]
# # 6) Scheduler

# %%
scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=50,   # tous les 50 epochs
    gamma=0.5       # LR = LR * 0.5
)

# %% [markdown]
# # 7) Loss function

# %%
# Pour DRIVE (binaire), on commence sans pondération explicite des classes.
# Si besoin, on pourra recalculer des poids plus tard à partir des fréquences de pixels.
weights = None

# %%
loss_function = DiceCELoss(
    include_background=False,   # on ne compte pas le background dans le Dice
    to_onehot_y=True,
    softmax=True,
    weight=weights,
    lambda_dice=1.0,
    lambda_ce=1.0,
)

# %% [markdown]
# # 8) History and metrics

# %%
best_val_loss = float("inf")
best_val_dice = -float("inf")

# %%
# ===========================================
#   DICTIONNAIRES STOCRAGE (MEAN ONLY)
# ===========================================

train_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        [],
    "lr":         [],
    "alpha":      []
}

val_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        []
}

# %%
def init_confmat_sums(num_classes=NUM_CLASSES):
    """
    Agrégats TP/FP/FN/TN sur l'ensemble du dataset.
    N = nombre de pixels pris en compte (dans le FOV).
    """
    sums = {
        "TP": np.zeros(num_classes, dtype=np.int64),
        "FP": np.zeros(num_classes, dtype=np.int64),
        "FN": np.zeros(num_classes, dtype=np.int64),
        "TN": np.zeros(num_classes, dtype=np.int64),
        "N":  0,
    }
    return sums

# %%
def init_auc_buffers(classes):
    """
    Buffers pour stocker y_true / y_score par classe (liste d'indices de classes).
    Exemple : classes = [VESSEL_CLASS].
    """
    buffers = {}
    for c in classes:
        buffers[c] = {"y_true": [], "y_score": []}
    return buffers

# %%
def update_confmat_sums(sums, preds, targets, num_classes=NUM_CLASSES, fov=None):
    """
    Mets à jour TP/FP/FN/TN en tenant compte éventuellement du FOV.
    - preds   : (B,H,W)
    - targets : (B,H,W) ou (B,1,H,W)
    - fov     : (B,H,W) ou (B,1,H,W), bool ou {0,1}; si None => tout le carré
    """
    with torch.no_grad():
        # Harmonisation des shapes
        if targets.dim() == 4:
            targets = targets.squeeze(1)          # (B,H,W)
        if fov is not None and fov.dim() == 4:
            fov = fov.squeeze(1)                  # (B,H,W)

        # Masque FOV binaire, si fourni
        if fov is not None:
            f = fov.bool()
        else:
            f = None

        for c in range(num_classes):
            p = (preds == c)
            t = (targets == c)

            if f is not None:
                p = p & f
                t = t & f

            tp = (p & t).sum().item()
            fp = (p & ~t).sum().item()
            fn = (~p & t).sum().item()
            tn = (~p & ~t).sum().item()

            sums["TP"][c] += tp
            sums["FP"][c] += fp
            sums["FN"][c] += fn
            sums["TN"][c] += tn

        if f is not None:
            sums["N"] += f.sum().item()
        else:
            sums["N"] += targets.numel()

# %%
def update_auc_buffers(buffers, logits, targets, fov=None):
    """
    Mets à jour les buffers pour AUC.
    - logits : (B,C,H,W)
    - targets: (B,H,W) ou (B,1,H,W)
    - fov    : (B,H,W) ou (B,1,H,W), bool ou {0,1}; si None => tout le carré
    """
    with torch.no_grad():
        if targets.dim() == 4:
            targets = targets.squeeze(1)          # (B,H,W)
        if fov is not None and fov.dim() == 4:
            fov = fov.squeeze(1)                  # (B,H,W)

        probs = F.softmax(logits, dim=1)          # (B,C,H,W)
        B, C, H, W = probs.shape

        # aplatir
        flat_probs = probs.permute(0, 2, 3, 1).reshape(-1, C)  # (B*H*W, C)
        flat_t     = targets.reshape(-1)                       # (B*H*W,)

        if fov is not None:
            flat_f = fov.reshape(-1).bool()
            flat_probs = flat_probs[flat_f]
            flat_t     = flat_t[flat_f]

        for c, pack in buffers.items():
            y_true  = (flat_t == c).cpu().numpy().astype(np.uint8)
            y_score = flat_probs[:, c].cpu().numpy()

            # cas dégénérés : pas de pos ou pas de neg => AUC non définie
            pos = (y_true == 1).sum()
            neg = (y_true == 0).sum()
            if pos == 0 or neg == 0:
                continue

            pack["y_true"].append(y_true)
            pack["y_score"].append(y_score)

# %%
def compute_scalar_metrics_from_confmat(sums, include_classes):
    """
    Calcule accuracy / precision / recall / specificity / dice / IoU
    en moyenne sur les classes listées (ex: [VESSEL_CLASS]).
    """
    TP, FP, FN, TN = sums["TP"], sums["FP"], sums["FN"], sums["TN"]
    eps = 1e-7

    acc_c  = (TP + TN) / np.maximum(TP + TN + FP + FN, eps)
    prec_c = TP / np.maximum(TP + FP, eps)
    rec_c  = TP / np.maximum(TP + FN, eps)
    spec_c = TN / np.maximum(TN + FP, eps)
    dice_c = (2 * TP) / np.maximum(2 * TP + FP + FN, eps)
    iou_c  = TP / np.maximum(TP + FP + FN, eps)

    idx = np.array(include_classes, dtype=int)
    return {
        "accuracy":    float(np.mean(acc_c[idx])),
        "precision":   float(np.mean(prec_c[idx])),
        "recall":      float(np.mean(rec_c[idx])),
        "specificity": float(np.mean(spec_c[idx])),
        "dice":        float(np.mean(dice_c[idx])),
        "iou":         float(np.mean(iou_c[idx])),
    }

# %%
def compute_mean_auc(buffers):
    """
    Calcule l'AUC moyen en moyennant sur les classes présentes dans `buffers`.
    """
    aucs = []
    for c, pack in buffers.items():
        if len(pack["y_true"]) == 0:
            continue
        y_true  = np.concatenate(pack["y_true"])
        y_score = np.concatenate(pack["y_score"])

        pos = (y_true == 1).sum()
        neg = (y_true == 0).sum()
        if pos == 0 or neg == 0:
            continue

        try:
            aucs.append(roc_auc_score(y_true, y_score))
        except Exception:
            pass

    if len(aucs) == 0:
        return float("nan")
    return float(np.mean(aucs))

# %% [markdown]
# # 9) Training

# %%
for epoch in range(EPOCHS):

    # =========================
    #        TRAIN
    # =========================
    model.train()

    running_loss = 0.0
    conf_sums = init_confmat_sums()
    auc_buf   = init_auc_buffers([VESSEL_CLASS])

    for batch in train_loader:

        imgs   = batch["image"].to(device, non_blocking=True)
        labels = batch["label"].to(device, non_blocking=True)  # (B,1,H,W)

        optimizer.zero_grad()

        outputs = model(imgs)         # (B,C,H,W)
        if isinstance(outputs, list):
            outputs = outputs[0]

        loss    = loss_function(outputs, labels)  # loss attend (B,1,H,W)

        loss.backward()
        optimizer.step()

        batch_size = imgs.size(0)
        running_loss += loss.item() * batch_size

        # ---- MÉTRIQUES DANS LE FOV UNIQUEMENT ----
        preds   = outputs.argmax(dim=1)          # (B,H,W)
        targets = labels.squeeze(1)              # (B,H,W)

        update_confmat_sums(conf_sums, preds, targets, NUM_CLASSES)
        update_auc_buffers(auc_buf, outputs, targets)

    train_loss   = running_loss / len(train_ds)
    train_metrics = compute_scalar_metrics_from_confmat(conf_sums, [VESSEL_CLASS])
    train_auc     = compute_mean_auc(auc_buf)

    current_lr = optimizer.param_groups[0]["lr"]

    train_history["loss"].append(train_loss)
    train_history["accuracy"].append(train_metrics["accuracy"])
    train_history["dice"].append(train_metrics["dice"])
    train_history["iou"].append(train_metrics["iou"])
    train_history["precision"].append(train_metrics["precision"])
    train_history["recall"].append(train_metrics["recall"])
    train_history["specificity"].append(train_metrics["specificity"])
    train_history["auc"].append(train_auc)
    train_history["lr"].append(current_lr)

    # =========================
    #       VALIDATION
    # =========================
    model.eval()

    val_running_loss = 0.0
    conf_sums_val = init_confmat_sums()
    auc_buf_val   = init_auc_buffers(classes=[VESSEL_CLASS])

    with torch.no_grad():
        for batch in val_loader:

            imgs   = batch["image"].to(device, non_blocking=True)
            labels = batch["label"].to(device, non_blocking=True)

            outputs = model(imgs)
            if isinstance(outputs, list):
                outputs = outputs[0]

            loss    = loss_function(outputs, labels)

            batch_size = imgs.size(0)
            val_running_loss += loss.item() * batch_size

            preds   = outputs.argmax(dim=1)
            targets = labels.squeeze(1)

            update_confmat_sums(conf_sums_val, preds, targets, NUM_CLASSES)
            update_auc_buffers(auc_buf_val, outputs, targets)

    val_loss    = val_running_loss / len(val_ds)
    val_metrics = compute_scalar_metrics_from_confmat(conf_sums_val, [VESSEL_CLASS])
    val_auc     = compute_mean_auc(auc_buf_val)

    val_history["loss"].append(val_loss)
    val_history["accuracy"].append(val_metrics["accuracy"])
    val_history["dice"].append(val_metrics["dice"])
    val_history["iou"].append(val_metrics["iou"])
    val_history["precision"].append(val_metrics["precision"])
    val_history["recall"].append(val_metrics["recall"])
    val_history["specificity"].append(val_metrics["specificity"])
    val_history["auc"].append(val_auc)

    # =========================
    #        LOGS
    # =========================
    print("-" * 40)
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"  Train Loss: {train_loss:.4f}")
    print(f"  Val   Loss: {val_loss:.4f}")
    print(f"  Train Dice: {train_metrics['dice']:.4f} | Val Dice: {val_metrics['dice']:.4f}")
    print(f"  Current LR: {current_lr:.6f}")

    # =========================
    #   SAVE BEST MODELS
    # =========================
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), str(models_dir / "loss_best_model_state_dict.pth"))
        torch.save(model,              str(models_dir / "loss_best_model_full.pth"))
        print("✅ New best model (loss) saved")

    if val_metrics["dice"] > best_val_dice:
        best_val_dice = val_metrics["dice"]
        torch.save(model.state_dict(), str(models_dir / "dice_best_model_state_dict.pth"))
        torch.save(model,              str(models_dir / "dice_best_model_full.pth"))
        print("✅ New best model (dice) saved")

    # =========================
    #   SCHEDULER STEP
    # =========================
    scheduler.step()

# =========================
#     SAVE LAST MODEL
# =========================
torch.save(model.state_dict(), str(models_dir / f"epoch{EPOCHS}_model_state_dict.pth"))
torch.save(model,              str(models_dir / f"epoch{EPOCHS}_model_full.pth"))
print("✅ Last model saved")
# Out:
# ----------------------------------------
# Epoch 1/200
#   Train Loss: 1.2781
#   Val   Loss: 1.4058
#   Train Dice: 0.3246 | Val Dice: 0.0000
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 2/200
#   Train Loss: 0.9603
#   Val   Loss: 1.2396
#   Train Dice: 0.5501 | Val Dice: 0.0000
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 3/200
#   Train Loss: 0.8668
#   Val   Loss: 1.2101
#   Train Dice: 0.5692 | Val Dice: 0.0000
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 4/200
#   Train Loss: 0.7708
#   Val   Loss: 1.1723
#   Train Dice: 0.6250 | Val Dice: 0.0000
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 5/200
#   Train Loss: 0.7289
#   Val   Loss: 1.1356
#   Train Dice: 0.6351 | Val Dice: 0.0000
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 6/200
#   Train Loss: 0.6469
#   Val   Loss: 1.0922
#   Train Dice: 0.6647 | Val Dice: 0.0938
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 7/200
#   Train Loss: 0.5932
#   Val   Loss: 1.1787
#   Train Dice: 0.6894 | Val Dice: 0.0972
#   Current LR: 0.001000
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 8/200
#   Train Loss: 0.5465
#   Val   Loss: 1.1543
#   Train Dice: 0.7088 | Val Dice: 0.0545
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 9/200
#   Train Loss: 0.5264
#   Val   Loss: 1.2827
#   Train Dice: 0.7183 | Val Dice: 0.0107
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 10/200
#   Train Loss: 0.4938
#   Val   Loss: 1.2661
#   Train Dice: 0.7360 | Val Dice: 0.0063
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 11/200
#   Train Loss: 0.4695
#   Val   Loss: 1.1432
#   Train Dice: 0.7439 | Val Dice: 0.0944
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 12/200
#   Train Loss: 0.4528
#   Val   Loss: 1.0869
#   Train Dice: 0.7514 | Val Dice: 0.1182
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 13/200
#   Train Loss: 0.4444
#   Val   Loss: 0.8891
#   Train Dice: 0.7531 | Val Dice: 0.3331
#   Current LR: 0.001000
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 14/200
#   Train Loss: 0.4208
#   Val   Loss: 1.0518
#   Train Dice: 0.7654 | Val Dice: 0.2406
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 15/200
#   Train Loss: 0.4107
#   Val   Loss: 1.1384
#   Train Dice: 0.7721 | Val Dice: 0.0942
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 16/200
#   Train Loss: 0.4038
#   Val   Loss: 1.1284
#   Train Dice: 0.7727 | Val Dice: 0.1363
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 17/200
#   Train Loss: 0.3845
#   Val   Loss: 1.2161
#   Train Dice: 0.7877 | Val Dice: 0.1581
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 18/200
#   Train Loss: 0.4318
#   Val   Loss: 1.0226
#   Train Dice: 0.7538 | Val Dice: 0.2888
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 19/200
#   Train Loss: 0.4065
#   Val   Loss: 1.3218
#   Train Dice: 0.7759 | Val Dice: 0.0424
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 20/200
#   Train Loss: 0.3849
#   Val   Loss: 0.9656
#   Train Dice: 0.7868 | Val Dice: 0.2333
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 21/200
#   Train Loss: 0.3738
#   Val   Loss: 1.0920
#   Train Dice: 0.7903 | Val Dice: 0.1640
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 22/200
#   Train Loss: 0.3721
#   Val   Loss: 1.0352
#   Train Dice: 0.7904 | Val Dice: 0.2511
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 23/200
#   Train Loss: 0.3728
#   Val   Loss: 1.1414
#   Train Dice: 0.7901 | Val Dice: 0.2021
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 24/200
#   Train Loss: 0.3930
#   Val   Loss: 1.4537
#   Train Dice: 0.7749 | Val Dice: 0.0151
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 25/200
#   Train Loss: 0.3903
#   Val   Loss: 1.3067
#   Train Dice: 0.7813 | Val Dice: 0.0533
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 26/200
#   Train Loss: 0.4030
#   Val   Loss: 1.1349
#   Train Dice: 0.7701 | Val Dice: 0.1471
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 27/200
#   Train Loss: 0.3835
#   Val   Loss: 1.0744
#   Train Dice: 0.7843 | Val Dice: 0.1602
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 28/200
#   Train Loss: 0.3648
#   Val   Loss: 1.2869
#   Train Dice: 0.7952 | Val Dice: 0.0406
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 29/200
#   Train Loss: 0.3683
#   Val   Loss: 1.1943
#   Train Dice: 0.7913 | Val Dice: 0.0318
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 30/200
#   Train Loss: 0.3820
#   Val   Loss: 1.3904
#   Train Dice: 0.7851 | Val Dice: 0.0124
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 31/200
#   Train Loss: 0.3813
#   Val   Loss: 1.0428
#   Train Dice: 0.7870 | Val Dice: 0.1784
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 32/200
#   Train Loss: 0.3568
#   Val   Loss: 1.1380
#   Train Dice: 0.8004 | Val Dice: 0.1175
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 33/200
#   Train Loss: 0.3399
#   Val   Loss: 1.2299
#   Train Dice: 0.8100 | Val Dice: 0.0902
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 34/200
#   Train Loss: 0.3349
#   Val   Loss: 1.0079
#   Train Dice: 0.8090 | Val Dice: 0.2642
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 35/200
#   Train Loss: 0.3264
#   Val   Loss: 1.2426
#   Train Dice: 0.8163 | Val Dice: 0.1090
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 36/200
#   Train Loss: 0.3208
#   Val   Loss: 0.9696
#   Train Dice: 0.8200 | Val Dice: 0.3155
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 37/200
#   Train Loss: 0.3214
#   Val   Loss: 1.1679
#   Train Dice: 0.8200 | Val Dice: 0.1237
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 38/200
#   Train Loss: 0.3476
#   Val   Loss: 1.2805
#   Train Dice: 0.8046 | Val Dice: 0.0596
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 39/200
#   Train Loss: 0.3321
#   Val   Loss: 1.3100
#   Train Dice: 0.8138 | Val Dice: 0.0530
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 40/200
#   Train Loss: 0.3129
#   Val   Loss: 1.4089
#   Train Dice: 0.8237 | Val Dice: 0.0019
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 41/200
#   Train Loss: 0.3118
#   Val   Loss: 1.1432
#   Train Dice: 0.8251 | Val Dice: 0.1328
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 42/200
#   Train Loss: 0.3100
#   Val   Loss: 1.3405
#   Train Dice: 0.8246 | Val Dice: 0.0675
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 43/200
#   Train Loss: 0.3218
#   Val   Loss: 1.1754
#   Train Dice: 0.8172 | Val Dice: 0.1480
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 44/200
#   Train Loss: 0.2983
#   Val   Loss: 1.1567
#   Train Dice: 0.8326 | Val Dice: 0.1810
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 45/200
#   Train Loss: 0.3064
#   Val   Loss: 1.1568
#   Train Dice: 0.8272 | Val Dice: 0.1733
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 46/200
#   Train Loss: 0.3072
#   Val   Loss: 1.2668
#   Train Dice: 0.8278 | Val Dice: 0.1171
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 47/200
#   Train Loss: 0.3091
#   Val   Loss: 1.1131
#   Train Dice: 0.8252 | Val Dice: 0.1929
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 48/200
#   Train Loss: 0.3290
#   Val   Loss: 1.4715
#   Train Dice: 0.8106 | Val Dice: 0.0094
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 49/200
#   Train Loss: 0.3129
#   Val   Loss: 1.2671
#   Train Dice: 0.8223 | Val Dice: 0.0683
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 50/200
#   Train Loss: 0.3101
#   Val   Loss: 1.1777
#   Train Dice: 0.8239 | Val Dice: 0.1732
#   Current LR: 0.001000
# ----------------------------------------
# Epoch 51/200
#   Train Loss: 0.3012
#   Val   Loss: 1.0649
#   Train Dice: 0.8309 | Val Dice: 0.2295
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 52/200
#   Train Loss: 0.2839
#   Val   Loss: 1.1938
#   Train Dice: 0.8397 | Val Dice: 0.1496
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 53/200
#   Train Loss: 0.2810
#   Val   Loss: 1.2865
#   Train Dice: 0.8393 | Val Dice: 0.0818
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 54/200
#   Train Loss: 0.2749
#   Val   Loss: 1.2426
#   Train Dice: 0.8445 | Val Dice: 0.1182
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 55/200
#   Train Loss: 0.2733
#   Val   Loss: 1.0572
#   Train Dice: 0.8446 | Val Dice: 0.2320
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 56/200
#   Train Loss: 0.2839
#   Val   Loss: 1.0261
#   Train Dice: 0.8389 | Val Dice: 0.2646
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 57/200
#   Train Loss: 0.2673
#   Val   Loss: 1.2287
#   Train Dice: 0.8481 | Val Dice: 0.1356
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 58/200
#   Train Loss: 0.2652
#   Val   Loss: 0.9756
#   Train Dice: 0.8488 | Val Dice: 0.2870
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 59/200
#   Train Loss: 0.2603
#   Val   Loss: 0.9381
#   Train Dice: 0.8522 | Val Dice: 0.2871
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 60/200
#   Train Loss: 0.2595
#   Val   Loss: 0.9245
#   Train Dice: 0.8526 | Val Dice: 0.3345
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 61/200
#   Train Loss: 0.2715
#   Val   Loss: 1.1919
#   Train Dice: 0.8447 | Val Dice: 0.1562
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 62/200
#   Train Loss: 0.2669
#   Val   Loss: 1.1745
#   Train Dice: 0.8482 | Val Dice: 0.1781
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 63/200
#   Train Loss: 0.2609
#   Val   Loss: 0.9477
#   Train Dice: 0.8527 | Val Dice: 0.3064
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 64/200
#   Train Loss: 0.2636
#   Val   Loss: 0.9766
#   Train Dice: 0.8499 | Val Dice: 0.3116
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 65/200
#   Train Loss: 0.2605
#   Val   Loss: 0.9079
#   Train Dice: 0.8520 | Val Dice: 0.3514
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 66/200
#   Train Loss: 0.2541
#   Val   Loss: 1.2933
#   Train Dice: 0.8554 | Val Dice: 0.1223
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 67/200
#   Train Loss: 0.2578
#   Val   Loss: 1.1729
#   Train Dice: 0.8543 | Val Dice: 0.1951
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 68/200
#   Train Loss: 0.2532
#   Val   Loss: 1.0258
#   Train Dice: 0.8558 | Val Dice: 0.2694
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 69/200
#   Train Loss: 0.2528
#   Val   Loss: 0.9816
#   Train Dice: 0.8555 | Val Dice: 0.3087
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 70/200
#   Train Loss: 0.2522
#   Val   Loss: 0.9283
#   Train Dice: 0.8561 | Val Dice: 0.3437
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 71/200
#   Train Loss: 0.2504
#   Val   Loss: 0.9080
#   Train Dice: 0.8571 | Val Dice: 0.3531
#   Current LR: 0.000500
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 72/200
#   Train Loss: 0.2490
#   Val   Loss: 0.8647
#   Train Dice: 0.8576 | Val Dice: 0.3886
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 73/200
#   Train Loss: 0.2496
#   Val   Loss: 0.9590
#   Train Dice: 0.8577 | Val Dice: 0.3210
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 74/200
#   Train Loss: 0.2418
#   Val   Loss: 1.0104
#   Train Dice: 0.8626 | Val Dice: 0.2807
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 75/200
#   Train Loss: 0.2403
#   Val   Loss: 0.9185
#   Train Dice: 0.8624 | Val Dice: 0.3532
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 76/200
#   Train Loss: 0.2470
#   Val   Loss: 0.9739
#   Train Dice: 0.8587 | Val Dice: 0.3137
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 77/200
#   Train Loss: 0.2415
#   Val   Loss: 0.9674
#   Train Dice: 0.8621 | Val Dice: 0.3179
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 78/200
#   Train Loss: 0.2332
#   Val   Loss: 0.8966
#   Train Dice: 0.8672 | Val Dice: 0.3781
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 79/200
#   Train Loss: 0.2387
#   Val   Loss: 1.0136
#   Train Dice: 0.8643 | Val Dice: 0.2933
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 80/200
#   Train Loss: 0.2392
#   Val   Loss: 1.0485
#   Train Dice: 0.8634 | Val Dice: 0.2563
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 81/200
#   Train Loss: 0.2299
#   Val   Loss: 0.7088
#   Train Dice: 0.8685 | Val Dice: 0.5037
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 82/200
#   Train Loss: 0.2425
#   Val   Loss: 0.8726
#   Train Dice: 0.8606 | Val Dice: 0.3923
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 83/200
#   Train Loss: 0.2293
#   Val   Loss: 0.8350
#   Train Dice: 0.8686 | Val Dice: 0.4149
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 84/200
#   Train Loss: 0.2393
#   Val   Loss: 0.7764
#   Train Dice: 0.8629 | Val Dice: 0.4635
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 85/200
#   Train Loss: 0.2308
#   Val   Loss: 0.6839
#   Train Dice: 0.8680 | Val Dice: 0.5333
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 86/200
#   Train Loss: 0.2443
#   Val   Loss: 0.9798
#   Train Dice: 0.8603 | Val Dice: 0.3283
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 87/200
#   Train Loss: 0.2376
#   Val   Loss: 0.9090
#   Train Dice: 0.8630 | Val Dice: 0.3759
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 88/200
#   Train Loss: 0.2317
#   Val   Loss: 1.0886
#   Train Dice: 0.8675 | Val Dice: 0.2544
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 89/200
#   Train Loss: 0.2370
#   Val   Loss: 1.0767
#   Train Dice: 0.8638 | Val Dice: 0.2813
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 90/200
#   Train Loss: 0.2329
#   Val   Loss: 0.6819
#   Train Dice: 0.8665 | Val Dice: 0.5316
#   Current LR: 0.000500
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 91/200
#   Train Loss: 0.2291
#   Val   Loss: 0.8247
#   Train Dice: 0.8686 | Val Dice: 0.4302
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 92/200
#   Train Loss: 0.2350
#   Val   Loss: 0.8484
#   Train Dice: 0.8653 | Val Dice: 0.4266
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 93/200
#   Train Loss: 0.2299
#   Val   Loss: 1.2132
#   Train Dice: 0.8681 | Val Dice: 0.1558
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 94/200
#   Train Loss: 0.2357
#   Val   Loss: 0.8750
#   Train Dice: 0.8649 | Val Dice: 0.3921
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 95/200
#   Train Loss: 0.2351
#   Val   Loss: 0.9979
#   Train Dice: 0.8655 | Val Dice: 0.2769
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 96/200
#   Train Loss: 0.2285
#   Val   Loss: 0.7434
#   Train Dice: 0.8688 | Val Dice: 0.4738
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 97/200
#   Train Loss: 0.2298
#   Val   Loss: 0.7685
#   Train Dice: 0.8676 | Val Dice: 0.4745
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 98/200
#   Train Loss: 0.2285
#   Val   Loss: 0.7390
#   Train Dice: 0.8690 | Val Dice: 0.4918
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 99/200
#   Train Loss: 0.2254
#   Val   Loss: 0.8042
#   Train Dice: 0.8707 | Val Dice: 0.4485
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 100/200
#   Train Loss: 0.2243
#   Val   Loss: 0.8431
#   Train Dice: 0.8705 | Val Dice: 0.4016
#   Current LR: 0.000500
# ----------------------------------------
# Epoch 101/200
#   Train Loss: 0.2154
#   Val   Loss: 0.6477
#   Train Dice: 0.8763 | Val Dice: 0.5582
#   Current LR: 0.000250
# ✅ New best model (loss) saved
# ✅ New best model (dice) saved
# ----------------------------------------
# Epoch 102/200
#   Train Loss: 0.2179
#   Val   Loss: 0.8409
#   Train Dice: 0.8746 | Val Dice: 0.4175
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 103/200
#   Train Loss: 0.2140
#   Val   Loss: 0.6425
#   Train Dice: 0.8764 | Val Dice: 0.5544
#   Current LR: 0.000250
# ✅ New best model (loss) saved
# ----------------------------------------
# Epoch 104/200
#   Train Loss: 0.2185
#   Val   Loss: 0.7090
#   Train Dice: 0.8742 | Val Dice: 0.5151
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 105/200
#   Train Loss: 0.2183
#   Val   Loss: 0.6955
#   Train Dice: 0.8742 | Val Dice: 0.5188
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 106/200
#   Train Loss: 0.2156
#   Val   Loss: 0.8801
#   Train Dice: 0.8755 | Val Dice: 0.4018
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 107/200
#   Train Loss: 0.2222
#   Val   Loss: 0.8537
#   Train Dice: 0.8722 | Val Dice: 0.3979
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 108/200
#   Train Loss: 0.2171
#   Val   Loss: 0.6683
#   Train Dice: 0.8752 | Val Dice: 0.5391
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 109/200
#   Train Loss: 0.2180
#   Val   Loss: 0.8108
#   Train Dice: 0.8744 | Val Dice: 0.4368
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 110/200
#   Train Loss: 0.2197
#   Val   Loss: 0.9384
#   Train Dice: 0.8734 | Val Dice: 0.3393
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 111/200
#   Train Loss: 0.2216
#   Val   Loss: 0.7429
#   Train Dice: 0.8719 | Val Dice: 0.4835
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 112/200
#   Train Loss: 0.2232
#   Val   Loss: 0.7407
#   Train Dice: 0.8709 | Val Dice: 0.4853
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 113/200
#   Train Loss: 0.2196
#   Val   Loss: 0.7471
#   Train Dice: 0.8739 | Val Dice: 0.4808
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 114/200
#   Train Loss: 0.2159
#   Val   Loss: 0.7272
#   Train Dice: 0.8749 | Val Dice: 0.4978
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 115/200
#   Train Loss: 0.2115
#   Val   Loss: 0.9108
#   Train Dice: 0.8783 | Val Dice: 0.3778
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 116/200
#   Train Loss: 0.2146
#   Val   Loss: 0.8279
#   Train Dice: 0.8767 | Val Dice: 0.4339
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 117/200
#   Train Loss: 0.2109
#   Val   Loss: 0.8508
#   Train Dice: 0.8786 | Val Dice: 0.4288
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 118/200
#   Train Loss: 0.2040
#   Val   Loss: 0.8615
#   Train Dice: 0.8827 | Val Dice: 0.4220
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 119/200
#   Train Loss: 0.2141
#   Val   Loss: 0.7907
#   Train Dice: 0.8753 | Val Dice: 0.4627
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 120/200
#   Train Loss: 0.2151
#   Val   Loss: 0.7863
#   Train Dice: 0.8763 | Val Dice: 0.4502
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 121/200
#   Train Loss: 0.2111
#   Val   Loss: 0.7993
#   Train Dice: 0.8783 | Val Dice: 0.4466
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 122/200
#   Train Loss: 0.2109
#   Val   Loss: 0.7830
#   Train Dice: 0.8785 | Val Dice: 0.4646
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 123/200
#   Train Loss: 0.2049
#   Val   Loss: 0.7498
#   Train Dice: 0.8819 | Val Dice: 0.4923
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 124/200
#   Train Loss: 0.2066
#   Val   Loss: 0.8298
#   Train Dice: 0.8818 | Val Dice: 0.4297
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 125/200
#   Train Loss: 0.2139
#   Val   Loss: 0.7111
#   Train Dice: 0.8768 | Val Dice: 0.5125
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 126/200
#   Train Loss: 0.2136
#   Val   Loss: 0.8135
#   Train Dice: 0.8777 | Val Dice: 0.4401
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 127/200
#   Train Loss: 0.2127
#   Val   Loss: 1.0725
#   Train Dice: 0.8772 | Val Dice: 0.2799
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 128/200
#   Train Loss: 0.2168
#   Val   Loss: 0.8394
#   Train Dice: 0.8761 | Val Dice: 0.4272
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 129/200
#   Train Loss: 0.2094
#   Val   Loss: 0.8761
#   Train Dice: 0.8794 | Val Dice: 0.4132
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 130/200
#   Train Loss: 0.2076
#   Val   Loss: 0.7591
#   Train Dice: 0.8801 | Val Dice: 0.4810
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 131/200
#   Train Loss: 0.2039
#   Val   Loss: 0.8330
#   Train Dice: 0.8819 | Val Dice: 0.4372
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 132/200
#   Train Loss: 0.2106
#   Val   Loss: 1.0310
#   Train Dice: 0.8777 | Val Dice: 0.3011
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 133/200
#   Train Loss: 0.2057
#   Val   Loss: 0.9640
#   Train Dice: 0.8811 | Val Dice: 0.3426
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 134/200
#   Train Loss: 0.2115
#   Val   Loss: 0.7912
#   Train Dice: 0.8781 | Val Dice: 0.4502
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 135/200
#   Train Loss: 0.2125
#   Val   Loss: 0.9348
#   Train Dice: 0.8777 | Val Dice: 0.3585
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 136/200
#   Train Loss: 0.2069
#   Val   Loss: 0.8372
#   Train Dice: 0.8803 | Val Dice: 0.4229
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 137/200
#   Train Loss: 0.2156
#   Val   Loss: 0.8783
#   Train Dice: 0.8754 | Val Dice: 0.4123
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 138/200
#   Train Loss: 0.2010
#   Val   Loss: 0.9286
#   Train Dice: 0.8839 | Val Dice: 0.3759
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 139/200
#   Train Loss: 0.2025
#   Val   Loss: 0.7629
#   Train Dice: 0.8829 | Val Dice: 0.4846
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 140/200
#   Train Loss: 0.1934
#   Val   Loss: 0.9679
#   Train Dice: 0.8882 | Val Dice: 0.3470
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 141/200
#   Train Loss: 0.2013
#   Val   Loss: 0.9335
#   Train Dice: 0.8842 | Val Dice: 0.3710
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 142/200
#   Train Loss: 0.1964
#   Val   Loss: 1.0035
#   Train Dice: 0.8859 | Val Dice: 0.3284
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 143/200
#   Train Loss: 0.2078
#   Val   Loss: 0.9099
#   Train Dice: 0.8801 | Val Dice: 0.3946
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 144/200
#   Train Loss: 0.2046
#   Val   Loss: 0.7128
#   Train Dice: 0.8824 | Val Dice: 0.5139
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 145/200
#   Train Loss: 0.1986
#   Val   Loss: 0.9587
#   Train Dice: 0.8850 | Val Dice: 0.3442
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 146/200
#   Train Loss: 0.1927
#   Val   Loss: 0.9173
#   Train Dice: 0.8885 | Val Dice: 0.3894
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 147/200
#   Train Loss: 0.2072
#   Val   Loss: 0.8388
#   Train Dice: 0.8795 | Val Dice: 0.4395
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 148/200
#   Train Loss: 0.1949
#   Val   Loss: 1.0214
#   Train Dice: 0.8877 | Val Dice: 0.3125
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 149/200
#   Train Loss: 0.2072
#   Val   Loss: 0.8669
#   Train Dice: 0.8802 | Val Dice: 0.4269
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 150/200
#   Train Loss: 0.2038
#   Val   Loss: 0.9281
#   Train Dice: 0.8822 | Val Dice: 0.3723
#   Current LR: 0.000250
# ----------------------------------------
# Epoch 151/200
#   Train Loss: 0.1977
#   Val   Loss: 0.7946
#   Train Dice: 0.8855 | Val Dice: 0.4735
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 152/200
#   Train Loss: 0.2010
#   Val   Loss: 0.8338
#   Train Dice: 0.8840 | Val Dice: 0.4424
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 153/200
#   Train Loss: 0.1998
#   Val   Loss: 0.8586
#   Train Dice: 0.8845 | Val Dice: 0.4257
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 154/200
#   Train Loss: 0.1971
#   Val   Loss: 0.8282
#   Train Dice: 0.8853 | Val Dice: 0.4547
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 155/200
#   Train Loss: 0.1905
#   Val   Loss: 0.8808
#   Train Dice: 0.8904 | Val Dice: 0.4200
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 156/200
#   Train Loss: 0.2017
#   Val   Loss: 1.0005
#   Train Dice: 0.8828 | Val Dice: 0.3294
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 157/200
#   Train Loss: 0.1943
#   Val   Loss: 0.8675
#   Train Dice: 0.8875 | Val Dice: 0.4179
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 158/200
#   Train Loss: 0.1955
#   Val   Loss: 0.8572
#   Train Dice: 0.8867 | Val Dice: 0.4218
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 159/200
#   Train Loss: 0.1969
#   Val   Loss: 0.9839
#   Train Dice: 0.8863 | Val Dice: 0.3419
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 160/200
#   Train Loss: 0.2002
#   Val   Loss: 0.7817
#   Train Dice: 0.8837 | Val Dice: 0.4823
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 161/200
#   Train Loss: 0.1890
#   Val   Loss: 0.8124
#   Train Dice: 0.8909 | Val Dice: 0.4587
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 162/200
#   Train Loss: 0.1990
#   Val   Loss: 0.8488
#   Train Dice: 0.8848 | Val Dice: 0.4342
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 163/200
#   Train Loss: 0.1942
#   Val   Loss: 0.8547
#   Train Dice: 0.8879 | Val Dice: 0.4280
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 164/200
#   Train Loss: 0.1909
#   Val   Loss: 0.8440
#   Train Dice: 0.8899 | Val Dice: 0.4449
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 165/200
#   Train Loss: 0.1987
#   Val   Loss: 0.9562
#   Train Dice: 0.8845 | Val Dice: 0.3584
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 166/200
#   Train Loss: 0.1908
#   Val   Loss: 0.9087
#   Train Dice: 0.8897 | Val Dice: 0.3741
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 167/200
#   Train Loss: 0.1859
#   Val   Loss: 0.8023
#   Train Dice: 0.8928 | Val Dice: 0.4582
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 168/200
#   Train Loss: 0.1959
#   Val   Loss: 0.8662
#   Train Dice: 0.8858 | Val Dice: 0.4194
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 169/200
#   Train Loss: 0.1919
#   Val   Loss: 0.8121
#   Train Dice: 0.8891 | Val Dice: 0.4610
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 170/200
#   Train Loss: 0.1916
#   Val   Loss: 0.7485
#   Train Dice: 0.8894 | Val Dice: 0.4969
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 171/200
#   Train Loss: 0.1914
#   Val   Loss: 0.8485
#   Train Dice: 0.8892 | Val Dice: 0.4337
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 172/200
#   Train Loss: 0.1985
#   Val   Loss: 0.8549
#   Train Dice: 0.8849 | Val Dice: 0.4274
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 173/200
#   Train Loss: 0.1958
#   Val   Loss: 0.8373
#   Train Dice: 0.8868 | Val Dice: 0.4378
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 174/200
#   Train Loss: 0.1916
#   Val   Loss: 0.8333
#   Train Dice: 0.8887 | Val Dice: 0.4494
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 175/200
#   Train Loss: 0.1940
#   Val   Loss: 0.7895
#   Train Dice: 0.8885 | Val Dice: 0.4754
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 176/200
#   Train Loss: 0.1905
#   Val   Loss: 0.7662
#   Train Dice: 0.8892 | Val Dice: 0.4872
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 177/200
#   Train Loss: 0.1904
#   Val   Loss: 0.8443
#   Train Dice: 0.8904 | Val Dice: 0.4370
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 178/200
#   Train Loss: 0.1877
#   Val   Loss: 0.8267
#   Train Dice: 0.8913 | Val Dice: 0.4535
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 179/200
#   Train Loss: 0.1889
#   Val   Loss: 0.8007
#   Train Dice: 0.8906 | Val Dice: 0.4694
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 180/200
#   Train Loss: 0.1856
#   Val   Loss: 0.8561
#   Train Dice: 0.8922 | Val Dice: 0.4307
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 181/200
#   Train Loss: 0.1973
#   Val   Loss: 0.8040
#   Train Dice: 0.8853 | Val Dice: 0.4628
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 182/200
#   Train Loss: 0.1953
#   Val   Loss: 0.7505
#   Train Dice: 0.8870 | Val Dice: 0.5053
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 183/200
#   Train Loss: 0.2014
#   Val   Loss: 0.8480
#   Train Dice: 0.8827 | Val Dice: 0.4318
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 184/200
#   Train Loss: 0.2022
#   Val   Loss: 0.8789
#   Train Dice: 0.8842 | Val Dice: 0.4205
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 185/200
#   Train Loss: 0.1891
#   Val   Loss: 0.8480
#   Train Dice: 0.8905 | Val Dice: 0.4407
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 186/200
#   Train Loss: 0.1791
#   Val   Loss: 0.8458
#   Train Dice: 0.8962 | Val Dice: 0.4473
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 187/200
#   Train Loss: 0.1809
#   Val   Loss: 0.8041
#   Train Dice: 0.8951 | Val Dice: 0.4645
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 188/200
#   Train Loss: 0.1803
#   Val   Loss: 0.7709
#   Train Dice: 0.8956 | Val Dice: 0.4865
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 189/200
#   Train Loss: 0.1869
#   Val   Loss: 0.7322
#   Train Dice: 0.8914 | Val Dice: 0.5146
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 190/200
#   Train Loss: 0.1805
#   Val   Loss: 0.8001
#   Train Dice: 0.8951 | Val Dice: 0.4656
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 191/200
#   Train Loss: 0.1877
#   Val   Loss: 0.8532
#   Train Dice: 0.8916 | Val Dice: 0.4341
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 192/200
#   Train Loss: 0.1848
#   Val   Loss: 0.7739
#   Train Dice: 0.8928 | Val Dice: 0.4924
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 193/200
#   Train Loss: 0.1906
#   Val   Loss: 0.8933
#   Train Dice: 0.8895 | Val Dice: 0.4095
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 194/200
#   Train Loss: 0.1955
#   Val   Loss: 0.8116
#   Train Dice: 0.8870 | Val Dice: 0.4628
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 195/200
#   Train Loss: 0.1821
#   Val   Loss: 0.8795
#   Train Dice: 0.8945 | Val Dice: 0.4250
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 196/200
#   Train Loss: 0.1877
#   Val   Loss: 0.8366
#   Train Dice: 0.8915 | Val Dice: 0.4506
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 197/200
#   Train Loss: 0.1908
#   Val   Loss: 0.8394
#   Train Dice: 0.8896 | Val Dice: 0.4515
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 198/200
#   Train Loss: 0.1828
#   Val   Loss: 0.8155
#   Train Dice: 0.8947 | Val Dice: 0.4647
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 199/200
#   Train Loss: 0.1788
#   Val   Loss: 0.9052
#   Train Dice: 0.8968 | Val Dice: 0.4032
#   Current LR: 0.000125
# ----------------------------------------
# Epoch 200/200
#   Train Loss: 0.1828
#   Val   Loss: 0.7381
#   Train Dice: 0.8939 | Val Dice: 0.5146
#   Current LR: 0.000125
# ✅ Last model saved

# %%
with open(data_dir / "UNet_train_history.json", "w") as f:
    json.dump(train_history, f, indent=4)

with open(data_dir / "UNet_val_history.json", "w") as f:
    json.dump(val_history, f, indent=4)

print("Historiques sauvegardés en JSON")
# Out:
# Historiques sauvegardés en JSON

# %% [markdown]
# # 10) Validation tests

# %% [markdown]
# #### 10.1) Load the model

# %%
model.load_state_dict(torch.load(models_dir / "dice_best_model_state_dict.pth", map_location=device, weights_only=True))
model.eval()
# Out:
# UUNet(
#   (stem): DoubleConv(
#     (block): Sequential(
#       (0): ConvBNReLU(
#         (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#       (1): ConvBNReLU(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act): ReLU(inplace=True)
#       )
#     )
#   )
#   (a0): AsymUNetBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (down_convs): ModuleList(
#       (0): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (1): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (2): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (3): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bottom): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#     (up_blocks): ModuleList(
#       (0): UpBlock(
#         (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): UpBlock(
#         (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (2): UpBlock(
#         (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (a1): AsymUNetBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (down_convs): ModuleList(
#       (0): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (1): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (2): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bottom): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#     (up_blocks): ModuleList(
#       (0): UpBlock(
#         (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): UpBlock(
#         (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (a2): AsymUNetBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (down_convs): ModuleList(
#       (0): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (1): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bottom): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#     (up_blocks): ModuleList(
#       (0): UpBlock(
#         (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (a3): DownToBottleneck(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (to4): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#     (bot): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (up4_to_3): UpBlock(
#     (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2), bias=False)
#     (conv): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#   )
#   (b3): AsymUNetBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (down_convs): ModuleList(
#       (0): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bottom): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#     (up_blocks): ModuleList(
#       (0): UpBlock(
#         (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): UpBlock(
#         (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (b2): AsymUNetBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (down_convs): ModuleList(
#       (0): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (1): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bottom): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#     (up_blocks): ModuleList(
#       (0): UpBlock(
#         (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): UpBlock(
#         (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (2): UpBlock(
#         (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (b1): AsymUNetBlock(
#     (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (down_convs): ModuleList(
#       (0): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (1): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#       (2): DoubleConv(
#         (block): Sequential(
#           (0): ConvBNReLU(
#             (conv): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#           (1): ConvBNReLU(
#             (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (act): ReLU(inplace=True)
#           )
#         )
#       )
#     )
#     (bottom): DoubleConv(
#       (block): Sequential(
#         (0): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#         (1): ConvBNReLU(
#           (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (act): ReLU(inplace=True)
#         )
#       )
#     )
#     (up_blocks): ModuleList(
#       (0): UpBlock(
#         (up): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(1024, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (1): UpBlock(
#         (up): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (2): UpBlock(
#         (up): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): UpBlock(
#         (up): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2), bias=False)
#         (conv): DoubleConv(
#           (block): Sequential(
#             (0): ConvBNReLU(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#             (1): ConvBNReLU(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (act): ReLU(inplace=True)
#             )
#           )
#         )
#       )
#     )
#   )
#   (out_conv): Conv2d(64, 2, kernel_size=(1, 1), stride=(1, 1))
# )

# %% [markdown]
# #### 10.2) Images

# %%
model.eval()

# 📁 Dossier pour sauvegarder les triplets
pred_dir = data_dir / "predictions_test_triplets"
pred_dir.mkdir(parents=True, exist_ok=True)

img_index = 0

with torch.no_grad():
    for batch in test_loader:
        imgs   = batch["image"].to(device)  # (B,3,H,W)
        labels = batch["label"].to(device)  # (B,1,H,W)

        logits = model(imgs)
        if isinstance(logits, list):
                logits = logits[0]                # (B,2,H,W)
        preds  = logits.argmax(dim=1)       # (B,H,W)
        targets = labels.squeeze(1)         # (B,H,W)

        for i in range(imgs.size(0)):
            img_i  = imgs[i].cpu()
            gt_i   = targets[i].cpu()
            pred_i = preds[i].cpu()

            fig, ax = plt.subplots(1, 3, figsize=(10, 4))

            ax[0].imshow(img_i.permute(1, 2, 0))
            ax[0].set_title("Original")

            ax[1].imshow(gt_i, cmap="gray")
            ax[1].set_title("Ground truth (vessels)")

            ax[2].imshow(pred_i, cmap="gray")
            ax[2].set_title("Prediction")

            for a in ax:
                a.axis("off")

            plt.tight_layout()

            save_path = pred_dir / f"test_triplet_{img_index:02d}.png"
            plt.savefig(save_path, dpi=150, bbox_inches="tight")
            plt.show()

            img_index += 1

print(f"Triplets sauvegardés dans : {pred_dir}")
# Out:
# Triplets sauvegardés dans : /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/predictions_test_triplets

# %% [markdown]
# #### 10.3) Curves

# %%
def plot_metric(train_history, val_history, key, title=None, mark_best_on="val_loss", save_folder=data_dir):
    """
    key: nom de la métrique dans les dicts (ex: "loss", "dice", "auc")

    mark_best_on:
        - "val_loss" → marquer l'epoch où val_loss est minimal
        - "val_<key>" → marquer la meilleure valeur validation pour cette métrique (max)
    """

    train = train_history.get(key, [])
    val   = val_history.get(key, [])

    if len(val) == 0:
        print(f"⚠️ Impossible de tracer '{key}' (aucune valeur de validation trouvée)")
        return

    epochs = range(1, len(val) + 1)

    plt.figure(figsize=(7, 5))
    plt.plot(epochs, train, label=f"Train {key}", linewidth=2)
    plt.plot(epochs, val,   label=f"Val {key}", linewidth=2)

    # ======== BEST POINT (scatter) =========
    if mark_best_on == "val_loss" and "loss" in val_history:
        # meilleur = minimum
        best_e = int(np.argmin(val_history["loss"])) + 1
        best_v = val[best_e - 1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")

    elif mark_best_on == f"val_{key}" and len(val) > 0:
        # meilleur = maximum
        best_e = int(np.nanargmax(val)) + 1
        best_v = val[best_e - 1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")

    plt.xlabel("Epoch")
    plt.ylabel(key)
    plt.title(title or f"{key} (train vs val)")
    plt.grid(True)
    plt.legend()

    save_path = save_folder / f"{key}.png"
    plt.savefig(save_path, dpi=200, bbox_inches="tight")
    print(f"💾 Courbe sauvegardée : {save_path}")

    plt.show()

# %%
# Loss totale, Dice, AUC : même type de visualisation que dans ton notebook

plot_metric(train_history, val_history, "loss",
            title="Loss (Dice + CE)", mark_best_on="val_loss")

plot_metric(train_history, val_history, "dice",
            title="Dice (artery+vein avg)", mark_best_on="val_dice")

plot_metric(train_history, val_history, "auc",
            title="AUC (artery+vein avg)", mark_best_on="val_auc")
# Out:
# 💾 Courbe sauvegardée : /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/loss.png
# 💾 Courbe sauvegardée : /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/dice.png
# 💾 Courbe sauvegardée : /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/auc.png

# %% [markdown]
# #### 10.4) Table of metrics

# %%
# ==== Évaluation globale sur le test ====

model.eval()

conf_sums_test = init_confmat_sums(num_classes=NUM_CLASSES)
auc_buf_test   = init_auc_buffers(classes=[VESSEL_CLASS])

with torch.no_grad():
    for batch in test_loader:
        imgs   = batch["image"].to(device)
        labels = batch["label"].to(device)   # (B,1,H,W)

        logits = model(imgs)
        if isinstance(logits, list):
                logits = logits[0]                 # (B,2,H,W)
        preds  = logits.argmax(dim=1)        # (B,H,W)
        targets = labels.squeeze(1)          # (B,H,W)

        update_confmat_sums(conf_sums_test, preds, targets, NUM_CLASSES)
        update_auc_buffers(auc_buf_test, logits, targets)

vessel_metrics = compute_scalar_metrics_from_confmat(conf_sums_test, include_classes=[VESSEL_CLASS])
vessel_auc     = compute_mean_auc(auc_buf_test)

results = {
    "Vessel": {
        "accuracy":    vessel_metrics["accuracy"],
        "precision":   vessel_metrics["precision"],
        "recall":      vessel_metrics["recall"],
        "specificity": vessel_metrics["specificity"],
        "dice":        vessel_metrics["dice"],
        "IoU":         vessel_metrics["iou"],
        "AUC":         vessel_auc,
    }
}

df_global = pd.DataFrame(results).T.round(4)

print("\n=== Résultats globaux sur le test (FOV uniquement) ===\n")
display(df_global)

# Sauvegarde en CSV / JSON
metrics_csv_path  = data_dir / "metrics_global_test.csv"
metrics_json_path = data_dir / "metrics_global_test.json"

df_global.to_csv(metrics_csv_path)
df_global.to_json(metrics_json_path, orient="index")

print("→ Sauvegardé :")
print("  ", metrics_csv_path)
print("  ", metrics_json_path)
# Out:
# === Résultats globaux sur le test (FOV uniquement) ===
#         accuracy  precision  recall  specificity   dice     IoU     AUC
# Vessel    0.9517     0.7436  0.8246       0.9666  0.782  0.6421  0.9663
# → Sauvegardé :
#    /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/metrics_global_test.csv
#    /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/metrics_global_test.json

# %% [markdown]
# #### 10.4) Comparaison of the images

# %%
# ==========================================================
#   Comparison of the images — Standalone (NO FOV version)
#   Fusion of the 3 original cells — produces final figure
# ==========================================================

# ---- HELPER FUNCTIONS ----

def confusion_binary(pred_bin: torch.Tensor, gt_bin: torch.Tensor):
    pred_bin = pred_bin.bool()
    gt_bin   = gt_bin.bool()
    TP = (pred_bin & gt_bin).sum().item()
    FP = (pred_bin & ~gt_bin).sum().item()
    FN = (~pred_bin & gt_bin).sum().item()
    TN = (~pred_bin & ~gt_bin).sum().item()
    return TP, FP, FN, TN


def metrics_from_conf(TP, FP, FN, TN):
    eps = 1e-7
    Acc  = (TP + TN) / max(TP + TN + FP + FN, eps)
    SE   = TP / max(TP + FN, eps)
    SP   = TN / max(TN + FP, eps)
    Prec = TP / max(TP + FP, eps)
    F1   = 2 * Prec * SE / max(Prec + SE, eps)
    IoU  = TP / max(TP + FP + FN, eps)
    return F1, IoU, Acc, SE, SP


def auc_from_logits_one_class(logits_1img, gt_1img, cls):
    with torch.no_grad():
        probs = F.softmax(logits_1img.unsqueeze(0), dim=1)[0]
        prob_cls = probs[cls]

        y_score = prob_cls.view(-1).cpu().numpy()
        y_true  = (gt_1img.view(-1) == cls).cpu().numpy().astype(np.uint8)

        if (y_true == 1).sum() == 0 or (y_true == 0).sum() == 0:
            return float("nan")

        try:
            return float(roc_auc_score(y_true, y_score))
        except:
            return float("nan")


# ==========================================================
#               METRICS PER IMAGE — FULL IMAGE ONLY
# ==========================================================

model.eval()

metric_names = ["F1", "IoU", "Acc", "SE", "SP", "AUC"]
scores_full = {m: [] for m in metric_names}

img_indices = []

with torch.no_grad():
    current_idx = 0
    for batch in test_loader:
        imgs   = batch["image"].to(device)
        labels = batch["label"].to(device)

        logits  = model(imgs)
        if isinstance(logits, list):
                logits = logits[0]
        preds   = logits.argmax(dim=1)
        targets = labels.squeeze(1)

        for i in range(imgs.size(0)):
            gt_i   = targets[i]
            pred_i = preds[i]
            log_i  = logits[i]

            pred_v = (pred_i == VESSEL_CLASS)
            gt_v   = (gt_i == VESSEL_CLASS)

            TP, FP, FN, TN = confusion_binary(pred_v, gt_v)
            F1, IoU, Acc, SE, SP = metrics_from_conf(TP, FP, FN, TN)
            AUC = auc_from_logits_one_class(log_i, gt_i, VESSEL_CLASS)

            scores_full["F1"].append(F1)
            scores_full["IoU"].append(IoU)
            scores_full["Acc"].append(Acc)
            scores_full["SE"].append(SE)
            scores_full["SP"].append(SP)
            scores_full["AUC"].append(AUC)

            img_indices.append(current_idx)
            current_idx += 1

# ==========================================================
#               FINAL FIGURE (SAME AS LAST CELL)
#           BUT SINGLE COLUMN (NO FOV IN DATASET)
# ==========================================================

metric_names = ["F1", "IoU", "Acc", "SE", "SP", "AUC"]

fig, axes = plt.subplots(
    nrows=6, ncols=1, figsize=(12, 30), sharex=True
)

axes = axes.ravel()

axes[0].set_title("METRICS PER IMAGE", fontsize=18, fontweight="bold", pad=20)

for row, m in enumerate(metric_names):

    vals = np.array(scores_full[m], dtype=float)
    mean_val = np.nanmean(vals)

    ax = axes[row]
    ax.bar(np.arange(len(vals)), vals)
    ax.axhline(mean_val, color="red", linestyle="--", linewidth=2)

    ax.text(
        0.99, 0.92,
        f"mean = {mean_val:.3f}",
        transform=ax.transAxes,
        horizontalalignment="right",
        fontsize=13,
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray")
    )

    ax.set_ylabel(m, fontsize=16, fontweight="bold")
    ax.grid(True, axis="y")


axes[-1].set_xticks(np.arange(len(vals)))
axes[-1].set_xticklabels(
    [f"{i+1:02d}" for i in range(len(vals))],
    rotation=45,
    fontsize=12
)
axes[-1].set_xlabel("Test image index", fontsize=14)

plt.tight_layout()

out_path = data_dir / "per_image_metrics.png"
plt.savefig(out_path, dpi=200, bbox_inches="tight")
plt.show()

print(f"Sauvegardé : {out_path}")
# Out:
# Sauvegardé : /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/per_image_metrics.png

# %%
# ==========================================================
#   Comparison of the images — Standalone (NO FOV)
#   + Images below histogram bars
# ==========================================================

# ---- HELPER FUNCTIONS ----

def confusion_binary(pred_bin: torch.Tensor, gt_bin: torch.Tensor):
    pred_bin = pred_bin.bool()
    gt_bin   = gt_bin.bool()
    TP = (pred_bin & gt_bin).sum().item()
    FP = (pred_bin & ~gt_bin).sum().item()
    FN = (~pred_bin & gt_bin).sum().item()
    TN = (~pred_bin & ~gt_bin).sum().item()
    return TP, FP, FN, TN


def metrics_from_conf(TP, FP, FN, TN):
    eps = 1e-7
    Acc  = (TP + TN) / max(TP + TN + FP + FN, eps)
    SE   = TP / max(TP + FN, eps)
    SP   = TN / max(TN + FP, eps)
    Prec = TP / max(TP + FP, eps)
    F1   = 2 * Prec * SE / max(Prec + SE, eps)
    IoU  = TP / max(TP + FP + FN, eps)
    return F1, IoU, Acc, SE, SP


def auc_from_logits_one_class(logits_1img, gt_1img, cls):
    with torch.no_grad():
        probs = F.softmax(logits_1img.unsqueeze(0), dim=1)[0]
        prob_cls = probs[cls]

        y_score = prob_cls.view(-1).cpu().numpy()
        y_true  = (gt_1img.view(-1) == cls).cpu().numpy().astype(np.uint8)

        if (y_true == 1).sum() == 0 or (y_true == 0).sum() == 0:
            return float("nan")

        try:
            return float(roc_auc_score(y_true, y_score))
        except:
            return float("nan")


# ==========================================================
#               METRICS PER IMAGE — FULL IMAGE ONLY
# ==========================================================

model.eval()

metric_names = ["F1", "IoU", "Acc", "SE", "SP", "AUC"]
scores_full = {m: [] for m in metric_names}
img_indices = []
all_images = []  # stockage des images brutes pour affichage

with torch.no_grad():
    current_idx = 0
    for batch in test_loader:
        imgs   = batch["image"].to(device)
        labels = batch["label"].to(device)

        logits  = model(imgs)
        if isinstance(logits, list):
                logits = logits[0]
        preds   = logits.argmax(dim=1)
        targets = labels.squeeze(1)

        for i in range(imgs.size(0)):
            gt_i   = targets[i]
            pred_i = preds[i]
            log_i  = logits[i]

            # Sauvegarde image originale pour affichage
            all_images.append(imgs[i].cpu().permute(1, 2, 0).numpy())

            pred_v = (pred_i == VESSEL_CLASS)
            gt_v   = (gt_i == VESSEL_CLASS)

            TP, FP, FN, TN = confusion_binary(pred_v, gt_v)
            F1, IoU, Acc, SE, SP = metrics_from_conf(TP, FP, FN, TN)
            AUC = auc_from_logits_one_class(log_i, gt_i, VESSEL_CLASS)

            scores_full["F1"].append(F1)
            scores_full["IoU"].append(IoU)
            scores_full["Acc"].append(Acc)
            scores_full["SE"].append(SE)
            scores_full["SP"].append(SP)
            scores_full["AUC"].append(AUC)

            img_indices.append(current_idx)
            current_idx += 1

# ==========================================================
#                FINAL FIGURE WITH IMAGES UNDER BARS
# ==========================================================

metric_names = ["F1", "IoU", "Acc", "SE", "SP", "AUC"]

fig, axes = plt.subplots(
    nrows=6, ncols=1, figsize=(14, 32), sharex=True
)

axes = axes.ravel()

axes[0].set_title("METRICS PER IMAGE — FULL IMAGE (NO FOV)", fontsize=22, fontweight="bold", pad=20)

n_images = len(all_images)
x = np.arange(n_images)

from matplotlib.offsetbox import OffsetImage, AnnotationBbox

def add_image_under_bar(ax, img, xpos, y_bottom):
    imagebox = OffsetImage(img, zoom=0.13)
    ab = AnnotationBbox(imagebox, (xpos, y_bottom - 0.08),
                        xycoords=("data", "axes fraction"),
                        frameon=False)
    ax.add_artist(ab)

for row, m in enumerate(metric_names):

    vals = np.array(scores_full[m], dtype=float)
    mean_val = np.nanmean(vals)

    ax = axes[row]
    bars = ax.bar(x, vals)

    # Ligne de moyenne
    ax.axhline(mean_val, color="red", linestyle="--", linewidth=2)
    ax.text(
        0.99, 0.92,
        f"mean = {mean_val:.3f}",
        transform=ax.transAxes,
        horizontalalignment="right",
        fontsize=13,
        bbox=dict(facecolor="white", alpha=0.8, edgecolor="gray")
    )

    # Ajout des images sous chaque barre
    for j in range(n_images):
        img = all_images[j]
        add_image_under_bar(ax, img, j, 0)

    ax.set_ylabel(m, fontsize=16, fontweight="bold")
    ax.grid(True, axis="y")

axes[-1].set_xticks(x)
axes[-1].set_xticklabels([f"{i+1:02d}" for i in x], rotation=45, fontsize=12)
axes[-1].set_xlabel("Test image index", fontsize=14)

plt.tight_layout()

out_path = data_dir / "per_image_metrics_FULLIMAGE_with_thumbnails.png"
plt.savefig(out_path, dpi=200, bbox_inches="tight")
plt.show()

print(f"Sauvegardé : {out_path}")
# Out:
# Sauvegardé : /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/per_image_metrics_FULLIMAGE_with_thumbnails.png

# %%
# ==========================================================
#   Overlay GT vs Pred — With legend, filenames, saving
# ==========================================================

model.eval()

# 📁 Dossier pour sauvegarder les overlays
overlay_dir = data_dir / "overlays_test"
overlay_dir.mkdir(parents=True, exist_ok=True)

# Pour récupérer le nom réel des fichiers test (triés)
test_img_paths = sorted(list(test_images_dir.glob("*.png")))

with torch.no_grad():
    for idx, batch in enumerate(test_loader):
        imgs    = batch["image"].to(device)      # (B,3,H,W)
        labels  = batch["label"].to(device)      # (B,1,H,W)
        logits  = model(imgs)
        if isinstance(logits, list):
                logits = logits[0]                  # (B,2,H,W)
        preds   = logits.argmax(dim=1)
        targets = labels.squeeze(1)

        batch_size = imgs.size(0)

        for i in range(batch_size):

            # Récupérer nom réel du fichier
            global_index = idx * batch_size + i
            img_name = test_img_paths[global_index].name

            # Tensors -> numpy
            gt  = (targets[i].cpu().numpy() == VESSEL_CLASS).astype(np.uint8)
            pr  = (preds[i].cpu().numpy()    == VESSEL_CLASS).astype(np.uint8)
            H, W = gt.shape

            # Overlay RGB
            overlay = np.zeros((H, W, 3), dtype=float)

            # TN (0,0) → noir
            mask_tn = (gt == 0) & (pr == 0)
            overlay[mask_tn] = [0, 0, 0]

            # TP (1,1) → vert
            mask_tp = (gt == 1) & (pr == 1)
            overlay[mask_tp] = [0, 1, 0]

            # FP (0,1) → rouge
            mask_fp = (gt == 0) & (pr == 1)
            overlay[mask_fp] = [1, 0, 0]

            # FN (1,0) → blanc
            mask_fn = (gt == 1) & (pr == 0)
            overlay[mask_fn] = [1, 1, 1]

            # ======== FIGURE ========
            fig, ax = plt.subplots(figsize=(6, 6))
            ax.imshow(overlay)
            ax.axis("off")
            ax.set_title(f"GT vs Pred — {img_name}", fontsize=14)

            # ======== LÉGENDE ========
            # On crée une "fake" légende avec des patches colorés
            import matplotlib.patches as mpatches
            legend_elems = [
                mpatches.Patch(color="black", label="TN: Background correct"),
                mpatches.Patch(color="green", label="TP: Vessel correct"),
                mpatches.Patch(color="red",   label="FP: Predicted vessel but GT background"),
                mpatches.Patch(facecolor="white", edgecolor="black", linewidth=1.5, label="FN: Missed vessel")
,
            ]
            ax.legend(handles=legend_elems, loc="lower center",
                      bbox_to_anchor=(0.5, -0.08),
                      fancybox=True, framealpha=1,
                      ncol=2)

            # ======== SAUVEGARDE ========
            save_path = overlay_dir / f"overlay_{global_index:02d}.png"
            plt.savefig(save_path, dpi=200, bbox_inches="tight")
            plt.show()

print(f"Overlays enregistrés dans : {overlay_dir}")
# Out:
# Overlays enregistrés dans : /home/usrs/hnoel/Tohoku/Monai/UUNET/UUNET_STARE_v2/overlays_test
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
