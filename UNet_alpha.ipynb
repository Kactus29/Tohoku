# %% [markdown]
# # Imports

# %% [markdown]
# #### PyTorch

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, OneCycleLR

# %%
print('PyTorch version', torch.__version__)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# PyTorch version 2.5.1
# Device: cuda

# %% [markdown]
# #### General

# %%
import os
import json
import math
import time
import random
from pathlib import Path
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from tqdm import tqdm

from sklearn.metrics import roc_auc_score

# %% [markdown]
# #### Monai

# %%
from monai.losses import DiceLoss, FocalLoss

# %% [markdown]
# # Parameters

# %% [markdown]
# #### Directories for the images

# %%
parent = Path().cwd().parent
data_root = parent / 'try_1'

train_images_dir = data_root / 'train' / 'images'
train_masks_dir = data_root / 'train' / 'masks'

val_images_dir = data_root / 'val' / 'images'
val_masks_dir = data_root / 'val' / 'masks'

# %% [markdown]
# #### General parameters

# %%
IMG_HEIGHT = 768
IMG_WIDTH = 768

BATCH_SIZE = 8

EPOCHS = 500
print('Number of epochs:', EPOCHS)

LR = 0.00005
print('Learning rate:', LR)

"""
0 : background (black)
1 : arteries (white)
2 : veins (gray)
"""
NUM_CLASSES = 3

COLOR_TO_LABEL = {
    (0,0,0): 0,
    (255,255,255): 1,
    (128,128,128): 2
}
# Out:
# Number of epochs: 500
# Learning rate: 5e-05

# %% [markdown]
# # DataLoaders

# %% [markdown]
# #### Create the class for the dataset images

# %%
class RAVIRDataset(Dataset):
    def __init__(self, img_dir, mask_dir, img_size=(IMG_HEIGHT, IMG_WIDTH), transforms=None):
        self.img_paths = sorted(list(Path(img_dir).glob('*.png')))
        self.mask_dir = Path(mask_dir)
        self.img_size = img_size
        self.transforms = transforms

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_p = self.img_paths[idx]
        mask_p = self.mask_dir / img_p.name
        img = Image.open(img_p).convert('RGB').resize(self.img_size, Image.BILINEAR)
        img = np.array(img, dtype=np.float32) / 255.0
        img = np.transpose(img, (2,0,1))  # C,H,W
        img_t = torch.from_numpy(img).float()
        # load mask and map colors to labels
        m = Image.open(mask_p).convert('RGB').resize(self.img_size, Image.NEAREST)
        m_arr = np.array(m, dtype=np.uint8)
        label = np.zeros((self.img_size[1], self.img_size[0]), dtype=np.uint8)
        for color, lab in COLOR_TO_LABEL.items():
            mask = np.all(m_arr == np.array(color, dtype=np.uint8), axis=-1)
            label[mask] = lab
        label_t = torch.from_numpy(label).long()  # H,W
        return img_t, label_t

# %%
train_ds = RAVIRDataset(train_images_dir, train_masks_dir, (IMG_WIDTH, IMG_HEIGHT))
val_ds = RAVIRDataset(val_images_dir, val_masks_dir, (IMG_WIDTH, IMG_HEIGHT))

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %% [markdown]
# # U-Net model

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True)
        )
    def forward(self, x):
        return self.net(x)

class UNet(nn.Module):
    def __init__(self, n_classes=NUM_CLASSES, in_channels=3, features=[32,64,128,256]):
        super().__init__()
        self.encs = nn.ModuleList()
        self.pools = nn.ModuleList()
        for f in features:
            self.encs.append(DoubleConv(in_channels, f))
            self.pools.append(nn.MaxPool2d(2))
            in_channels = f
        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        # decoder
        self.upconvs = nn.ModuleList()
        self.decs = nn.ModuleList()
        for f in reversed(features):
            self.upconvs.append(nn.ConvTranspose2d(f*2, f, kernel_size=2, stride=2))
            self.decs.append(DoubleConv(f*2, f))
        self.final_conv = nn.Conv2d(features[0], n_classes, kernel_size=1)

    def forward(self, x):
        skips = []
        for enc, pool in zip(self.encs, self.pools):
            x = enc(x)
            skips.append(x)
            x = pool(x)
        x = self.bottleneck(x)
        for up, dec, skip in zip(self.upconvs, self.decs, reversed(skips)):
            x = up(x)
            # pad if needed
            if x.shape != skip.shape:
                x = nn.functional.interpolate(x, size=skip.shape[2:])
            x = torch.cat([skip, x], dim=1)
            x = dec(x)
        x = self.final_conv(x)
        return x

model = UNet().to(device)
# print(model)

# %% [markdown]
# # Optimizer

# %%
optimizer = optim.AdamW(model.parameters(), lr=LR)

# %% [markdown]
# # Scheduler

# %%
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, 
    max_lr = 0.0001,
    steps_per_epoch = len(train_loader),
    epochs = EPOCHS,
    pct_start = 0.3,
    anneal_strategy = "cos"
)

# %% [markdown]
# # Loss function

# %%
def dice_loss(outputs, targets, epsilon=1e-6):
    """
    outputs: logits (N, C, H, W)
    targets: labels (N, H, W)
    """
    # Probabilités
    probs = F.softmax(outputs, dim=1)

    N, C, H, W = probs.shape

    # One-hot du masque → shape (N, C, H, W)
    targets_onehot = F.one_hot(targets, num_classes=C).permute(0, 3, 1, 2).float()

    # On ignore la classe 0 (background)
    probs = probs[:, 1:, :, :]          # (N, C-1, H, W)
    targets_onehot = targets_onehot[:, 1:, :, :]  # (N, C-1, H, W)

    # Dice par classe
    intersection = torch.sum(probs * targets_onehot, dim=(0, 2, 3))
    cardinality  = torch.sum(probs + targets_onehot, dim=(0, 2, 3))

    dice_per_class = (2 * intersection + epsilon) / (cardinality + epsilon)

    # Loss = 1 - moyenne des dice des classes artery + vein
    return 1 - dice_per_class.mean()

# %%
percentage = [0.872, 0.054, 0.073]
inverse_percentage = [round((1/p),2) for p in percentage]
print(inverse_percentage)

weights = torch.tensor(inverse_percentage).to(device)
CE_loss = nn.CrossEntropyLoss(weight=weights)
# Out:
# [1.15, 18.52, 13.7]

# %% [markdown]
# #### Alpha functions

# %%
def alpha_linear(epoch, total_epoch, start=0.9, end=0.1) :
    return start - (start-end) * (epoch / (total_epoch-1))

# %%
def alpha_exponential(epoch, total_epochs, start=0.9, end=0.1, k=5) :
    """α(t) decreases fastly at first, then stabilises"""
    return end + (start-end)*np.exp(-k * epoch / (total_epochs-1))

# %%
def alpha_cosine(epoch, total_epochs, start=0.9, end=0.1):
    """α(t) decreases according to a cosine (gentler at the beginning and end)"""
    return end + 0.5 * (start - end) * (1 + np.cos(np.pi * epoch / (total_epochs-1)))

# %% [markdown]
# # Model train

# %%
best_val_loss = float("inf")
best_val_dice = -float("inf")

model_name = "My_UNet_alpha_cosine_v1"
save_dir = Path("Models") / model_name

save_dir.mkdir(parents=True, exist_ok=True)
last_epoch_save = 0

# %%
NUM_CLASSES = 3
BACKGROUND_IDX = 0
VESSEL_CLASSES = [1, 2]

# %%
# ===========================================
#   DICTIONNAIRES STOCRAGE (MEAN ONLY)
# ===========================================

train_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        [],
    "lr":         [],
    "alpha":      []
}

val_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        []
}

# %%
# =========================
#          INIT
# =========================

def init_confmat_sums(num_classes=NUM_CLASSES) :
    sums = {
        "TP" : np.zeros(num_classes, dtype=np.int64),
        "FP" : np.zeros(num_classes, dtype=np.int64),
        "FN" : np.zeros(num_classes, dtype=np.int64),
        "TN" : np.zeros(num_classes, dtype=np.int64),
        "N"  : 0
    }
    return sums

def init_auc_buffers(include_classes=VESSEL_CLASSES) :
    return {c : {"y_true" : [], "y_score" : []} for c in include_classes}

# %%
# =========================
#         UPDATE
# =========================

def update_confmat_sums(sums, preds, targets, num_classes=NUM_CLASSES) :
    with torch.no_grad() :
        for c in range(num_classes) :
            p = (preds == c)
            t = (targets == c)
            tp = (p & t).sum().item()
            fp = (p & ~t).sum().item()
            fn = (~p & t).sum().item()
            tn = (~p & ~t).sum().item()
            sums["TP"][c] += tp
            sums["FP"][c] += fp
            sums["FN"][c] += fn
            sums["TN"][c] += tn
        sums["N"] += targets.numel()



def update_auc_buffers(buffers, logits, targets):
    with torch.no_grad():
        probs = F.softmax(logits, dim=1)
        flat_probs = probs.permute(0,2,3,1).reshape(-1, probs.shape[1])
        flat_t     = targets.reshape(-1)

        for c in buffers.keys():
            y_true = (flat_t == c).cpu().numpy().astype(np.uint8)
            y_score = flat_probs[:, c].cpu().numpy()
            buffers[c]["y_true"].append(y_true)
            buffers[c]["y_score"].append(y_score)

# %%
def compute_scalar_metrics_from_confmat(sums, include_classes):
    TP, FP, FN, TN = sums["TP"], sums["FP"], sums["FN"], sums["TN"]
    eps = 1e-7

    acc_c  = (TP + TN) / np.maximum(TP + TN + FP + FN, eps)
    prec_c = TP / np.maximum(TP + FP, eps)
    rec_c  = TP / np.maximum(TP + FN, eps)
    spec_c = TN / np.maximum(TN + FP, eps)
    dice_c = (2 * TP) / np.maximum(2 * TP + FP + FN, eps)
    iou_c  = TP / np.maximum(TP + FP + FN, eps)

    idx = np.array(include_classes, dtype=int)
    return {
        "accuracy":   float(np.mean(acc_c[idx])),
        "precision":  float(np.mean(prec_c[idx])),
        "recall":     float(np.mean(rec_c[idx])),
        "specificity":float(np.mean(spec_c[idx])),
        "dice":       float(np.mean(dice_c[idx])),
        "iou":        float(np.mean(iou_c[idx])),
    }

# %%
def compute_mean_auc(buffers):
    aucs = []
    for c, pack in buffers.items():
        if len(pack["y_true"]) == 0: 
            continue
        y_true = np.concatenate(pack["y_true"])
        y_score = np.concatenate(pack["y_score"])
        pos = (y_true == 1).sum()
        neg = (y_true == 0).sum()
        if pos == 0 or neg == 0:
            continue
        try:
            aucs.append(roc_auc_score(y_true, y_score))
        except:
            pass
    if len(aucs) == 0:
        return float("nan")
    return float(np.mean(aucs))

# %%
# =========================
#        LEARNING
# =========================

for epoch in range(EPOCHS) :

    # =========================
    #        TRAIN
    # =========================

    model.train()

    runing_loss = 0.0
    conf_sums = init_confmat_sums()
    auc_buf = init_auc_buffers()

    for imgs, masks in train_loader :

        imgs = imgs.to(device)
        masks = masks.to(device)

        optimizer.zero_grad()

        outputs = model(imgs)

        alpha = alpha_cosine(epoch, EPOCHS, start=0.9, end=0.1)
        loss = alpha * CE_loss(outputs, masks) + (1-alpha) * dice_loss(outputs, masks)
        loss.backward()

        optimizer.step()
        scheduler.step()

        runing_loss += loss.item() * imgs.size(0)

        preds = outputs.argmax(dim=1)
        update_confmat_sums(conf_sums, preds, masks, NUM_CLASSES)
        update_auc_buffers(auc_buf, outputs, masks)
    
    train_loss = runing_loss / len(train_ds)
    train_metrics = compute_scalar_metrics_from_confmat(conf_sums, VESSEL_CLASSES)
    train_auc = compute_mean_auc(auc_buf)

    train_history["loss"].append(train_loss)
    train_history["accuracy"].append(train_metrics["accuracy"])
    train_history["dice"].append(train_metrics["dice"])
    train_history["iou"].append(train_metrics["iou"])
    train_history["precision"].append(train_metrics["precision"])
    train_history["recall"].append(train_metrics["recall"])
    train_history["specificity"].append(train_metrics["specificity"])
    train_history["auc"].append(train_auc)
    train_history["lr"].append(scheduler.get_last_lr()[0])
    train_history["alpha"].append(alpha)




    # =========================
    #       VALIDATION
    # =========================
    model.eval()

    val_runing_loss = 0.0
    conf_sums_val = init_confmat_sums()
    auc_buf_val   = init_auc_buffers()

    with torch.no_grad():
        for imgs, masks in val_loader:
            imgs  = imgs.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)

            outputs = model(imgs)

            loss = alpha * CE_loss(outputs, masks) + (1-alpha) * dice_loss(outputs, masks)

            val_runing_loss += loss.item() * imgs.size(0)

            preds = outputs.argmax(dim=1)
            update_confmat_sums(conf_sums_val, preds, masks, NUM_CLASSES)
            update_auc_buffers(auc_buf_val, outputs, masks)

    val_loss = val_runing_loss / len(val_ds)
    val_metrics = compute_scalar_metrics_from_confmat(conf_sums_val, VESSEL_CLASSES)
    val_auc = compute_mean_auc(auc_buf_val)

    val_history["loss"].append(val_loss)
    val_history["accuracy"].append(val_metrics["accuracy"])
    val_history["dice"].append(val_metrics["dice"])
    val_history["iou"].append(val_metrics["iou"])
    val_history["precision"].append(val_metrics["precision"])
    val_history["recall"].append(val_metrics["recall"])
    val_history["specificity"].append(val_metrics["specificity"])
    val_history["auc"].append(val_auc)




    # =========================
    #           LOGS
    # =========================
    print('-'*30)
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"  Train Loss: {train_loss:.4f} | Dice: {train_metrics['dice']:.4f} | IoU: {train_metrics['iou']:.4f}")
    print(f"  Val   Loss: {val_loss:.4f} | Dice: {val_metrics['dice']:.4f} | IoU: {val_metrics['iou']:.4f}")




    # =========================
    #     SAVE BEST MODEL
    # =========================
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), str(save_dir / "loss_best_model_state_dict.pth"))
        torch.save(model, str(save_dir / "loss_best_model_full.pth"))
        print(f"✅ Nouveau meilleur modèle loss sauvegardé")
    
    val_dice = val_metrics["dice"]
    if val_dice > best_val_dice :
        best_val_dice = val_dice
        torch.save(model.state_dict(), str(save_dir / "dice_best_model_state_dict.pth"))
        torch.save(model, str(save_dir / "dice_best_model_full.pth"))
        print(f"✅ Nouveau meilleur modèle dice sauvegardé")



# =========================
#     SAVE LAST MODEL
# =========================
torch.save(model.state_dict(), str(save_dir / f"epoch{EPOCHS}_model_state_dict.pth"))
torch.save(model, str(save_dir / f"epoch{EPOCHS}_model_full.pth"))
# Out:
# ------------------------------
# Epoch 1/500
#   Train Loss: 1.0790 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0791 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 2/500
#   Train Loss: 1.0789 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0790 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 3/500
#   Train Loss: 1.0789 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0790 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 4/500
#   Train Loss: 1.0789 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0789 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 5/500
#   Train Loss: 1.0788 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0789 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 6/500
#   Train Loss: 1.0787 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0788 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 7/500
#   Train Loss: 1.0786 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0788 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 8/500
#   Train Loss: 1.0783 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0787 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 9/500
#   Train Loss: 1.0784 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0787 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 10/500
#   Train Loss: 1.0783 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0786 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 11/500
#   Train Loss: 1.0782 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0785 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 12/500
#   Train Loss: 1.0783 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0784 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 13/500
#   Train Loss: 1.0780 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0784 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 14/500
#   Train Loss: 1.0781 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0783 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 15/500
#   Train Loss: 1.0780 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0782 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 16/500
#   Train Loss: 1.0778 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0781 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 17/500
#   Train Loss: 1.0777 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0780 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 18/500
#   Train Loss: 1.0776 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0779 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 19/500
#   Train Loss: 1.0774 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0777 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 20/500
#   Train Loss: 1.0774 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0776 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 21/500
#   Train Loss: 1.0772 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0775 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 22/500
#   Train Loss: 1.0770 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0774 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 23/500
#   Train Loss: 1.0769 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0772 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 24/500
#   Train Loss: 1.0767 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0771 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 25/500
#   Train Loss: 1.0766 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0769 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 26/500
#   Train Loss: 1.0764 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0768 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 27/500
#   Train Loss: 1.0762 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0766 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 28/500
#   Train Loss: 1.0759 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0764 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 29/500
#   Train Loss: 1.0758 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0763 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 30/500
#   Train Loss: 1.0756 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0761 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 31/500
#   Train Loss: 1.0754 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0759 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 32/500
#   Train Loss: 1.0751 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0757 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 33/500
#   Train Loss: 1.0748 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0754 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 34/500
#   Train Loss: 1.0746 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0752 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 35/500
#   Train Loss: 1.0742 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0750 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 36/500
#   Train Loss: 1.0740 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0747 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 37/500
#   Train Loss: 1.0737 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0744 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 38/500
#   Train Loss: 1.0734 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0741 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 39/500
#   Train Loss: 1.0730 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0738 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 40/500
#   Train Loss: 1.0726 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0735 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 41/500
#   Train Loss: 1.0722 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0732 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 42/500
#   Train Loss: 1.0718 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0728 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 43/500
#   Train Loss: 1.0713 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0724 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 44/500
#   Train Loss: 1.0708 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0720 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 45/500
#   Train Loss: 1.0702 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0715 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 46/500
#   Train Loss: 1.0696 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0710 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 47/500
#   Train Loss: 1.0691 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0706 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 48/500
#   Train Loss: 1.0684 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0701 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 49/500
#   Train Loss: 1.0677 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0696 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 50/500
#   Train Loss: 1.0671 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0690 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 51/500
#   Train Loss: 1.0664 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0685 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 52/500
#   Train Loss: 1.0657 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0679 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 53/500
#   Train Loss: 1.0648 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0672 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 54/500
#   Train Loss: 1.0640 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0665 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 55/500
#   Train Loss: 1.0630 | Dice: 0.0000 | IoU: 0.0000
#   Val   Loss: 1.0657 | Dice: 0.0000 | IoU: 0.0000
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 56/500
#   Train Loss: 1.0620 | Dice: 0.0001 | IoU: 0.0000
#   Val   Loss: 1.0649 | Dice: 0.0130 | IoU: 0.0066
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 57/500
#   Train Loss: 1.0608 | Dice: 0.0881 | IoU: 0.0483
#   Val   Loss: 1.0639 | Dice: 0.0981 | IoU: 0.0544
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 58/500
#   Train Loss: 1.0594 | Dice: 0.0952 | IoU: 0.0526
#   Val   Loss: 1.0628 | Dice: 0.0700 | IoU: 0.0376
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 59/500
#   Train Loss: 1.0576 | Dice: 0.0749 | IoU: 0.0405
#   Val   Loss: 1.0614 | Dice: 0.0645 | IoU: 0.0345
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 60/500
#   Train Loss: 1.0559 | Dice: 0.0698 | IoU: 0.0375
#   Val   Loss: 1.0596 | Dice: 0.0641 | IoU: 0.0343
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 61/500
#   Train Loss: 1.0521 | Dice: 0.0696 | IoU: 0.0374
#   Val   Loss: 1.0573 | Dice: 0.0641 | IoU: 0.0343
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 62/500
#   Train Loss: 1.0479 | Dice: 0.0695 | IoU: 0.0374
#   Val   Loss: 1.0596 | Dice: 0.0640 | IoU: 0.0342
# ------------------------------
# Epoch 63/500
#   Train Loss: 1.0492 | Dice: 0.0695 | IoU: 0.0373
#   Val   Loss: 1.0607 | Dice: 0.0640 | IoU: 0.0342
# ------------------------------
# Epoch 64/500
#   Train Loss: 1.0431 | Dice: 0.0695 | IoU: 0.0374
#   Val   Loss: 1.0551 | Dice: 0.0641 | IoU: 0.0342
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 65/500
#   Train Loss: 1.0405 | Dice: 0.0695 | IoU: 0.0374
#   Val   Loss: 1.0531 | Dice: 0.0642 | IoU: 0.0343
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 66/500
#   Train Loss: 1.0412 | Dice: 0.0697 | IoU: 0.0374
#   Val   Loss: 1.0524 | Dice: 0.0643 | IoU: 0.0344
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 67/500
#   Train Loss: 1.0408 | Dice: 0.0698 | IoU: 0.0375
#   Val   Loss: 1.0513 | Dice: 0.0644 | IoU: 0.0344
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 68/500
#   Train Loss: 1.0387 | Dice: 0.0698 | IoU: 0.0375
#   Val   Loss: 1.0504 | Dice: 0.0642 | IoU: 0.0343
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 69/500
#   Train Loss: 1.0357 | Dice: 0.0697 | IoU: 0.0375
#   Val   Loss: 1.0501 | Dice: 0.0642 | IoU: 0.0343
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 70/500
#   Train Loss: 1.0332 | Dice: 0.0697 | IoU: 0.0374
#   Val   Loss: 1.0497 | Dice: 0.0642 | IoU: 0.0343
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 71/500
#   Train Loss: 1.0310 | Dice: 0.0697 | IoU: 0.0375
#   Val   Loss: 1.0464 | Dice: 0.0644 | IoU: 0.0344
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 72/500
#   Train Loss: 1.0285 | Dice: 0.0700 | IoU: 0.0376
#   Val   Loss: 1.0440 | Dice: 0.0653 | IoU: 0.0349
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 73/500
#   Train Loss: 1.0255 | Dice: 0.0719 | IoU: 0.0388
#   Val   Loss: 1.0415 | Dice: 0.0676 | IoU: 0.0363
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 74/500
#   Train Loss: 1.0230 | Dice: 0.0738 | IoU: 0.0398
#   Val   Loss: 1.0437 | Dice: 0.0663 | IoU: 0.0355
# ------------------------------
# Epoch 75/500
#   Train Loss: 1.0224 | Dice: 0.0722 | IoU: 0.0389
#   Val   Loss: 1.0359 | Dice: 0.0744 | IoU: 0.0402
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 76/500
#   Train Loss: 1.0177 | Dice: 0.0862 | IoU: 0.0472
#   Val   Loss: 1.0341 | Dice: 0.0845 | IoU: 0.0462
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 77/500
#   Train Loss: 1.0180 | Dice: 0.0943 | IoU: 0.0520
#   Val   Loss: 1.0309 | Dice: 0.0767 | IoU: 0.0416
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 78/500
#   Train Loss: 1.0134 | Dice: 0.0842 | IoU: 0.0460
#   Val   Loss: 1.0302 | Dice: 0.0765 | IoU: 0.0414
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 79/500
#   Train Loss: 1.0095 | Dice: 0.0881 | IoU: 0.0483
#   Val   Loss: 1.0263 | Dice: 0.0893 | IoU: 0.0490
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 80/500
#   Train Loss: 1.0116 | Dice: 0.1011 | IoU: 0.0562
#   Val   Loss: 1.0233 | Dice: 0.0894 | IoU: 0.0491
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 81/500
#   Train Loss: 1.0064 | Dice: 0.0936 | IoU: 0.0516
#   Val   Loss: 1.0231 | Dice: 0.0804 | IoU: 0.0437
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 82/500
#   Train Loss: 1.0034 | Dice: 0.0927 | IoU: 0.0511
#   Val   Loss: 1.0178 | Dice: 0.0923 | IoU: 0.0508
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 83/500
#   Train Loss: 1.0012 | Dice: 0.1013 | IoU: 0.0564
#   Val   Loss: 1.0147 | Dice: 0.0920 | IoU: 0.0507
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 84/500
#   Train Loss: 0.9975 | Dice: 0.1032 | IoU: 0.0575
#   Val   Loss: 1.0121 | Dice: 0.0900 | IoU: 0.0494
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 85/500
#   Train Loss: 0.9981 | Dice: 0.0931 | IoU: 0.0513
#   Val   Loss: 1.0090 | Dice: 0.0911 | IoU: 0.0501
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 86/500
#   Train Loss: 0.9920 | Dice: 0.1047 | IoU: 0.0585
#   Val   Loss: 1.0050 | Dice: 0.0987 | IoU: 0.0548
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 87/500
#   Train Loss: 0.9871 | Dice: 0.1037 | IoU: 0.0579
#   Val   Loss: 1.0041 | Dice: 0.0870 | IoU: 0.0477
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 88/500
#   Train Loss: 0.9845 | Dice: 0.1005 | IoU: 0.0558
#   Val   Loss: 0.9973 | Dice: 0.1050 | IoU: 0.0587
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 89/500
#   Train Loss: 0.9808 | Dice: 0.1125 | IoU: 0.0634
#   Val   Loss: 0.9934 | Dice: 0.0943 | IoU: 0.0521
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 90/500
#   Train Loss: 0.9751 | Dice: 0.1022 | IoU: 0.0569
#   Val   Loss: 0.9869 | Dice: 0.1107 | IoU: 0.0623
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 91/500
#   Train Loss: 0.9715 | Dice: 0.1181 | IoU: 0.0669
#   Val   Loss: 0.9834 | Dice: 0.0953 | IoU: 0.0526
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 92/500
#   Train Loss: 0.9643 | Dice: 0.1038 | IoU: 0.0579
#   Val   Loss: 0.9852 | Dice: 0.1407 | IoU: 0.0818
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 93/500
#   Train Loss: 0.9644 | Dice: 0.1330 | IoU: 0.0767
#   Val   Loss: 1.0107 | Dice: 0.0664 | IoU: 0.0356
# ------------------------------
# Epoch 94/500
#   Train Loss: 0.9746 | Dice: 0.0879 | IoU: 0.0482
#   Val   Loss: 0.9719 | Dice: 0.1578 | IoU: 0.0937
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 95/500
#   Train Loss: 0.9524 | Dice: 0.1326 | IoU: 0.0764
#   Val   Loss: 0.9653 | Dice: 0.0957 | IoU: 0.0529
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 96/500
#   Train Loss: 0.9446 | Dice: 0.1090 | IoU: 0.0612
#   Val   Loss: 0.9572 | Dice: 0.1525 | IoU: 0.0899
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 97/500
#   Train Loss: 0.9380 | Dice: 0.1361 | IoU: 0.0788
#   Val   Loss: 0.9524 | Dice: 0.1048 | IoU: 0.0585
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 98/500
#   Train Loss: 0.9308 | Dice: 0.1200 | IoU: 0.0682
#   Val   Loss: 0.9356 | Dice: 0.1377 | IoU: 0.0799
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 99/500
#   Train Loss: 0.9158 | Dice: 0.1312 | IoU: 0.0755
#   Val   Loss: 0.9299 | Dice: 0.1650 | IoU: 0.0988
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 100/500
#   Train Loss: 0.9073 | Dice: 0.1488 | IoU: 0.0874
#   Val   Loss: 0.9288 | Dice: 0.1110 | IoU: 0.0624
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 101/500
#   Train Loss: 0.9051 | Dice: 0.1407 | IoU: 0.0818
#   Val   Loss: 0.9280 | Dice: 0.1087 | IoU: 0.0609
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 102/500
#   Train Loss: 0.8945 | Dice: 0.1369 | IoU: 0.0793
#   Val   Loss: 0.9003 | Dice: 0.1944 | IoU: 0.1207
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 103/500
#   Train Loss: 0.8895 | Dice: 0.1463 | IoU: 0.0857
#   Val   Loss: 0.8973 | Dice: 0.1455 | IoU: 0.0851
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 104/500
#   Train Loss: 0.8706 | Dice: 0.1690 | IoU: 0.1017
#   Val   Loss: 0.8927 | Dice: 0.1446 | IoU: 0.0845
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 105/500
#   Train Loss: 0.8551 | Dice: 0.1645 | IoU: 0.0984
#   Val   Loss: 0.9117 | Dice: 0.2314 | IoU: 0.1505
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 106/500
#   Train Loss: 0.8904 | Dice: 0.1521 | IoU: 0.0897
#   Val   Loss: 0.9008 | Dice: 0.2042 | IoU: 0.1283
# ------------------------------
# Epoch 107/500
#   Train Loss: 0.8550 | Dice: 0.1810 | IoU: 0.1105
#   Val   Loss: 0.8606 | Dice: 0.2094 | IoU: 0.1324
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 108/500
#   Train Loss: 0.8385 | Dice: 0.2023 | IoU: 0.1268
#   Val   Loss: 0.8658 | Dice: 0.1945 | IoU: 0.1207
# ------------------------------
# Epoch 109/500
#   Train Loss: 0.8310 | Dice: 0.1877 | IoU: 0.1155
#   Val   Loss: 0.8527 | Dice: 0.1910 | IoU: 0.1180
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 110/500
#   Train Loss: 0.8198 | Dice: 0.1889 | IoU: 0.1164
#   Val   Loss: 0.8720 | Dice: 0.1466 | IoU: 0.0859
# ------------------------------
# Epoch 111/500
#   Train Loss: 0.8411 | Dice: 0.1820 | IoU: 0.1113
#   Val   Loss: 1.1591 | Dice: 0.0686 | IoU: 0.0368
# ------------------------------
# Epoch 112/500
#   Train Loss: 0.9823 | Dice: 0.1064 | IoU: 0.0595
#   Val   Loss: 1.0294 | Dice: 0.2135 | IoU: 0.1357
# ------------------------------
# Epoch 113/500
#   Train Loss: 0.9390 | Dice: 0.1961 | IoU: 0.1218
#   Val   Loss: 0.9149 | Dice: 0.1135 | IoU: 0.0634
# ------------------------------
# Epoch 114/500
#   Train Loss: 0.8610 | Dice: 0.1487 | IoU: 0.0866
#   Val   Loss: 0.8717 | Dice: 0.2195 | IoU: 0.1402
# ------------------------------
# Epoch 115/500
#   Train Loss: 0.8465 | Dice: 0.1733 | IoU: 0.1042
#   Val   Loss: 0.8571 | Dice: 0.1702 | IoU: 0.1021
# ------------------------------
# Epoch 116/500
#   Train Loss: 0.8284 | Dice: 0.1852 | IoU: 0.1130
#   Val   Loss: 0.8535 | Dice: 0.1722 | IoU: 0.1035
# ------------------------------
# Epoch 117/500
#   Train Loss: 0.8321 | Dice: 0.1559 | IoU: 0.0918
#   Val   Loss: 0.8409 | Dice: 0.2059 | IoU: 0.1294
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 118/500
#   Train Loss: 0.8200 | Dice: 0.2009 | IoU: 0.1255
#   Val   Loss: 0.8390 | Dice: 0.2162 | IoU: 0.1379
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 119/500
#   Train Loss: 0.8185 | Dice: 0.2047 | IoU: 0.1287
#   Val   Loss: 0.8551 | Dice: 0.1657 | IoU: 0.0993
# ------------------------------
# Epoch 120/500
#   Train Loss: 0.8167 | Dice: 0.1685 | IoU: 0.1014
#   Val   Loss: 0.8707 | Dice: 0.2163 | IoU: 0.1380
# ------------------------------
# Epoch 121/500
#   Train Loss: 0.8178 | Dice: 0.2034 | IoU: 0.1277
#   Val   Loss: 0.8648 | Dice: 0.1511 | IoU: 0.0890
# ------------------------------
# Epoch 122/500
#   Train Loss: 0.8266 | Dice: 0.1689 | IoU: 0.1016
#   Val   Loss: 0.8244 | Dice: 0.2176 | IoU: 0.1390
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 123/500
#   Train Loss: 0.8202 | Dice: 0.1656 | IoU: 0.0992
#   Val   Loss: 0.8955 | Dice: 0.2228 | IoU: 0.1434
# ------------------------------
# Epoch 124/500
#   Train Loss: 0.8507 | Dice: 0.2210 | IoU: 0.1418
#   Val   Loss: 0.8509 | Dice: 0.1620 | IoU: 0.0964
# ------------------------------
# Epoch 125/500
#   Train Loss: 0.8246 | Dice: 0.1625 | IoU: 0.0965
#   Val   Loss: 0.8791 | Dice: 0.2343 | IoU: 0.1522
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 126/500
#   Train Loss: 0.8345 | Dice: 0.2073 | IoU: 0.1291
#   Val   Loss: 0.8253 | Dice: 0.2212 | IoU: 0.1387
# ------------------------------
# Epoch 127/500
#   Train Loss: 0.8065 | Dice: 0.2389 | IoU: 0.1513
#   Val   Loss: 0.8335 | Dice: 0.2041 | IoU: 0.1210
# ------------------------------
# Epoch 128/500
#   Train Loss: 0.8052 | Dice: 0.1999 | IoU: 0.1197
#   Val   Loss: 0.8706 | Dice: 0.2429 | IoU: 0.1563
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 129/500
#   Train Loss: 0.8233 | Dice: 0.2406 | IoU: 0.1522
#   Val   Loss: 0.8116 | Dice: 0.2287 | IoU: 0.1414
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 130/500
#   Train Loss: 0.7946 | Dice: 0.2395 | IoU: 0.1509
#   Val   Loss: 0.8160 | Dice: 0.2147 | IoU: 0.1304
# ------------------------------
# Epoch 131/500
#   Train Loss: 0.8020 | Dice: 0.1876 | IoU: 0.1123
#   Val   Loss: 0.8754 | Dice: 0.2536 | IoU: 0.1669
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 132/500
#   Train Loss: 0.8251 | Dice: 0.2449 | IoU: 0.1571
#   Val   Loss: 0.8275 | Dice: 0.2043 | IoU: 0.1222
# ------------------------------
# Epoch 133/500
#   Train Loss: 0.8004 | Dice: 0.2165 | IoU: 0.1332
#   Val   Loss: 0.8188 | Dice: 0.2160 | IoU: 0.1337
# ------------------------------
# Epoch 134/500
#   Train Loss: 0.7844 | Dice: 0.2075 | IoU: 0.1274
#   Val   Loss: 0.8119 | Dice: 0.2028 | IoU: 0.1243
# ------------------------------
# Epoch 135/500
#   Train Loss: 0.7885 | Dice: 0.2148 | IoU: 0.1348
#   Val   Loss: 0.8224 | Dice: 0.1937 | IoU: 0.1190
# ------------------------------
# Epoch 136/500
#   Train Loss: 0.8015 | Dice: 0.1701 | IoU: 0.1016
#   Val   Loss: 0.8675 | Dice: 0.2351 | IoU: 0.1527
# ------------------------------
# Epoch 137/500
#   Train Loss: 0.8123 | Dice: 0.2305 | IoU: 0.1471
#   Val   Loss: 0.8163 | Dice: 0.2138 | IoU: 0.1302
# ------------------------------
# Epoch 138/500
#   Train Loss: 0.7889 | Dice: 0.2247 | IoU: 0.1406
#   Val   Loss: 0.8317 | Dice: 0.2443 | IoU: 0.1566
# ------------------------------
# Epoch 139/500
#   Train Loss: 0.7802 | Dice: 0.2443 | IoU: 0.1542
#   Val   Loss: 0.8207 | Dice: 0.2038 | IoU: 0.1220
# ------------------------------
# Epoch 140/500
#   Train Loss: 0.7908 | Dice: 0.2190 | IoU: 0.1347
#   Val   Loss: 0.8127 | Dice: 0.2099 | IoU: 0.1267
# ------------------------------
# Epoch 141/500
#   Train Loss: 0.8097 | Dice: 0.2011 | IoU: 0.1232
#   Val   Loss: 0.9254 | Dice: 0.1335 | IoU: 0.0747
# ------------------------------
# Epoch 142/500
#   Train Loss: 0.8370 | Dice: 0.1584 | IoU: 0.0917
#   Val   Loss: 0.9098 | Dice: 0.2512 | IoU: 0.1622
# ------------------------------
# Epoch 143/500
#   Train Loss: 0.8453 | Dice: 0.2400 | IoU: 0.1497
#   Val   Loss: 0.8343 | Dice: 0.2522 | IoU: 0.1588
# ------------------------------
# Epoch 144/500
#   Train Loss: 0.8106 | Dice: 0.2716 | IoU: 0.1728
#   Val   Loss: 0.8230 | Dice: 0.2330 | IoU: 0.1415
# ------------------------------
# Epoch 145/500
#   Train Loss: 0.7874 | Dice: 0.2358 | IoU: 0.1440
#   Val   Loss: 0.8212 | Dice: 0.2213 | IoU: 0.1344
# ------------------------------
# Epoch 146/500
#   Train Loss: 0.7830 | Dice: 0.2242 | IoU: 0.1372
#   Val   Loss: 0.8322 | Dice: 0.2307 | IoU: 0.1461
# ------------------------------
# Epoch 147/500
#   Train Loss: 0.7850 | Dice: 0.2248 | IoU: 0.1397
#   Val   Loss: 0.8170 | Dice: 0.2095 | IoU: 0.1270
# ------------------------------
# Epoch 148/500
#   Train Loss: 0.7925 | Dice: 0.2072 | IoU: 0.1273
#   Val   Loss: 0.8215 | Dice: 0.2407 | IoU: 0.1541
# ------------------------------
# Epoch 149/500
#   Train Loss: 0.7844 | Dice: 0.2281 | IoU: 0.1429
#   Val   Loss: 0.8106 | Dice: 0.2295 | IoU: 0.1402
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 150/500
#   Train Loss: 0.7911 | Dice: 0.2550 | IoU: 0.1591
#   Val   Loss: 0.8006 | Dice: 0.2679 | IoU: 0.1649
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 151/500
#   Train Loss: 0.7749 | Dice: 0.2670 | IoU: 0.1636
#   Val   Loss: 0.8057 | Dice: 0.2881 | IoU: 0.1789
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 152/500
#   Train Loss: 0.7714 | Dice: 0.3064 | IoU: 0.1909
#   Val   Loss: 0.8063 | Dice: 0.2699 | IoU: 0.1649
# ------------------------------
# Epoch 153/500
#   Train Loss: 0.7818 | Dice: 0.2716 | IoU: 0.1700
#   Val   Loss: 0.8095 | Dice: 0.2772 | IoU: 0.1755
# ------------------------------
# Epoch 154/500
#   Train Loss: 0.7773 | Dice: 0.2495 | IoU: 0.1518
#   Val   Loss: 0.8094 | Dice: 0.2338 | IoU: 0.1426
# ------------------------------
# Epoch 155/500
#   Train Loss: 0.7725 | Dice: 0.2479 | IoU: 0.1541
#   Val   Loss: 0.7989 | Dice: 0.2575 | IoU: 0.1625
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 156/500
#   Train Loss: 0.7684 | Dice: 0.2603 | IoU: 0.1654
#   Val   Loss: 0.8360 | Dice: 0.2733 | IoU: 0.1758
# ------------------------------
# Epoch 157/500
#   Train Loss: 0.7873 | Dice: 0.2888 | IoU: 0.1830
#   Val   Loss: 0.8026 | Dice: 0.2653 | IoU: 0.1601
# ------------------------------
# Epoch 158/500
#   Train Loss: 0.7708 | Dice: 0.2615 | IoU: 0.1586
#   Val   Loss: 0.7963 | Dice: 0.3096 | IoU: 0.1959
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 159/500
#   Train Loss: 0.7735 | Dice: 0.3060 | IoU: 0.1936
#   Val   Loss: 0.8010 | Dice: 0.3079 | IoU: 0.1978
# ------------------------------
# Epoch 160/500
#   Train Loss: 0.7884 | Dice: 0.3146 | IoU: 0.2003
#   Val   Loss: 0.7928 | Dice: 0.2722 | IoU: 0.1669
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 161/500
#   Train Loss: 0.7594 | Dice: 0.2752 | IoU: 0.1694
#   Val   Loss: 0.7915 | Dice: 0.2926 | IoU: 0.1838
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 162/500
#   Train Loss: 0.7593 | Dice: 0.3161 | IoU: 0.2022
#   Val   Loss: 0.8204 | Dice: 0.2443 | IoU: 0.1467
# ------------------------------
# Epoch 163/500
#   Train Loss: 0.7832 | Dice: 0.2332 | IoU: 0.1417
#   Val   Loss: 0.8288 | Dice: 0.2636 | IoU: 0.1661
# ------------------------------
# Epoch 164/500
#   Train Loss: 0.7777 | Dice: 0.2424 | IoU: 0.1470
#   Val   Loss: 0.7925 | Dice: 0.2665 | IoU: 0.1646
# ------------------------------
# Epoch 165/500
#   Train Loss: 0.7594 | Dice: 0.2926 | IoU: 0.1850
#   Val   Loss: 0.8076 | Dice: 0.2626 | IoU: 0.1589
# ------------------------------
# Epoch 166/500
#   Train Loss: 0.7731 | Dice: 0.2578 | IoU: 0.1588
#   Val   Loss: 0.8962 | Dice: 0.2912 | IoU: 0.1862
# ------------------------------
# Epoch 167/500
#   Train Loss: 0.8157 | Dice: 0.3173 | IoU: 0.2009
#   Val   Loss: 0.8446 | Dice: 0.2205 | IoU: 0.1292
# ------------------------------
# Epoch 168/500
#   Train Loss: 0.7921 | Dice: 0.2238 | IoU: 0.1351
#   Val   Loss: 0.8313 | Dice: 0.3182 | IoU: 0.2078
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 169/500
#   Train Loss: 0.7945 | Dice: 0.3044 | IoU: 0.1918
#   Val   Loss: 0.8207 | Dice: 0.2738 | IoU: 0.1666
# ------------------------------
# Epoch 170/500
#   Train Loss: 0.7705 | Dice: 0.2975 | IoU: 0.1813
#   Val   Loss: 0.8128 | Dice: 0.2959 | IoU: 0.1816
# ------------------------------
# Epoch 171/500
#   Train Loss: 0.7709 | Dice: 0.3244 | IoU: 0.2022
#   Val   Loss: 0.8114 | Dice: 0.2940 | IoU: 0.1818
# ------------------------------
# Epoch 172/500
#   Train Loss: 0.7687 | Dice: 0.3162 | IoU: 0.1980
#   Val   Loss: 0.8122 | Dice: 0.2613 | IoU: 0.1582
# ------------------------------
# Epoch 173/500
#   Train Loss: 0.7709 | Dice: 0.2551 | IoU: 0.1551
#   Val   Loss: 0.8635 | Dice: 0.2583 | IoU: 0.1625
# ------------------------------
# Epoch 174/500
#   Train Loss: 0.7769 | Dice: 0.2808 | IoU: 0.1738
#   Val   Loss: 0.8081 | Dice: 0.2677 | IoU: 0.1616
# ------------------------------
# Epoch 175/500
#   Train Loss: 0.7651 | Dice: 0.2838 | IoU: 0.1764
#   Val   Loss: 0.8525 | Dice: 0.2988 | IoU: 0.1889
# ------------------------------
# Epoch 176/500
#   Train Loss: 0.7831 | Dice: 0.3138 | IoU: 0.1948
#   Val   Loss: 0.8152 | Dice: 0.2567 | IoU: 0.1522
# ------------------------------
# Epoch 177/500
#   Train Loss: 0.7665 | Dice: 0.2878 | IoU: 0.1763
#   Val   Loss: 0.7869 | Dice: 0.3259 | IoU: 0.2053
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 178/500
#   Train Loss: 0.7542 | Dice: 0.3460 | IoU: 0.2198
#   Val   Loss: 0.7856 | Dice: 0.2955 | IoU: 0.1813
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 179/500
#   Train Loss: 0.7601 | Dice: 0.3060 | IoU: 0.1897
#   Val   Loss: 0.7852 | Dice: 0.2933 | IoU: 0.1808
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 180/500
#   Train Loss: 0.7575 | Dice: 0.2861 | IoU: 0.1756
#   Val   Loss: 0.7780 | Dice: 0.3271 | IoU: 0.2059
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 181/500
#   Train Loss: 0.7514 | Dice: 0.3527 | IoU: 0.2240
#   Val   Loss: 0.7726 | Dice: 0.3179 | IoU: 0.1967
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 182/500
#   Train Loss: 0.7480 | Dice: 0.3184 | IoU: 0.1976
#   Val   Loss: 0.7924 | Dice: 0.3338 | IoU: 0.2110
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 183/500
#   Train Loss: 0.7524 | Dice: 0.3564 | IoU: 0.2259
#   Val   Loss: 0.7856 | Dice: 0.2998 | IoU: 0.1842
# ------------------------------
# Epoch 184/500
#   Train Loss: 0.7525 | Dice: 0.3141 | IoU: 0.1960
#   Val   Loss: 0.7752 | Dice: 0.3263 | IoU: 0.2054
# ------------------------------
# Epoch 185/500
#   Train Loss: 0.7466 | Dice: 0.3256 | IoU: 0.2042
#   Val   Loss: 0.7888 | Dice: 0.3263 | IoU: 0.2067
# ------------------------------
# Epoch 186/500
#   Train Loss: 0.7622 | Dice: 0.3468 | IoU: 0.2215
#   Val   Loss: 0.7718 | Dice: 0.3217 | IoU: 0.2019
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 187/500
#   Train Loss: 0.7505 | Dice: 0.3364 | IoU: 0.2114
#   Val   Loss: 0.7853 | Dice: 0.3140 | IoU: 0.1963
# ------------------------------
# Epoch 188/500
#   Train Loss: 0.7453 | Dice: 0.3469 | IoU: 0.2195
#   Val   Loss: 0.7750 | Dice: 0.3241 | IoU: 0.2018
# ------------------------------
# Epoch 189/500
#   Train Loss: 0.7430 | Dice: 0.3381 | IoU: 0.2120
#   Val   Loss: 0.7818 | Dice: 0.3295 | IoU: 0.2064
# ------------------------------
# Epoch 190/500
#   Train Loss: 0.7420 | Dice: 0.3512 | IoU: 0.2205
#   Val   Loss: 0.7730 | Dice: 0.3216 | IoU: 0.2004
# ------------------------------
# Epoch 191/500
#   Train Loss: 0.7433 | Dice: 0.3514 | IoU: 0.2245
#   Val   Loss: 0.7762 | Dice: 0.3344 | IoU: 0.2112
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 192/500
#   Train Loss: 0.7441 | Dice: 0.3523 | IoU: 0.2237
#   Val   Loss: 0.7830 | Dice: 0.3116 | IoU: 0.1944
# ------------------------------
# Epoch 193/500
#   Train Loss: 0.7527 | Dice: 0.3344 | IoU: 0.2085
#   Val   Loss: 0.7747 | Dice: 0.3113 | IoU: 0.1925
# ------------------------------
# Epoch 194/500
#   Train Loss: 0.7432 | Dice: 0.3315 | IoU: 0.2094
#   Val   Loss: 0.7987 | Dice: 0.3575 | IoU: 0.2278
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 195/500
#   Train Loss: 0.7643 | Dice: 0.3878 | IoU: 0.2481
#   Val   Loss: 0.7733 | Dice: 0.3339 | IoU: 0.2067
# ------------------------------
# Epoch 196/500
#   Train Loss: 0.7411 | Dice: 0.3545 | IoU: 0.2206
#   Val   Loss: 0.7724 | Dice: 0.3595 | IoU: 0.2266
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 197/500
#   Train Loss: 0.7370 | Dice: 0.3901 | IoU: 0.2499
#   Val   Loss: 0.7617 | Dice: 0.3391 | IoU: 0.2118
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 198/500
#   Train Loss: 0.7415 | Dice: 0.3403 | IoU: 0.2139
#   Val   Loss: 0.8072 | Dice: 0.3258 | IoU: 0.2044
# ------------------------------
# Epoch 199/500
#   Train Loss: 0.7506 | Dice: 0.3488 | IoU: 0.2205
#   Val   Loss: 0.8136 | Dice: 0.3214 | IoU: 0.2028
# ------------------------------
# Epoch 200/500
#   Train Loss: 0.7611 | Dice: 0.3612 | IoU: 0.2300
#   Val   Loss: 0.7902 | Dice: 0.2969 | IoU: 0.1806
# ------------------------------
# Epoch 201/500
#   Train Loss: 0.7439 | Dice: 0.3346 | IoU: 0.2088
#   Val   Loss: 0.7703 | Dice: 0.3582 | IoU: 0.2273
# ------------------------------
# Epoch 202/500
#   Train Loss: 0.7462 | Dice: 0.3793 | IoU: 0.2437
#   Val   Loss: 0.7918 | Dice: 0.3487 | IoU: 0.2197
# ------------------------------
# Epoch 203/500
#   Train Loss: 0.7553 | Dice: 0.3835 | IoU: 0.2443
#   Val   Loss: 0.7616 | Dice: 0.3388 | IoU: 0.2114
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 204/500
#   Train Loss: 0.7372 | Dice: 0.3502 | IoU: 0.2184
#   Val   Loss: 0.7658 | Dice: 0.3448 | IoU: 0.2161
# ------------------------------
# Epoch 205/500
#   Train Loss: 0.7375 | Dice: 0.3548 | IoU: 0.2234
#   Val   Loss: 0.7928 | Dice: 0.3600 | IoU: 0.2291
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 206/500
#   Train Loss: 0.7584 | Dice: 0.4007 | IoU: 0.2586
#   Val   Loss: 0.8258 | Dice: 0.2870 | IoU: 0.1733
# ------------------------------
# Epoch 207/500
#   Train Loss: 0.7640 | Dice: 0.3169 | IoU: 0.1950
#   Val   Loss: 0.8097 | Dice: 0.3313 | IoU: 0.2049
# ------------------------------
# Epoch 208/500
#   Train Loss: 0.7792 | Dice: 0.3352 | IoU: 0.2110
#   Val   Loss: 0.8136 | Dice: 0.3382 | IoU: 0.2100
# ------------------------------
# Epoch 209/500
#   Train Loss: 0.7550 | Dice: 0.3676 | IoU: 0.2311
#   Val   Loss: 0.8039 | Dice: 0.3278 | IoU: 0.2021
# ------------------------------
# Epoch 210/500
#   Train Loss: 0.7518 | Dice: 0.3724 | IoU: 0.2345
#   Val   Loss: 0.7921 | Dice: 0.3186 | IoU: 0.1966
# ------------------------------
# Epoch 211/500
#   Train Loss: 0.7688 | Dice: 0.3182 | IoU: 0.2006
#   Val   Loss: 0.8178 | Dice: 0.3375 | IoU: 0.2136
# ------------------------------
# Epoch 212/500
#   Train Loss: 0.7652 | Dice: 0.3448 | IoU: 0.2129
#   Val   Loss: 0.7932 | Dice: 0.3132 | IoU: 0.1919
# ------------------------------
# Epoch 213/500
#   Train Loss: 0.7585 | Dice: 0.3635 | IoU: 0.2283
#   Val   Loss: 0.7932 | Dice: 0.3085 | IoU: 0.1893
# ------------------------------
# Epoch 214/500
#   Train Loss: 0.7573 | Dice: 0.3300 | IoU: 0.2075
#   Val   Loss: 0.8015 | Dice: 0.3346 | IoU: 0.2086
# ------------------------------
# Epoch 215/500
#   Train Loss: 0.7552 | Dice: 0.3737 | IoU: 0.2354
#   Val   Loss: 0.7859 | Dice: 0.3106 | IoU: 0.1898
# ------------------------------
# Epoch 216/500
#   Train Loss: 0.7494 | Dice: 0.3134 | IoU: 0.1925
#   Val   Loss: 0.7792 | Dice: 0.3322 | IoU: 0.2078
# ------------------------------
# Epoch 217/500
#   Train Loss: 0.7382 | Dice: 0.3783 | IoU: 0.2413
#   Val   Loss: 0.7681 | Dice: 0.3371 | IoU: 0.2106
# ------------------------------
# Epoch 218/500
#   Train Loss: 0.7409 | Dice: 0.3506 | IoU: 0.2215
#   Val   Loss: 0.7657 | Dice: 0.3479 | IoU: 0.2189
# ------------------------------
# Epoch 219/500
#   Train Loss: 0.7401 | Dice: 0.3868 | IoU: 0.2471
#   Val   Loss: 0.7623 | Dice: 0.3419 | IoU: 0.2127
# ------------------------------
# Epoch 220/500
#   Train Loss: 0.7381 | Dice: 0.3531 | IoU: 0.2215
#   Val   Loss: 0.7596 | Dice: 0.3527 | IoU: 0.2206
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 221/500
#   Train Loss: 0.7311 | Dice: 0.3739 | IoU: 0.2351
#   Val   Loss: 0.7622 | Dice: 0.3448 | IoU: 0.2149
# ------------------------------
# Epoch 222/500
#   Train Loss: 0.7412 | Dice: 0.3535 | IoU: 0.2235
#   Val   Loss: 0.7637 | Dice: 0.3669 | IoU: 0.2331
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 223/500
#   Train Loss: 0.7340 | Dice: 0.4020 | IoU: 0.2591
#   Val   Loss: 0.7701 | Dice: 0.3220 | IoU: 0.1981
# ------------------------------
# Epoch 224/500
#   Train Loss: 0.7376 | Dice: 0.3378 | IoU: 0.2103
#   Val   Loss: 0.7781 | Dice: 0.3588 | IoU: 0.2273
# ------------------------------
# Epoch 225/500
#   Train Loss: 0.7418 | Dice: 0.4041 | IoU: 0.2611
#   Val   Loss: 0.7620 | Dice: 0.3457 | IoU: 0.2162
# ------------------------------
# Epoch 226/500
#   Train Loss: 0.7301 | Dice: 0.3728 | IoU: 0.2380
#   Val   Loss: 0.7617 | Dice: 0.3619 | IoU: 0.2272
# ------------------------------
# Epoch 227/500
#   Train Loss: 0.7281 | Dice: 0.3955 | IoU: 0.2513
#   Val   Loss: 0.7635 | Dice: 0.3500 | IoU: 0.2181
# ------------------------------
# Epoch 228/500
#   Train Loss: 0.7333 | Dice: 0.3787 | IoU: 0.2407
#   Val   Loss: 0.7525 | Dice: 0.3701 | IoU: 0.2336
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 229/500
#   Train Loss: 0.7256 | Dice: 0.3945 | IoU: 0.2537
#   Val   Loss: 0.7554 | Dice: 0.3604 | IoU: 0.2259
# ------------------------------
# Epoch 230/500
#   Train Loss: 0.7253 | Dice: 0.3838 | IoU: 0.2427
#   Val   Loss: 0.7541 | Dice: 0.3599 | IoU: 0.2263
# ------------------------------
# Epoch 231/500
#   Train Loss: 0.7228 | Dice: 0.3943 | IoU: 0.2535
#   Val   Loss: 0.7527 | Dice: 0.3693 | IoU: 0.2342
# ------------------------------
# Epoch 232/500
#   Train Loss: 0.7221 | Dice: 0.4025 | IoU: 0.2601
#   Val   Loss: 0.7546 | Dice: 0.3569 | IoU: 0.2229
# ------------------------------
# Epoch 233/500
#   Train Loss: 0.7241 | Dice: 0.3758 | IoU: 0.2363
#   Val   Loss: 0.7540 | Dice: 0.3630 | IoU: 0.2280
# ------------------------------
# Epoch 234/500
#   Train Loss: 0.7246 | Dice: 0.3986 | IoU: 0.2544
#   Val   Loss: 0.7529 | Dice: 0.3672 | IoU: 0.2321
# ------------------------------
# Epoch 235/500
#   Train Loss: 0.7243 | Dice: 0.4061 | IoU: 0.2631
#   Val   Loss: 0.7500 | Dice: 0.3744 | IoU: 0.2363
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 236/500
#   Train Loss: 0.7197 | Dice: 0.3975 | IoU: 0.2539
#   Val   Loss: 0.7582 | Dice: 0.3592 | IoU: 0.2251
# ------------------------------
# Epoch 237/500
#   Train Loss: 0.7203 | Dice: 0.3956 | IoU: 0.2521
#   Val   Loss: 0.7522 | Dice: 0.3708 | IoU: 0.2347
# ------------------------------
# Epoch 238/500
#   Train Loss: 0.7206 | Dice: 0.3960 | IoU: 0.2552
#   Val   Loss: 0.7622 | Dice: 0.3823 | IoU: 0.2419
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 239/500
#   Train Loss: 0.7251 | Dice: 0.4134 | IoU: 0.2664
#   Val   Loss: 0.7710 | Dice: 0.3609 | IoU: 0.2269
# ------------------------------
# Epoch 240/500
#   Train Loss: 0.7259 | Dice: 0.4123 | IoU: 0.2669
#   Val   Loss: 0.7554 | Dice: 0.3687 | IoU: 0.2325
# ------------------------------
# Epoch 241/500
#   Train Loss: 0.7262 | Dice: 0.3870 | IoU: 0.2483
#   Val   Loss: 0.7643 | Dice: 0.3829 | IoU: 0.2419
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 242/500
#   Train Loss: 0.7286 | Dice: 0.4105 | IoU: 0.2629
#   Val   Loss: 0.7531 | Dice: 0.3793 | IoU: 0.2395
# ------------------------------
# Epoch 243/500
#   Train Loss: 0.7203 | Dice: 0.4197 | IoU: 0.2711
#   Val   Loss: 0.7804 | Dice: 0.3497 | IoU: 0.2207
# ------------------------------
# Epoch 244/500
#   Train Loss: 0.7313 | Dice: 0.3767 | IoU: 0.2418
#   Val   Loss: 0.8254 | Dice: 0.3787 | IoU: 0.2394
# ------------------------------
# Epoch 245/500
#   Train Loss: 0.7473 | Dice: 0.4330 | IoU: 0.2819
#   Val   Loss: 0.8327 | Dice: 0.3071 | IoU: 0.1899
# ------------------------------
# Epoch 246/500
#   Train Loss: 0.7743 | Dice: 0.3193 | IoU: 0.2003
#   Val   Loss: 0.7956 | Dice: 0.3867 | IoU: 0.2451
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 247/500
#   Train Loss: 0.7453 | Dice: 0.4369 | IoU: 0.2836
#   Val   Loss: 0.7940 | Dice: 0.3281 | IoU: 0.2030
# ------------------------------
# Epoch 248/500
#   Train Loss: 0.7684 | Dice: 0.3130 | IoU: 0.1932
#   Val   Loss: 0.7619 | Dice: 0.3867 | IoU: 0.2468
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 249/500
#   Train Loss: 0.7432 | Dice: 0.4372 | IoU: 0.2871
#   Val   Loss: 0.7776 | Dice: 0.3712 | IoU: 0.2352
# ------------------------------
# Epoch 250/500
#   Train Loss: 0.7274 | Dice: 0.3968 | IoU: 0.2557
#   Val   Loss: 0.7782 | Dice: 0.3361 | IoU: 0.2095
# ------------------------------
# Epoch 251/500
#   Train Loss: 0.7333 | Dice: 0.3673 | IoU: 0.2333
#   Val   Loss: 0.7613 | Dice: 0.3954 | IoU: 0.2518
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 252/500
#   Train Loss: 0.7275 | Dice: 0.4352 | IoU: 0.2834
#   Val   Loss: 0.7818 | Dice: 0.3428 | IoU: 0.2145
# ------------------------------
# Epoch 253/500
#   Train Loss: 0.7350 | Dice: 0.3677 | IoU: 0.2345
#   Val   Loss: 0.8046 | Dice: 0.3671 | IoU: 0.2310
# ------------------------------
# Epoch 254/500
#   Train Loss: 0.7332 | Dice: 0.4261 | IoU: 0.2768
#   Val   Loss: 0.7628 | Dice: 0.3711 | IoU: 0.2334
# ------------------------------
# Epoch 255/500
#   Train Loss: 0.7221 | Dice: 0.3990 | IoU: 0.2543
#   Val   Loss: 0.7552 | Dice: 0.3792 | IoU: 0.2395
# ------------------------------
# Epoch 256/500
#   Train Loss: 0.7197 | Dice: 0.4178 | IoU: 0.2703
#   Val   Loss: 0.7473 | Dice: 0.4071 | IoU: 0.2611
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 257/500
#   Train Loss: 0.7210 | Dice: 0.4514 | IoU: 0.2973
#   Val   Loss: 0.7580 | Dice: 0.3759 | IoU: 0.2380
# ------------------------------
# Epoch 258/500
#   Train Loss: 0.7219 | Dice: 0.4054 | IoU: 0.2620
#   Val   Loss: 0.7633 | Dice: 0.3771 | IoU: 0.2378
# ------------------------------
# Epoch 259/500
#   Train Loss: 0.7176 | Dice: 0.4188 | IoU: 0.2703
#   Val   Loss: 0.7487 | Dice: 0.3938 | IoU: 0.2507
# ------------------------------
# Epoch 260/500
#   Train Loss: 0.7122 | Dice: 0.4319 | IoU: 0.2817
#   Val   Loss: 0.7499 | Dice: 0.3761 | IoU: 0.2385
# ------------------------------
# Epoch 261/500
#   Train Loss: 0.7152 | Dice: 0.4036 | IoU: 0.2613
#   Val   Loss: 0.7489 | Dice: 0.3926 | IoU: 0.2500
# ------------------------------
# Epoch 262/500
#   Train Loss: 0.7122 | Dice: 0.4336 | IoU: 0.2834
#   Val   Loss: 0.7519 | Dice: 0.3939 | IoU: 0.2511
# ------------------------------
# Epoch 263/500
#   Train Loss: 0.7162 | Dice: 0.4450 | IoU: 0.2917
#   Val   Loss: 0.7499 | Dice: 0.3854 | IoU: 0.2446
# ------------------------------
# Epoch 264/500
#   Train Loss: 0.7111 | Dice: 0.4097 | IoU: 0.2646
#   Val   Loss: 0.7438 | Dice: 0.4045 | IoU: 0.2587
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 265/500
#   Train Loss: 0.7152 | Dice: 0.4520 | IoU: 0.2971
#   Val   Loss: 0.7507 | Dice: 0.3825 | IoU: 0.2431
# ------------------------------
# Epoch 266/500
#   Train Loss: 0.7089 | Dice: 0.4117 | IoU: 0.2667
#   Val   Loss: 0.7445 | Dice: 0.3986 | IoU: 0.2547
# ------------------------------
# Epoch 267/500
#   Train Loss: 0.7063 | Dice: 0.4500 | IoU: 0.2965
#   Val   Loss: 0.7421 | Dice: 0.3955 | IoU: 0.2522
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 268/500
#   Train Loss: 0.7052 | Dice: 0.4183 | IoU: 0.2700
#   Val   Loss: 0.7497 | Dice: 0.3792 | IoU: 0.2401
# ------------------------------
# Epoch 269/500
#   Train Loss: 0.7058 | Dice: 0.4118 | IoU: 0.2646
#   Val   Loss: 0.7491 | Dice: 0.4102 | IoU: 0.2636
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 270/500
#   Train Loss: 0.7069 | Dice: 0.4507 | IoU: 0.2975
#   Val   Loss: 0.7514 | Dice: 0.3736 | IoU: 0.2368
# ------------------------------
# Epoch 271/500
#   Train Loss: 0.7091 | Dice: 0.4105 | IoU: 0.2656
#   Val   Loss: 0.7462 | Dice: 0.4057 | IoU: 0.2594
# ------------------------------
# Epoch 272/500
#   Train Loss: 0.7099 | Dice: 0.4551 | IoU: 0.2997
#   Val   Loss: 0.7465 | Dice: 0.3939 | IoU: 0.2534
# ------------------------------
# Epoch 273/500
#   Train Loss: 0.7052 | Dice: 0.4301 | IoU: 0.2830
#   Val   Loss: 0.7544 | Dice: 0.4066 | IoU: 0.2592
# ------------------------------
# Epoch 274/500
#   Train Loss: 0.7132 | Dice: 0.4539 | IoU: 0.2973
#   Val   Loss: 0.7665 | Dice: 0.3678 | IoU: 0.2332
# ------------------------------
# Epoch 275/500
#   Train Loss: 0.7138 | Dice: 0.4000 | IoU: 0.2593
#   Val   Loss: 0.8053 | Dice: 0.4046 | IoU: 0.2589
# ------------------------------
# Epoch 276/500
#   Train Loss: 0.7295 | Dice: 0.4675 | IoU: 0.3096
#   Val   Loss: 0.7560 | Dice: 0.3765 | IoU: 0.2375
# ------------------------------
# Epoch 277/500
#   Train Loss: 0.7317 | Dice: 0.3729 | IoU: 0.2373
#   Val   Loss: 0.7343 | Dice: 0.4033 | IoU: 0.2589
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 278/500
#   Train Loss: 0.7169 | Dice: 0.4469 | IoU: 0.2946
#   Val   Loss: 0.7524 | Dice: 0.3970 | IoU: 0.2553
# ------------------------------
# Epoch 279/500
#   Train Loss: 0.7124 | Dice: 0.4313 | IoU: 0.2838
#   Val   Loss: 0.7738 | Dice: 0.3867 | IoU: 0.2465
# ------------------------------
# Epoch 280/500
#   Train Loss: 0.7140 | Dice: 0.4389 | IoU: 0.2880
#   Val   Loss: 0.7433 | Dice: 0.3940 | IoU: 0.2514
# ------------------------------
# Epoch 281/500
#   Train Loss: 0.7032 | Dice: 0.4241 | IoU: 0.2744
#   Val   Loss: 0.7395 | Dice: 0.4000 | IoU: 0.2560
# ------------------------------
# Epoch 282/500
#   Train Loss: 0.7072 | Dice: 0.4309 | IoU: 0.2816
#   Val   Loss: 0.7347 | Dice: 0.4052 | IoU: 0.2604
# ------------------------------
# Epoch 283/500
#   Train Loss: 0.6999 | Dice: 0.4452 | IoU: 0.2931
#   Val   Loss: 0.7408 | Dice: 0.3841 | IoU: 0.2446
# ------------------------------
# Epoch 284/500
#   Train Loss: 0.7027 | Dice: 0.4201 | IoU: 0.2733
#   Val   Loss: 0.7341 | Dice: 0.4036 | IoU: 0.2586
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 285/500
# ...
#   Train Loss: 0.5149 | Dice: 0.6020 | IoU: 0.4373
#   Val   Loss: 0.7003 | Dice: 0.4581 | IoU: 0.3042
# ------------------------------
# Epoch 407/500
#   Train Loss: 0.5157 | Dice: 0.5962 | IoU: 0.4315
#   Val   Loss: 0.6995 | Dice: 0.4652 | IoU: 0.3087
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 408/500
#   Train Loss: 0.5149 | Dice: 0.6047 | IoU: 0.4399
#   Val   Loss: 0.7019 | Dice: 0.4552 | IoU: 0.3017
# ------------------------------
# Epoch 409/500
#   Train Loss: 0.5182 | Dice: 0.5908 | IoU: 0.4254
#   Val   Loss: 0.6997 | Dice: 0.4654 | IoU: 0.3090
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 410/500
#   Train Loss: 0.5154 | Dice: 0.6056 | IoU: 0.4408
#   Val   Loss: 0.7014 | Dice: 0.4600 | IoU: 0.3050
# ------------------------------
# Epoch 411/500
#   Train Loss: 0.5143 | Dice: 0.5934 | IoU: 0.4278
#   Val   Loss: 0.6992 | Dice: 0.4588 | IoU: 0.3038
# ------------------------------
# Epoch 412/500
#   Train Loss: 0.5114 | Dice: 0.6026 | IoU: 0.4378
#   Val   Loss: 0.7041 | Dice: 0.4643 | IoU: 0.3068
# ------------------------------
# Epoch 413/500
#   Train Loss: 0.5100 | Dice: 0.6050 | IoU: 0.4404
#   Val   Loss: 0.7027 | Dice: 0.4508 | IoU: 0.2986
# ------------------------------
# Epoch 414/500
#   Train Loss: 0.5146 | Dice: 0.5902 | IoU: 0.4249
#   Val   Loss: 0.6945 | Dice: 0.4674 | IoU: 0.3104
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 415/500
#   Train Loss: 0.5086 | Dice: 0.6100 | IoU: 0.4455
#   Val   Loss: 0.6946 | Dice: 0.4648 | IoU: 0.3084
# ------------------------------
# Epoch 416/500
#   Train Loss: 0.5035 | Dice: 0.6107 | IoU: 0.4458
#   Val   Loss: 0.6996 | Dice: 0.4586 | IoU: 0.3039
# ------------------------------
# Epoch 417/500
#   Train Loss: 0.5025 | Dice: 0.6099 | IoU: 0.4445
#   Val   Loss: 0.7006 | Dice: 0.4636 | IoU: 0.3071
# ------------------------------
# Epoch 418/500
#   Train Loss: 0.5046 | Dice: 0.6137 | IoU: 0.4489
#   Val   Loss: 0.6964 | Dice: 0.4613 | IoU: 0.3061
# ------------------------------
# Epoch 419/500
#   Train Loss: 0.5002 | Dice: 0.6094 | IoU: 0.4444
#   Val   Loss: 0.6946 | Dice: 0.4605 | IoU: 0.3054
# ------------------------------
# Epoch 420/500
#   Train Loss: 0.4971 | Dice: 0.6127 | IoU: 0.4479
#   Val   Loss: 0.6970 | Dice: 0.4622 | IoU: 0.3057
# ------------------------------
# Epoch 421/500
#   Train Loss: 0.4986 | Dice: 0.6135 | IoU: 0.4486
#   Val   Loss: 0.6992 | Dice: 0.4589 | IoU: 0.3038
# ------------------------------
# Epoch 422/500
#   Train Loss: 0.4966 | Dice: 0.6120 | IoU: 0.4467
#   Val   Loss: 0.6984 | Dice: 0.4612 | IoU: 0.3058
# ------------------------------
# Epoch 423/500
#   Train Loss: 0.4953 | Dice: 0.6163 | IoU: 0.4515
#   Val   Loss: 0.6934 | Dice: 0.4639 | IoU: 0.3077
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 424/500
#   Train Loss: 0.4922 | Dice: 0.6177 | IoU: 0.4528
#   Val   Loss: 0.6893 | Dice: 0.4567 | IoU: 0.3029
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 425/500
#   Train Loss: 0.4964 | Dice: 0.6089 | IoU: 0.4433
#   Val   Loss: 0.6853 | Dice: 0.4650 | IoU: 0.3091
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 426/500
#   Train Loss: 0.4920 | Dice: 0.6183 | IoU: 0.4537
#   Val   Loss: 0.6885 | Dice: 0.4669 | IoU: 0.3103
# ------------------------------
# Epoch 427/500
#   Train Loss: 0.4921 | Dice: 0.6184 | IoU: 0.4537
#   Val   Loss: 0.6904 | Dice: 0.4630 | IoU: 0.3074
# ------------------------------
# Epoch 428/500
#   Train Loss: 0.4891 | Dice: 0.6190 | IoU: 0.4539
#   Val   Loss: 0.6953 | Dice: 0.4623 | IoU: 0.3059
# ------------------------------
# Epoch 429/500
#   Train Loss: 0.4896 | Dice: 0.6190 | IoU: 0.4539
#   Val   Loss: 0.6942 | Dice: 0.4608 | IoU: 0.3052
# ------------------------------
# Epoch 430/500
#   Train Loss: 0.4868 | Dice: 0.6203 | IoU: 0.4555
#   Val   Loss: 0.6905 | Dice: 0.4623 | IoU: 0.3068
# ------------------------------
# Epoch 431/500
#   Train Loss: 0.4863 | Dice: 0.6198 | IoU: 0.4552
#   Val   Loss: 0.6873 | Dice: 0.4643 | IoU: 0.3081
# ------------------------------
# Epoch 432/500
#   Train Loss: 0.4850 | Dice: 0.6211 | IoU: 0.4567
#   Val   Loss: 0.6882 | Dice: 0.4645 | IoU: 0.3082
# ------------------------------
# Epoch 433/500
#   Train Loss: 0.4832 | Dice: 0.6225 | IoU: 0.4579
#   Val   Loss: 0.6904 | Dice: 0.4640 | IoU: 0.3080
# ------------------------------
# Epoch 434/500
#   Train Loss: 0.4830 | Dice: 0.6238 | IoU: 0.4590
#   Val   Loss: 0.6895 | Dice: 0.4651 | IoU: 0.3090
# ------------------------------
# Epoch 435/500
#   Train Loss: 0.4830 | Dice: 0.6256 | IoU: 0.4610
#   Val   Loss: 0.6877 | Dice: 0.4648 | IoU: 0.3087
# ------------------------------
# Epoch 436/500
#   Train Loss: 0.4814 | Dice: 0.6253 | IoU: 0.4605
#   Val   Loss: 0.6856 | Dice: 0.4622 | IoU: 0.3067
# ------------------------------
# Epoch 437/500
#   Train Loss: 0.4795 | Dice: 0.6238 | IoU: 0.4587
#   Val   Loss: 0.6845 | Dice: 0.4621 | IoU: 0.3064
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 438/500
#   Train Loss: 0.4794 | Dice: 0.6252 | IoU: 0.4604
#   Val   Loss: 0.6849 | Dice: 0.4638 | IoU: 0.3075
# ------------------------------
# Epoch 439/500
#   Train Loss: 0.4786 | Dice: 0.6264 | IoU: 0.4618
#   Val   Loss: 0.6847 | Dice: 0.4645 | IoU: 0.3083
# ------------------------------
# Epoch 440/500
#   Train Loss: 0.4778 | Dice: 0.6253 | IoU: 0.4606
#   Val   Loss: 0.6811 | Dice: 0.4647 | IoU: 0.3090
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 441/500
#   Train Loss: 0.4774 | Dice: 0.6260 | IoU: 0.4614
#   Val   Loss: 0.6800 | Dice: 0.4655 | IoU: 0.3092
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 442/500
#   Train Loss: 0.4781 | Dice: 0.6267 | IoU: 0.4624
#   Val   Loss: 0.6802 | Dice: 0.4644 | IoU: 0.3084
# ------------------------------
# Epoch 443/500
#   Train Loss: 0.4757 | Dice: 0.6268 | IoU: 0.4623
#   Val   Loss: 0.6817 | Dice: 0.4638 | IoU: 0.3080
# ------------------------------
# Epoch 444/500
#   Train Loss: 0.4751 | Dice: 0.6279 | IoU: 0.4633
#   Val   Loss: 0.6836 | Dice: 0.4656 | IoU: 0.3090
# ------------------------------
# Epoch 445/500
#   Train Loss: 0.4741 | Dice: 0.6301 | IoU: 0.4657
#   Val   Loss: 0.6813 | Dice: 0.4658 | IoU: 0.3092
# ------------------------------
# Epoch 446/500
#   Train Loss: 0.4726 | Dice: 0.6301 | IoU: 0.4656
#   Val   Loss: 0.6779 | Dice: 0.4640 | IoU: 0.3083
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 447/500
#   Train Loss: 0.4726 | Dice: 0.6274 | IoU: 0.4627
#   Val   Loss: 0.6771 | Dice: 0.4642 | IoU: 0.3084
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 448/500
#   Train Loss: 0.4721 | Dice: 0.6288 | IoU: 0.4643
#   Val   Loss: 0.6786 | Dice: 0.4652 | IoU: 0.3088
# ------------------------------
# Epoch 449/500
#   Train Loss: 0.4723 | Dice: 0.6308 | IoU: 0.4665
#   Val   Loss: 0.6800 | Dice: 0.4642 | IoU: 0.3080
# ------------------------------
# Epoch 450/500
#   Train Loss: 0.4708 | Dice: 0.6315 | IoU: 0.4669
#   Val   Loss: 0.6820 | Dice: 0.4631 | IoU: 0.3071
# ------------------------------
# Epoch 451/500
#   Train Loss: 0.4708 | Dice: 0.6316 | IoU: 0.4667
#   Val   Loss: 0.6829 | Dice: 0.4644 | IoU: 0.3079
# ------------------------------
# Epoch 452/500
#   Train Loss: 0.4698 | Dice: 0.6328 | IoU: 0.4681
#   Val   Loss: 0.6806 | Dice: 0.4650 | IoU: 0.3085
# ------------------------------
# Epoch 453/500
#   Train Loss: 0.4686 | Dice: 0.6334 | IoU: 0.4690
#   Val   Loss: 0.6776 | Dice: 0.4651 | IoU: 0.3088
# ------------------------------
# Epoch 454/500
#   Train Loss: 0.4675 | Dice: 0.6336 | IoU: 0.4692
#   Val   Loss: 0.6754 | Dice: 0.4648 | IoU: 0.3087
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 455/500
#   Train Loss: 0.4671 | Dice: 0.6327 | IoU: 0.4683
#   Val   Loss: 0.6741 | Dice: 0.4643 | IoU: 0.3083
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 456/500
#   Train Loss: 0.4668 | Dice: 0.6324 | IoU: 0.4680
#   Val   Loss: 0.6739 | Dice: 0.4647 | IoU: 0.3084
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 457/500
#   Train Loss: 0.4661 | Dice: 0.6331 | IoU: 0.4688
#   Val   Loss: 0.6746 | Dice: 0.4651 | IoU: 0.3087
# ------------------------------
# Epoch 458/500
#   Train Loss: 0.4655 | Dice: 0.6341 | IoU: 0.4699
#   Val   Loss: 0.6756 | Dice: 0.4648 | IoU: 0.3085
# ------------------------------
# Epoch 459/500
#   Train Loss: 0.4641 | Dice: 0.6339 | IoU: 0.4695
#   Val   Loss: 0.6760 | Dice: 0.4646 | IoU: 0.3085
# ------------------------------
# Epoch 460/500
#   Train Loss: 0.4651 | Dice: 0.6340 | IoU: 0.4695
#   Val   Loss: 0.6754 | Dice: 0.4651 | IoU: 0.3088
# ------------------------------
# Epoch 461/500
#   Train Loss: 0.4661 | Dice: 0.6353 | IoU: 0.4710
#   Val   Loss: 0.6741 | Dice: 0.4654 | IoU: 0.3090
# ------------------------------
# Epoch 462/500
#   Train Loss: 0.4653 | Dice: 0.6358 | IoU: 0.4716
#   Val   Loss: 0.6728 | Dice: 0.4654 | IoU: 0.3090
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 463/500
#   Train Loss: 0.4630 | Dice: 0.6360 | IoU: 0.4718
#   Val   Loss: 0.6721 | Dice: 0.4649 | IoU: 0.3088
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 464/500
#   Train Loss: 0.4618 | Dice: 0.6361 | IoU: 0.4718
#   Val   Loss: 0.6715 | Dice: 0.4649 | IoU: 0.3088
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 465/500
#   Train Loss: 0.4624 | Dice: 0.6363 | IoU: 0.4720
#   Val   Loss: 0.6708 | Dice: 0.4654 | IoU: 0.3092
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 466/500
#   Train Loss: 0.4616 | Dice: 0.6366 | IoU: 0.4724
#   Val   Loss: 0.6702 | Dice: 0.4660 | IoU: 0.3096
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 467/500
#   Train Loss: 0.4613 | Dice: 0.6369 | IoU: 0.4727
#   Val   Loss: 0.6692 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 468/500
#   Train Loss: 0.4616 | Dice: 0.6369 | IoU: 0.4728
#   Val   Loss: 0.6686 | Dice: 0.4661 | IoU: 0.3098
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 469/500
#   Train Loss: 0.4611 | Dice: 0.6372 | IoU: 0.4730
#   Val   Loss: 0.6684 | Dice: 0.4663 | IoU: 0.3099
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 470/500
#   Train Loss: 0.4605 | Dice: 0.6375 | IoU: 0.4734
#   Val   Loss: 0.6682 | Dice: 0.4663 | IoU: 0.3099
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 471/500
#   Train Loss: 0.4599 | Dice: 0.6376 | IoU: 0.4734
#   Val   Loss: 0.6679 | Dice: 0.4660 | IoU: 0.3096
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 472/500
#   Train Loss: 0.4608 | Dice: 0.6377 | IoU: 0.4735
#   Val   Loss: 0.6674 | Dice: 0.4659 | IoU: 0.3096
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 473/500
#   Train Loss: 0.4593 | Dice: 0.6377 | IoU: 0.4736
#   Val   Loss: 0.6670 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 474/500
#   Train Loss: 0.4588 | Dice: 0.6378 | IoU: 0.4736
#   Val   Loss: 0.6665 | Dice: 0.4662 | IoU: 0.3098
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 475/500
#   Train Loss: 0.4587 | Dice: 0.6379 | IoU: 0.4737
#   Val   Loss: 0.6661 | Dice: 0.4663 | IoU: 0.3099
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 476/500
#   Train Loss: 0.4599 | Dice: 0.6380 | IoU: 0.4738
#   Val   Loss: 0.6658 | Dice: 0.4663 | IoU: 0.3099
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 477/500
#   Train Loss: 0.4588 | Dice: 0.6381 | IoU: 0.4740
#   Val   Loss: 0.6655 | Dice: 0.4663 | IoU: 0.3098
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 478/500
#   Train Loss: 0.4585 | Dice: 0.6381 | IoU: 0.4740
#   Val   Loss: 0.6651 | Dice: 0.4662 | IoU: 0.3098
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 479/500
#   Train Loss: 0.4574 | Dice: 0.6382 | IoU: 0.4741
#   Val   Loss: 0.6646 | Dice: 0.4660 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 480/500
#   Train Loss: 0.4588 | Dice: 0.6380 | IoU: 0.4738
#   Val   Loss: 0.6641 | Dice: 0.4659 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 481/500
#   Train Loss: 0.4582 | Dice: 0.6379 | IoU: 0.4737
#   Val   Loss: 0.6638 | Dice: 0.4660 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 482/500
#   Train Loss: 0.4573 | Dice: 0.6380 | IoU: 0.4738
#   Val   Loss: 0.6636 | Dice: 0.4662 | IoU: 0.3098
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 483/500
#   Train Loss: 0.4579 | Dice: 0.6381 | IoU: 0.4740
#   Val   Loss: 0.6635 | Dice: 0.4665 | IoU: 0.3100
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 484/500
#   Train Loss: 0.4569 | Dice: 0.6383 | IoU: 0.4742
#   Val   Loss: 0.6634 | Dice: 0.4666 | IoU: 0.3100
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 485/500
#   Train Loss: 0.4570 | Dice: 0.6384 | IoU: 0.4743
#   Val   Loss: 0.6632 | Dice: 0.4665 | IoU: 0.3100
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 486/500
#   Train Loss: 0.4567 | Dice: 0.6384 | IoU: 0.4743
#   Val   Loss: 0.6630 | Dice: 0.4664 | IoU: 0.3099
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 487/500
#   Train Loss: 0.4573 | Dice: 0.6384 | IoU: 0.4743
#   Val   Loss: 0.6627 | Dice: 0.4662 | IoU: 0.3098
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 488/500
#   Train Loss: 0.4568 | Dice: 0.6383 | IoU: 0.4742
#   Val   Loss: 0.6625 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 489/500
#   Train Loss: 0.4568 | Dice: 0.6383 | IoU: 0.4741
#   Val   Loss: 0.6623 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 490/500
#   Train Loss: 0.4567 | Dice: 0.6382 | IoU: 0.4741
#   Val   Loss: 0.6620 | Dice: 0.4660 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 491/500
#   Train Loss: 0.4562 | Dice: 0.6382 | IoU: 0.4740
#   Val   Loss: 0.6619 | Dice: 0.4660 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 492/500
#   Train Loss: 0.4560 | Dice: 0.6382 | IoU: 0.4741
#   Val   Loss: 0.6617 | Dice: 0.4660 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 493/500
#   Train Loss: 0.4564 | Dice: 0.6382 | IoU: 0.4741
#   Val   Loss: 0.6616 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 494/500
#   Train Loss: 0.4562 | Dice: 0.6382 | IoU: 0.4741
#   Val   Loss: 0.6615 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 495/500
#   Train Loss: 0.4573 | Dice: 0.6382 | IoU: 0.4741
#   Val   Loss: 0.6614 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 496/500
#   Train Loss: 0.4560 | Dice: 0.6383 | IoU: 0.4741
#   Val   Loss: 0.6613 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 497/500
#   Train Loss: 0.4563 | Dice: 0.6383 | IoU: 0.4741
#   Val   Loss: 0.6613 | Dice: 0.4662 | IoU: 0.3098
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 498/500
#   Train Loss: 0.4552 | Dice: 0.6383 | IoU: 0.4741
#   Val   Loss: 0.6612 | Dice: 0.4661 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 499/500
#   Train Loss: 0.4566 | Dice: 0.6383 | IoU: 0.4741
#   Val   Loss: 0.6612 | Dice: 0.4662 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 500/500
#   Train Loss: 0.4571 | Dice: 0.6383 | IoU: 0.4741
#   Val   Loss: 0.6612 | Dice: 0.4662 | IoU: 0.3097
# ✅ Nouveau meilleur modèle loss sauvegardé

# %%
with open(save_dir / "UNet_alpha_cosine_v1_train_history.json", "w") as f:
    json.dump(train_history, f, indent=4)

with open(save_dir / "UNet_alpha_cosine_v1_val_history.json", "w") as f:
    json.dump(val_history, f, indent=4)

print("Historiques sauvegardés en JSON")
# Out:
# Historiques sauvegardés en JSON

# %% [markdown]
# # Validation tests

# %% [markdown]
# #### Load the best model

# %%
model = torch.load(save_dir / "loss_best_model_full.pth")
# Out:
# /tmp/ipykernel_2926046/448777230.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(save_dir / "dice_best_model_full.pth")

# %% [markdown]
# #### Images

# %%
model.eval()
total_correct = 0
total_pixels = 0

# 📁 Dossier pour sauvegarder les prédictions
pred_dir = save_dir / "predictions"
pred_dir.mkdir(parents=True, exist_ok=True)

with torch.no_grad():
    img_index = 0  # compteur global des images

    for imgs, masks in val_loader:
        imgs = imgs.to(device)
        masks = masks.to(device)

        outputs = model(imgs)
        preds = torch.argmax(F.softmax(outputs, dim=1), dim=1)

        # Boucle sur chaque image du batch
        for i in range(len(imgs)):
            pred = preds[i]
            mask = masks[i]

            # ===== Calcul de l’accuracy de cette image =====
            correct_pixels = (pred == mask).sum().item()
            total_pixels_img = mask.numel()
            acc_img = correct_pixels / total_pixels_img

            print(f"🖼️ Image {img_index+1} — Accuracy : {acc_img:.4f}")

            # ===== Création de la figure =====
            fig, ax = plt.subplots(1, 3, figsize=(10, 4))
            ax[0].imshow(imgs[i].cpu().permute(1, 2, 0))
            ax[0].set_title("Original picture")
            ax[1].imshow(mask.cpu(), cmap="gray")
            ax[1].set_title("Real mask")
            ax[2].imshow(pred.cpu(), cmap="gray")
            ax[2].set_title("Predicted mask")
            for a in ax:
                a.axis("off")
            plt.tight_layout()

            # 📌 Sauvegarde dans Models/<model_name>/predictions/
            save_path = pred_dir / f"val_img_{img_index:03d}.png"
            plt.savefig(save_path, dpi=150, bbox_inches='tight')

            # ✅ Affichage immédiat dans notebook
            plt.show()

            # ===== Accumulateur global =====
            total_correct += correct_pixels
            total_pixels += total_pixels_img
            img_index += 1

# ===== Accuracy globale =====
val_acc = total_correct / total_pixels
print(f"\n✅ Accuracy moyenne sur le jeu de validation : {val_acc:.4f}")
# Out:
# 🖼️ Image 1 — Accuracy : 0.9145
# 🖼️ Image 2 — Accuracy : 0.9027
# 🖼️ Image 3 — Accuracy : 0.8770
# 🖼️ Image 4 — Accuracy : 0.8916
# 🖼️ Image 5 — Accuracy : 0.8325
# ✅ Accuracy moyenne sur le jeu de validation : 0.8837

# %% [markdown]
# #### Curves

# %%
# --- Création du dossier d'enregistrement ---
curves_dir = save_dir / "curves"
curves_dir.mkdir(parents=True, exist_ok=True)

# %%
def plot_metric(train_history, val_history, key, title=None, mark_best_on="val_loss", save_folder=curves_dir):
    """
    key:        nom de la métrique dans les dicts (ex: "loss", "dice", "auc")
    mark_best_on:
        - "val_loss" → marquer l'epoch où val_loss est minimal
        - "val_<key>" → marquer la meilleure valeur de cette métrique (max)
    """

    train = train_history.get(key, [])
    val   = val_history.get(key, [])

    if len(val) == 0:
        print(f"⚠️ Impossible de tracer '{key}' (pas de valeurs validation trouvées)")
        return

    epochs = range(1, len(val)+1)

    plt.figure(figsize=(7,5))
    plt.plot(epochs, train, label=f"Train {key}", linewidth=2)
    plt.plot(epochs, val,   label=f"Val {key}", linewidth=2)

    # ========= Marqueur du "best" =========
    if mark_best_on == "val_loss" and "loss" in val_history:
        best_e = int(np.argmin(val_history["loss"])) + 1
        best_v = val[best_e-1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")
    elif mark_best_on == f"val_{key}" and len(val) > 0:
        best_e = int(np.nanargmax(val)) + 1
        best_v = val[best_e-1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")

    plt.xlabel("Epoch")
    plt.ylabel(key)
    plt.title(title or f"{key} (train vs val)")
    plt.grid(True)
    plt.legend()

    # ========= SAVE =========
    save_path = save_folder / f"{key}.png"
    plt.savefig(save_path, dpi=200, bbox_inches="tight")
    print(f"💾 Courbe sauvegardée : {save_path}")

    plt.show()   # continue à afficher


# ======== TRAÇAGE ========

plot_metric(train_history, val_history, "loss", title="Loss curves", mark_best_on="val_loss")
plot_metric(train_history, val_history, "dice", title="Dice (artery+vein avg)", mark_best_on="val_dice")
plot_metric(train_history, val_history, "auc",  title="AUC (artery+vein avg)",  mark_best_on="val_auc")
# Out:
# 💾 Courbe sauvegardée : Models/My_UNet_alpha_random/curves/loss.png
# 💾 Courbe sauvegardée : Models/My_UNet_alpha_random/curves/dice.png
# 💾 Courbe sauvegardée : Models/My_UNet_alpha_random/curves/auc.png

# %%
alpha_values = train_history.get("alpha", [])
lr_values = train_history.get("lr", [])
epochs = np.arange(1, len(alpha_values) + 1)


# =========================
#   COURBE ALPHA(t)
# =========================
fig_alpha, ax = plt.subplots(figsize=(8, 5))
ax.plot(epochs, alpha_values, color="#1f77b4", linewidth=2)
ax.set_title("Evolution of α in Loss = α * CE + (1-α)*DiceLoss")
ax.set_xlabel("Epoch", fontsize=11)
ax.set_ylabel("α value", fontsize=11)
ax.grid(alpha=0.4)
ax.legend(["α(t) schedule"], loc="best")
plt.tight_layout()

alpha_path = curves_dir / "alpha_curve.png"
plt.savefig(alpha_path, dpi=200, bbox_inches='tight')
print(f"✅ Courbe α(t) sauvegardée dans : {alpha_path}")

plt.show()



# =========================
#   COURBE LEARNING RATE
# =========================
fig_lr, ax = plt.subplots(figsize=(8, 5))
ax.plot(epochs, lr_values, color="#ff7f0e", linewidth=2)
ax.set_title("Learning Rate Schedule")
ax.set_xlabel("Epoch", fontsize=11)
ax.set_ylabel("Learning rate", fontsize=11)
ax.grid(alpha=0.4)
ax.legend(["lr(t)"], loc="best")
plt.tight_layout()

lr_path = curves_dir / "lr_curve.png"
plt.savefig(lr_path, dpi=200, bbox_inches='tight')
print(f"✅ Courbe learning rate sauvegardée dans : {lr_path}")

plt.show()
# Out:
# ✅ Courbe α(t) sauvegardée dans : Models/My_UNet_alpha_random/curves/alpha_curve.png
# ✅ Courbe learning rate sauvegardée dans : Models/My_UNet_alpha_random/curves/lr_curve.png

# %% [markdown]
# #### Summary of the metrics

# %%
# =========================
#   CONFIG CLASSES
# =========================
ARTERY_CLASS = 1
VEIN_CLASS   = 2
VESSEL_CLASSES = [ARTERY_CLASS, VEIN_CLASS]
assert NUM_CLASSES >= 3, "NUM_CLASSES doit inclure background + artery + vein"


# =========================
#  UTILS: métriques par classe
# =========================
def compute_per_class_metrics_from_confmat(sums, c):
    TP, FP, FN, TN = sums["TP"][c], sums["FP"][c], sums["FN"][c], sums["TN"][c]
    eps = 1e-7

    acc  = (TP + TN) / max(TP + TN + FP + FN, eps)
    prec = TP / max(TP + FP, eps)
    rec  = TP / max(TP + FN, eps)
    spec = TN / max(TN + FP, eps)
    dice = (2 * TP) / max(2 * TP + FP + FN, eps)
    iou  = TP / max(TP + FP + FN, eps)

    return {
        "accuracy":   float(acc),
        "precision":  float(prec),
        "recall":     float(rec),      # Sensitivity
        "specificity":float(spec),
        "dice":       float(dice),
        "iou":        float(iou),
    }

def compute_auc_for_class(buffers, c):
    pack = buffers.get(c, None)
    if pack is None or len(pack["y_true"]) == 0:
        return float("nan")

    y_true  = np.concatenate(pack["y_true"])
    y_score = np.concatenate(pack["y_score"])

    pos = (y_true == 1).sum()
    neg = (y_true == 0).sum()
    if pos == 0 or neg == 0:
        return float("nan")

    try:
        return float(roc_auc_score(y_true, y_score))
    except:
        return float("nan")


# =========================
#   ÉVALUATION
# =========================
model.eval()
conf_sums_val = init_confmat_sums(num_classes=NUM_CLASSES)
auc_buf_val   = init_auc_buffers(include_classes=VESSEL_CLASSES)

with torch.no_grad():
    for imgs, masks in val_loader:
        imgs  = imgs.to(device)
        masks = masks.to(device)

        outputs = model(imgs)
        preds = outputs.argmax(dim=1)

        update_confmat_sums(conf_sums_val, preds, masks, NUM_CLASSES)
        update_auc_buffers(auc_buf_val, outputs, masks)


# =========================
#   MÉTRIQUES PAR CLASSE
# =========================
results = {}

for cls, name in zip(VESSEL_CLASSES, ["Artery", "Vein"]):
    m = compute_per_class_metrics_from_confmat(conf_sums_val, cls)
    m["auc"] = compute_auc_for_class(auc_buf_val, cls)
    results[name] = m


# =========================
#   MOYENNES ARTERY + VEIN
# =========================
avg_metrics = {metric: np.nanmean([results["Artery"][metric], results["Vein"][metric]])
               for metric in results["Artery"].keys()}

results["Average (A+V)"] = avg_metrics


# =========================
#   AFFICHAGE TABLEAU (4 décimales)
# =========================
df = pd.DataFrame(results).T
df = df.round(4)  # <= Arrondi propre à 4 décimales

print("\n=== Résultats de validation ===\n")
display(df.style.format("{:.4f}"))
# Out:
# === Résultats de validation ===
# <style type="text/css">
# </style>
# <table id="T_eb664">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb664_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_eb664_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_eb664_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_eb664_level0_col3" class="col_heading level0 col3" >specificity</th>
#       <th id="T_eb664_level0_col4" class="col_heading level0 col4" >dice</th>
#       <th id="T_eb664_level0_col5" class="col_heading level0 col5" >iou</th>
#       <th id="T_eb664_level0_col6" class="col_heading level0 col6" >auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb664_level0_row0" class="row_heading level0 row0" >Artery</th>
#       <td id="T_eb664_row0_col0" class="data row0 col0" >0.9322</td>
#       <td id="T_eb664_row0_col1" class="data row0 col1" >0.5040</td>
#       <td id="T_eb664_row0_col2" class="data row0 col2" >0.5694</td>
#       <td id="T_eb664_row0_col3" class="data row0 col3" >0.9589</td>
#       <td id="T_eb664_row0_col4" class="data row0 col4" >0.5347</td>
#       <td id="T_eb664_row0_col5" class="data row0 col5" >0.3649</td>
#       <td id="T_eb664_row0_col6" class="data row0 col6" >0.9237</td>
#     </tr>
#     <tr>
#       <th id="T_eb664_level0_row1" class="row_heading level0 row1" >Vein</th>
#       <td id="T_eb664_row1_col0" class="data row1 col0" >0.9168</td>
#       <td id="T_eb664_row1_col1" class="data row1 col1" >0.3450</td>
#       <td id="T_eb664_row1_col2" class="data row1 col2" >0.4565</td>
#       <td id="T_eb664_row1_col3" class="data row1 col3" >0.9457</td>
#       <td id="T_eb664_row1_col4" class="data row1 col4" >0.3930</td>
#       <td id="T_eb664_row1_col5" class="data row1 col5" >0.2445</td>
#       <td id="T_eb664_row1_col6" class="data row1 col6" >0.8027</td>
#     </tr>
#     <tr>
#       <th id="T_eb664_level0_row2" class="row_heading level0 row2" >Average (A+V)</th>
#       <td id="T_eb664_row2_col0" class="data row2 col0" >0.9245</td>
#       <td id="T_eb664_row2_col1" class="data row2 col1" >0.4245</td>
#       <td id="T_eb664_row2_col2" class="data row2 col2" >0.5129</td>
#       <td id="T_eb664_row2_col3" class="data row2 col3" >0.9523</td>
#       <td id="T_eb664_row2_col4" class="data row2 col4" >0.4639</td>
#       <td id="T_eb664_row2_col5" class="data row2 col5" >0.3047</td>
#       <td id="T_eb664_row2_col6" class="data row2 col6" >0.8632</td>
#     </tr>
#   </tbody>
# </table>

# %%
# =========================
#   CONFIG CLASSES
# =========================
ARTERY_CLASS = 1
VEIN_CLASS   = 2
VESSEL_CLASSES = [ARTERY_CLASS, VEIN_CLASS]
assert NUM_CLASSES >= 3, "NUM_CLASSES must include background + artery + vein"

# =========================
#   PER-IMAGE METRIC HELPERS
# =========================
def dice_per_image(pred, target, cls):
    eps = 1e-7
    p = (pred == cls).float()
    t = (target == cls).float()
    inter = (p * t).sum()
    denom = p.sum() + t.sum()
    return float((2.0 * inter) / (denom + eps))

def iou_per_image(pred, target, cls):
    eps = 1e-7
    p = (pred == cls)
    t = (target == cls)
    inter = (p & t).sum().item()
    union = (p | t).sum().item()
    return float(inter / (union + eps))

def auc_per_image_from_logits(logits, target, cls):
    # logits: (C,H,W) for a single image
    probs = F.softmax(logits, dim=0)
    y_score = probs[cls].reshape(-1).cpu().numpy()
    y_true  = (target == cls).reshape(-1).cpu().numpy().astype(np.uint8)
    pos = (y_true == 1).sum()
    neg = (y_true == 0).sum()
    if pos == 0 or neg == 0:
        return float("nan")
    try:
        return float(roc_auc_score(y_true, y_score))
    except Exception:
        return float("nan")

# =========================
#   COLLECT PER-IMAGE METRICS
# =========================
model.eval()

artery_dice_list, vein_dice_list, avg_dice_list = [], [], []
artery_iou_list,  vein_iou_list,  avg_iou_list  = [], [], []
artery_auc_list,  vein_auc_list,  avg_auc_list  = [], [], []

with torch.no_grad():
    for imgs, masks in val_loader:
        imgs  = imgs.to(device)
        masks = masks.to(device)

        logits = model(imgs)          # (N,C,H,W)
        preds  = logits.argmax(dim=1) # (N,H,W)

        for i in range(imgs.size(0)):
            p   = preds[i]
            gt  = masks[i]
            log = logits[i]

            # Dice
            a_d = dice_per_image(p, gt, ARTERY_CLASS)
            v_d = dice_per_image(p, gt, VEIN_CLASS)
            artery_dice_list.append(a_d)
            vein_dice_list.append(v_d)
            avg_dice_list.append(np.nanmean([a_d, v_d]))

            # IoU
            a_i = iou_per_image(p, gt, ARTERY_CLASS)
            v_i = iou_per_image(p, gt, VEIN_CLASS)
            artery_iou_list.append(a_i)
            vein_iou_list.append(v_i)
            avg_iou_list.append(np.nanmean([a_i, v_i]))

            # AUC
            a_auc = auc_per_image_from_logits(log, gt, ARTERY_CLASS)
            v_auc = auc_per_image_from_logits(log, gt, VEIN_CLASS)
            artery_auc_list.append(a_auc)
            vein_auc_list.append(v_auc)
            avg_auc_list.append(np.nanmean([a_auc, v_auc]))

# =========================
#   BAR PLOTS (3 rows × 3 cols)
#   One bar per image; red dashed = mean
# =========================
def plot_bars_one_metric(ax, values, title):
    values = np.array(values, dtype=float)
    n = len(values)
    x = np.arange(1, n+1)

    ax.bar(x, values, color="#1f77b4", edgecolor="black", alpha=0.9)

    m = np.nanmean(values)
    ax.axhline(m, color="red", linestyle="--", linewidth=2, label=f"mean = {m:.3f}")

    ax.set_ylim(0, 1)            # metrics in [0,1]
    ax.set_xlim(0.5, n + 0.5)
    ax.set_xlabel("Validation image index")
    ax.set_ylabel("Score")
    ax.set_title(title)
    # lighten x ticks if many images
    if n > 30:
        ax.set_xticks(np.linspace(1, n, 10, dtype=int))
    ax.grid(axis="y", alpha=0.3)
    ax.legend(loc="upper right")

fig, axes = plt.subplots(3, 3, figsize=(20, 12), constrained_layout=True)

# Row 1: Dice
plot_bars_one_metric(axes[0,0], artery_dice_list, "Dice – Artery")
plot_bars_one_metric(axes[0,1], vein_dice_list,   "Dice – Vein")
plot_bars_one_metric(axes[0,2], avg_dice_list,    "Dice – Average (A+V)")

# Row 2: IoU
plot_bars_one_metric(axes[1,0], artery_iou_list, "IoU – Artery")
plot_bars_one_metric(axes[1,1], vein_iou_list,   "IoU – Vein")
plot_bars_one_metric(axes[1,2], avg_iou_list,    "IoU – Average (A+V)")

# Row 3: AUC
plot_bars_one_metric(axes[2,0], artery_auc_list, "AUC – Artery")
plot_bars_one_metric(axes[2,1], vein_auc_list,   "AUC – Vein")
plot_bars_one_metric(axes[2,2], avg_auc_list,    "AUC – Average (A+V)")

plt.show()
