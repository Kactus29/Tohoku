# %% [markdown]
# # Imports

# %% [markdown]
# #### PyTorch

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, OneCycleLR

# %%
print('PyTorch version', torch.__version__)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# PyTorch version 2.5.1
# Device: cuda

# %% [markdown]
# #### General

# %%
import os
import json
import math
import time
import random
from pathlib import Path
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from tqdm import tqdm

from sklearn.metrics import roc_auc_score

# %% [markdown]
# #### Monai

# %%
from monai.losses import DiceLoss, FocalLoss

# %% [markdown]
# # Parameters

# %% [markdown]
# #### Directories for the images

# %%
parent = Path().cwd().parent
data_root = parent / 'try_1'

train_images_dir = data_root / 'train' / 'images'
train_masks_dir = data_root / 'train' / 'masks'

val_images_dir = data_root / 'val' / 'images'
val_masks_dir = data_root / 'val' / 'masks'

# %% [markdown]
# #### General parameters

# %%
IMG_HEIGHT = 768
IMG_WIDTH = 768

BATCH_SIZE = 4

EPOCHS = 200
print('Number of epochs:', EPOCHS)

LR = 0.0005
print('Learning rate:', LR)

"""
0 : background (black)
1 : arteries (white)
2 : veins (gray)
"""
NUM_CLASSES = 3

COLOR_TO_LABEL = {
    (0,0,0): 0,
    (255,255,255): 1,
    (128,128,128): 2
}
# Out:
# Number of epochs: 200
# Learning rate: 0.0005

# %% [markdown]
# # DataLoaders

# %% [markdown]
# #### Create the class for the dataset images

# %%
class RAVIRDataset(Dataset):
    def __init__(self, img_dir, mask_dir, img_size=(IMG_HEIGHT, IMG_WIDTH), transforms=None):
        self.img_paths = sorted(list(Path(img_dir).glob('*.png')))
        self.mask_dir = Path(mask_dir)
        self.img_size = img_size
        self.transforms = transforms

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_p = self.img_paths[idx]
        mask_p = self.mask_dir / img_p.name
        img = Image.open(img_p).convert('RGB').resize(self.img_size, Image.BILINEAR)
        img = np.array(img, dtype=np.float32) / 255.0
        img = np.transpose(img, (2,0,1))  # C,H,W
        img_t = torch.from_numpy(img).float()
        # load mask and map colors to labels
        m = Image.open(mask_p).convert('RGB').resize(self.img_size, Image.NEAREST)
        m_arr = np.array(m, dtype=np.uint8)
        label = np.zeros((self.img_size[1], self.img_size[0]), dtype=np.uint8)
        for color, lab in COLOR_TO_LABEL.items():
            mask = np.all(m_arr == np.array(color, dtype=np.uint8), axis=-1)
            label[mask] = lab
        label_t = torch.from_numpy(label).long()  # H,W
        return img_t, label_t

# %%
train_ds = RAVIRDataset(train_images_dir, train_masks_dir, (IMG_WIDTH, IMG_HEIGHT))
val_ds = RAVIRDataset(val_images_dir, val_masks_dir, (IMG_WIDTH, IMG_HEIGHT))

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %% [markdown]
# # U-Net model

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True)
        )
    def forward(self, x):
        return self.net(x)

class UNet(nn.Module):
    def __init__(self, n_classes=NUM_CLASSES, in_channels=3, features=[32,64,128,256]):
        super().__init__()
        self.encs = nn.ModuleList()
        self.pools = nn.ModuleList()
        for f in features:
            self.encs.append(DoubleConv(in_channels, f))
            self.pools.append(nn.MaxPool2d(2))
            in_channels = f
        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        # decoder
        self.upconvs = nn.ModuleList()
        self.decs = nn.ModuleList()
        for f in reversed(features):
            self.upconvs.append(nn.ConvTranspose2d(f*2, f, kernel_size=2, stride=2))
            self.decs.append(DoubleConv(f*2, f))
        self.final_conv = nn.Conv2d(features[0], n_classes, kernel_size=1)

    def forward(self, x):
        skips = []
        for enc, pool in zip(self.encs, self.pools):
            x = enc(x)
            skips.append(x)
            x = pool(x)
        x = self.bottleneck(x)
        for up, dec, skip in zip(self.upconvs, self.decs, reversed(skips)):
            x = up(x)
            # pad if needed
            if x.shape != skip.shape:
                x = nn.functional.interpolate(x, size=skip.shape[2:])
            x = torch.cat([skip, x], dim=1)
            x = dec(x)
        x = self.final_conv(x)
        return x

model = UNet().to(device)
# print(model)

# %% [markdown]
# # Optimizer

# %%
optimizer = optim.AdamW(model.parameters(), lr=LR)

# %% [markdown]
# # Scheduler

# %%
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, 
    max_lr = 0.001,
    steps_per_epoch = len(train_loader),
    epochs = EPOCHS,
    pct_start = 0.3,
    anneal_strategy = "cos"
)

# %% [markdown]
# # Loss function

# %%
def dice_loss(outputs, targets, epsilon=1e-6):
    """
    outputs: logits (N, C, H, W)
    targets: labels (N, H, W)
    """
    # Probabilités
    probs = F.softmax(outputs, dim=1)

    N, C, H, W = probs.shape

    # One-hot du masque → shape (N, C, H, W)
    targets_onehot = F.one_hot(targets, num_classes=C).permute(0, 3, 1, 2).float()

    # On ignore la classe 0 (background)
    probs = probs[:, 1:, :, :]          # (N, C-1, H, W)
    targets_onehot = targets_onehot[:, 1:, :, :]  # (N, C-1, H, W)

    # Dice par classe
    intersection = torch.sum(probs * targets_onehot, dim=(0, 2, 3))
    cardinality  = torch.sum(probs + targets_onehot, dim=(0, 2, 3))

    dice_per_class = (2 * intersection + epsilon) / (cardinality + epsilon)

    # Loss = 1 - moyenne des dice des classes artery + vein
    return 1 - dice_per_class.mean()

# %%
percentage = [0.872, 0.054, 0.073]
inverse_percentage = [round((1/p),2) for p in percentage]
print(inverse_percentage)

weights = torch.tensor(inverse_percentage).to(device)
CE_loss = nn.CrossEntropyLoss(weight=weights)
# Out:
# [1.15, 18.52, 13.7]

# %%
def combined_loss(outputs, targets, alpha=0.5) :
    return alpha * CE_loss(outputs, targets) + (1-alpha) * dice_loss(outputs, targets)

# %% [markdown]
# # Model train

# %%
best_val_loss = float("inf")
best_val_dice = -float("inf")

model_name = "My_UNet_v3_1"
save_dir = Path("Models") / model_name

save_dir.mkdir(parents=True, exist_ok=True)
last_epoch_save = 0

# %%
NUM_CLASSES = 3
BACKGROUND_IDX = 0
VESSEL_CLASSES = [1, 2]

# %%
# ===========================================
#   DICTIONNAIRES STOCRAGE (MEAN ONLY)
# ===========================================

train_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        []
}

val_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        []
}

# %%
# =========================
#          INIT
# =========================

def init_confmat_sums(num_classes=NUM_CLASSES) :
    sums = {
        "TP" : np.zeros(num_classes, dtype=np.int64),
        "FP" : np.zeros(num_classes, dtype=np.int64),
        "FN" : np.zeros(num_classes, dtype=np.int64),
        "TN" : np.zeros(num_classes, dtype=np.int64),
        "N"  : 0
    }
    return sums

def init_auc_buffers(include_classes=VESSEL_CLASSES) :
    return {c : {"y_true" : [], "y_score" : []} for c in include_classes}

# %%
# =========================
#         UPDATE
# =========================

def update_confmat_sums(sums, preds, targets, num_classes=NUM_CLASSES) :
    with torch.no_grad() :
        for c in range(num_classes) :
            p = (preds == c)
            t = (targets == c)
            tp = (p & t).sum().item()
            fp = (p & ~t).sum().item()
            fn = (~p & t).sum().item()
            tn = (~p & ~t).sum().item()
            sums["TP"][c] += tp
            sums["FP"][c] += fp
            sums["FN"][c] += fn
            sums["TN"][c] += tn
        sums["N"] += targets.numel()



def update_auc_buffers(buffers, logits, targets):
    with torch.no_grad():
        probs = F.softmax(logits, dim=1)
        flat_probs = probs.permute(0,2,3,1).reshape(-1, probs.shape[1])
        flat_t     = targets.reshape(-1)

        for c in buffers.keys():
            y_true = (flat_t == c).cpu().numpy().astype(np.uint8)
            y_score = flat_probs[:, c].cpu().numpy()
            buffers[c]["y_true"].append(y_true)
            buffers[c]["y_score"].append(y_score)

# %%
def compute_scalar_metrics_from_confmat(sums, include_classes):
    TP, FP, FN, TN = sums["TP"], sums["FP"], sums["FN"], sums["TN"]
    eps = 1e-7

    acc_c  = (TP + TN) / np.maximum(TP + TN + FP + FN, eps)
    prec_c = TP / np.maximum(TP + FP, eps)
    rec_c  = TP / np.maximum(TP + FN, eps)
    spec_c = TN / np.maximum(TN + FP, eps)
    dice_c = (2 * TP) / np.maximum(2 * TP + FP + FN, eps)
    iou_c  = TP / np.maximum(TP + FP + FN, eps)

    idx = np.array(include_classes, dtype=int)
    return {
        "accuracy":   float(np.mean(acc_c[idx])),
        "precision":  float(np.mean(prec_c[idx])),
        "recall":     float(np.mean(rec_c[idx])),
        "specificity":float(np.mean(spec_c[idx])),
        "dice":       float(np.mean(dice_c[idx])),
        "iou":        float(np.mean(iou_c[idx])),
    }

# %%
def compute_mean_auc(buffers):
    aucs = []
    for c, pack in buffers.items():
        if len(pack["y_true"]) == 0: 
            continue
        y_true = np.concatenate(pack["y_true"])
        y_score = np.concatenate(pack["y_score"])
        pos = (y_true == 1).sum()
        neg = (y_true == 0).sum()
        if pos == 0 or neg == 0:
            continue
        try:
            aucs.append(roc_auc_score(y_true, y_score))
        except:
            pass
    if len(aucs) == 0:
        return float("nan")
    return float(np.mean(aucs))

# %%
# =========================
#        LEARNING
# =========================

for epoch in range(EPOCHS) :

    # =========================
    #        TRAIN
    # =========================

    model.train()

    runing_loss = 0.0
    conf_sums = init_confmat_sums()
    auc_buf = init_auc_buffers()

    for imgs, masks in train_loader :

        imgs = imgs.to(device)
        masks = masks.to(device)

        optimizer.zero_grad()

        outputs = model(imgs)

        loss = combined_loss(outputs, masks, alpha=0.3)
        loss.backward()
        optimizer.step()
        scheduler.step()

        runing_loss += loss.item() * imgs.size(0)

        preds = outputs.argmax(dim=1)
        update_confmat_sums(conf_sums, preds, masks, NUM_CLASSES)
        update_auc_buffers(auc_buf, outputs, masks)
    
    train_loss = runing_loss / len(train_ds)
    train_metrics = compute_scalar_metrics_from_confmat(conf_sums, VESSEL_CLASSES)
    train_auc = compute_mean_auc(auc_buf)

    train_history["loss"].append(train_loss)
    train_history["accuracy"].append(train_metrics["accuracy"])
    train_history["dice"].append(train_metrics["dice"])
    train_history["iou"].append(train_metrics["iou"])
    train_history["precision"].append(train_metrics["precision"])
    train_history["recall"].append(train_metrics["recall"])
    train_history["specificity"].append(train_metrics["specificity"])
    train_history["auc"].append(train_auc)




    # =========================
    #       VALIDATION
    # =========================
    model.eval()

    val_runing_loss = 0.0
    conf_sums_val = init_confmat_sums()
    auc_buf_val   = init_auc_buffers()

    with torch.no_grad():
        for imgs, masks in val_loader:
            imgs  = imgs.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)

            outputs = model(imgs)
            loss = combined_loss(outputs, masks, alpha=0.3)
            val_runing_loss += loss.item() * imgs.size(0)

            preds = outputs.argmax(dim=1)
            update_confmat_sums(conf_sums_val, preds, masks, NUM_CLASSES)
            update_auc_buffers(auc_buf_val, outputs, masks)

    val_loss = val_runing_loss / len(val_ds)
    val_metrics = compute_scalar_metrics_from_confmat(conf_sums_val, VESSEL_CLASSES)
    val_auc = compute_mean_auc(auc_buf_val)

    val_history["loss"].append(val_loss)
    val_history["accuracy"].append(val_metrics["accuracy"])
    val_history["dice"].append(val_metrics["dice"])
    val_history["iou"].append(val_metrics["iou"])
    val_history["precision"].append(val_metrics["precision"])
    val_history["recall"].append(val_metrics["recall"])
    val_history["specificity"].append(val_metrics["specificity"])
    val_history["auc"].append(val_auc)




    # =========================
    #           LOGS
    # =========================
    print('-'*30)
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"  Train Loss: {train_loss:.4f} | Dice: {train_metrics['dice']:.4f} | IoU: {train_metrics['iou']:.4f}")
    print(f"  Val   Loss: {val_loss:.4f} | Dice: {val_metrics['dice']:.4f} | IoU: {val_metrics['iou']:.4f}")




    # =========================
    #     SAVE BEST MODEL
    # =========================
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), str(save_dir / "loss_best_model_state_dict.pth"))
        torch.save(model, str(save_dir / "loss_best_model_full.pth"))
        print(f"✅ Nouveau meilleur modèle loss sauvegardé")
    
    val_dice = val_metrics["dice"]
    if val_dice > best_val_dice :
        best_val_dice = val_dice
        torch.save(model.state_dict(), str(save_dir / "dice_best_model_state_dict.pth"))
        torch.save(model, str(save_dir / "dice_best_model_full.pth"))
        print(f"✅ Nouveau meilleur modèle dice sauvegardé")



# =========================
#     SAVE LAST MODEL
# =========================
torch.save(model.state_dict(), str(save_dir / f"epoch{EPOCHS}_model_state_dict.pth"))
torch.save(model, str(save_dir / f"epoch{EPOCHS}_model_full.pth"))
# Out:
# ------------------------------
# Epoch 1/200
#   Train Loss: 0.9583 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9572 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 2/200
#   Train Loss: 0.9579 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9570 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 3/200
#   Train Loss: 0.9576 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9568 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 4/200
#   Train Loss: 0.9574 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9566 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 5/200
#   Train Loss: 0.9571 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9563 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 6/200
#   Train Loss: 0.9567 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9560 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 7/200
#   Train Loss: 0.9564 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9557 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 8/200
#   Train Loss: 0.9559 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9554 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 9/200
#   Train Loss: 0.9554 | Dice: 0.0507 | IoU: 0.0267
#   Val   Loss: 0.9549 | Dice: 0.0581 | IoU: 0.0308
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 10/200
#   Train Loss: 0.9546 | Dice: 0.0783 | IoU: 0.0410
#   Val   Loss: 0.9542 | Dice: 0.1206 | IoU: 0.0643
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 11/200
#   Train Loss: 0.9536 | Dice: 0.0901 | IoU: 0.0476
#   Val   Loss: 0.9532 | Dice: 0.0671 | IoU: 0.0357
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 12/200
#   Train Loss: 0.9518 | Dice: 0.0726 | IoU: 0.0389
#   Val   Loss: 0.9516 | Dice: 0.0643 | IoU: 0.0343
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 13/200
#   Train Loss: 0.9489 | Dice: 0.0695 | IoU: 0.0374
#   Val   Loss: 0.9505 | Dice: 0.0640 | IoU: 0.0342
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 14/200
#   Train Loss: 0.9460 | Dice: 0.0695 | IoU: 0.0373
#   Val   Loss: 0.9521 | Dice: 0.0640 | IoU: 0.0342
# ------------------------------
# Epoch 15/200
#   Train Loss: 0.9457 | Dice: 0.0695 | IoU: 0.0373
#   Val   Loss: 0.9497 | Dice: 0.0640 | IoU: 0.0342
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 16/200
#   Train Loss: 0.9446 | Dice: 0.0695 | IoU: 0.0373
#   Val   Loss: 0.9480 | Dice: 0.0640 | IoU: 0.0342
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 17/200
#   Train Loss: 0.9427 | Dice: 0.0695 | IoU: 0.0373
#   Val   Loss: 0.9469 | Dice: 0.0640 | IoU: 0.0342
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 18/200
#   Train Loss: 0.9403 | Dice: 0.0695 | IoU: 0.0373
#   Val   Loss: 0.9446 | Dice: 0.0641 | IoU: 0.0342
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 19/200
#   Train Loss: 0.9361 | Dice: 0.0770 | IoU: 0.0417
#   Val   Loss: 0.9383 | Dice: 0.0761 | IoU: 0.0412
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 20/200
#   Train Loss: 0.9288 | Dice: 0.0834 | IoU: 0.0455
#   Val   Loss: 0.9305 | Dice: 0.0817 | IoU: 0.0445
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 21/200
#   Train Loss: 0.9220 | Dice: 0.0982 | IoU: 0.0544
#   Val   Loss: 0.9232 | Dice: 0.0964 | IoU: 0.0533
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 22/200
#   Train Loss: 0.9188 | Dice: 0.1074 | IoU: 0.0601
#   Val   Loss: 0.9199 | Dice: 0.0939 | IoU: 0.0518
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 23/200
#   Train Loss: 0.9128 | Dice: 0.1069 | IoU: 0.0599
#   Val   Loss: 0.9164 | Dice: 0.1335 | IoU: 0.0770
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 24/200
#   Train Loss: 0.9109 | Dice: 0.1240 | IoU: 0.0708
#   Val   Loss: 0.9321 | Dice: 0.0770 | IoU: 0.0417
# ------------------------------
# Epoch 25/200
#   Train Loss: 0.9065 | Dice: 0.1129 | IoU: 0.0636
#   Val   Loss: 0.9160 | Dice: 0.1392 | IoU: 0.0809
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 26/200
#   Train Loss: 0.9179 | Dice: 0.1044 | IoU: 0.0583
#   Val   Loss: 0.9118 | Dice: 0.1196 | IoU: 0.0667
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 27/200
#   Train Loss: 0.9139 | Dice: 0.1366 | IoU: 0.0768
#   Val   Loss: 0.9114 | Dice: 0.1041 | IoU: 0.0581
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 28/200
#   Train Loss: 0.9089 | Dice: 0.1004 | IoU: 0.0558
#   Val   Loss: 0.9108 | Dice: 0.1091 | IoU: 0.0612
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 29/200
#   Train Loss: 0.9033 | Dice: 0.1178 | IoU: 0.0668
#   Val   Loss: 0.9122 | Dice: 0.0972 | IoU: 0.0539
# ------------------------------
# Epoch 30/200
#   Train Loss: 0.9019 | Dice: 0.1061 | IoU: 0.0593
#   Val   Loss: 0.9072 | Dice: 0.1255 | IoU: 0.0717
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 31/200
#   Train Loss: 0.8963 | Dice: 0.1285 | IoU: 0.0737
#   Val   Loss: 0.9443 | Dice: 0.0775 | IoU: 0.0420
# ------------------------------
# Epoch 32/200
#   Train Loss: 0.9050 | Dice: 0.1037 | IoU: 0.0578
#   Val   Loss: 0.9017 | Dice: 0.1364 | IoU: 0.0789
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 33/200
#   Train Loss: 0.9019 | Dice: 0.1032 | IoU: 0.0575
#   Val   Loss: 0.9107 | Dice: 0.1561 | IoU: 0.0924
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 34/200
#   Train Loss: 0.8948 | Dice: 0.1364 | IoU: 0.0789
#   Val   Loss: 0.9230 | Dice: 0.0877 | IoU: 0.0481
# ------------------------------
# Epoch 35/200
#   Train Loss: 0.9021 | Dice: 0.1134 | IoU: 0.0639
#   Val   Loss: 0.9010 | Dice: 0.1438 | IoU: 0.0839
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 36/200
#   Train Loss: 0.8974 | Dice: 0.1137 | IoU: 0.0637
#   Val   Loss: 0.8983 | Dice: 0.1710 | IoU: 0.0986
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 37/200
#   Train Loss: 0.8867 | Dice: 0.1677 | IoU: 0.0957
#   Val   Loss: 0.9085 | Dice: 0.1030 | IoU: 0.0571
# ------------------------------
# Epoch 38/200
#   Train Loss: 0.8815 | Dice: 0.1271 | IoU: 0.0723
#   Val   Loss: 0.8827 | Dice: 0.1356 | IoU: 0.0784
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 39/200
#   Train Loss: 0.9112 | Dice: 0.1251 | IoU: 0.0714
#   Val   Loss: 0.8853 | Dice: 0.1361 | IoU: 0.0787
# ------------------------------
# Epoch 40/200
#   Train Loss: 0.8727 | Dice: 0.1453 | IoU: 0.0844
#   Val   Loss: 0.9116 | Dice: 0.0962 | IoU: 0.0531
# ------------------------------
# Epoch 41/200
#   Train Loss: 0.8979 | Dice: 0.1316 | IoU: 0.0732
#   Val   Loss: 0.9040 | Dice: 0.2174 | IoU: 0.1279
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 42/200
#   Train Loss: 0.8860 | Dice: 0.1741 | IoU: 0.0984
#   Val   Loss: 0.8855 | Dice: 0.1762 | IoU: 0.1004
# ------------------------------
# Epoch 43/200
#   Train Loss: 0.8663 | Dice: 0.1882 | IoU: 0.1075
#   Val   Loss: 0.8767 | Dice: 0.1633 | IoU: 0.0942
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 44/200
#   Train Loss: 0.8927 | Dice: 0.1402 | IoU: 0.0784
#   Val   Loss: 0.8889 | Dice: 0.2439 | IoU: 0.1454
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 45/200
#   Train Loss: 0.8634 | Dice: 0.2157 | IoU: 0.1258
#   Val   Loss: 0.8856 | Dice: 0.2291 | IoU: 0.1346
# ------------------------------
# Epoch 46/200
#   Train Loss: 0.8579 | Dice: 0.2049 | IoU: 0.1173
#   Val   Loss: 0.8949 | Dice: 0.1629 | IoU: 0.0919
# ------------------------------
# Epoch 47/200
#   Train Loss: 0.8670 | Dice: 0.1948 | IoU: 0.1120
#   Val   Loss: 0.8590 | Dice: 0.2836 | IoU: 0.1717
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 48/200
#   Train Loss: 0.8558 | Dice: 0.2591 | IoU: 0.1533
#   Val   Loss: 0.8619 | Dice: 0.2509 | IoU: 0.1494
# ------------------------------
# Epoch 49/200
#   Train Loss: 0.8628 | Dice: 0.2712 | IoU: 0.1593
#   Val   Loss: 0.8517 | Dice: 0.2877 | IoU: 0.1771
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 50/200
#   Train Loss: 0.8420 | Dice: 0.2660 | IoU: 0.1584
#   Val   Loss: 0.8529 | Dice: 0.2661 | IoU: 0.1619
# ------------------------------
# Epoch 51/200
#   Train Loss: 0.8492 | Dice: 0.2271 | IoU: 0.1337
#   Val   Loss: 0.8627 | Dice: 0.3040 | IoU: 0.1860
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 52/200
#   Train Loss: 0.8336 | Dice: 0.2719 | IoU: 0.1620
#   Val   Loss: 0.8254 | Dice: 0.2793 | IoU: 0.1691
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 53/200
#   Train Loss: 0.8128 | Dice: 0.2733 | IoU: 0.1631
#   Val   Loss: 0.8190 | Dice: 0.3330 | IoU: 0.2060
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 54/200
#   Train Loss: 0.7847 | Dice: 0.3404 | IoU: 0.2113
#   Val   Loss: 1.0069 | Dice: 0.1930 | IoU: 0.1135
# ------------------------------
# Epoch 55/200
#   Train Loss: 0.8685 | Dice: 0.2622 | IoU: 0.1562
#   Val   Loss: 0.8553 | Dice: 0.2498 | IoU: 0.1494
# ------------------------------
# Epoch 56/200
#   Train Loss: 0.8341 | Dice: 0.2619 | IoU: 0.1581
#   Val   Loss: 0.8396 | Dice: 0.2324 | IoU: 0.1338
# ------------------------------
# Epoch 57/200
#   Train Loss: 0.8221 | Dice: 0.2607 | IoU: 0.1506
#   Val   Loss: 0.8262 | Dice: 0.2949 | IoU: 0.1770
# ------------------------------
# Epoch 58/200
#   Train Loss: 0.8016 | Dice: 0.2737 | IoU: 0.1619
#   Val   Loss: 0.7956 | Dice: 0.3184 | IoU: 0.1979
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 59/200
#   Train Loss: 0.7740 | Dice: 0.3225 | IoU: 0.1997
#   Val   Loss: 0.8095 | Dice: 0.3138 | IoU: 0.1944
# ------------------------------
# Epoch 60/200
#   Train Loss: 0.7552 | Dice: 0.3569 | IoU: 0.2258
#   Val   Loss: 0.8147 | Dice: 0.3369 | IoU: 0.2090
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 61/200
#   Train Loss: 0.7682 | Dice: 0.3638 | IoU: 0.2276
#   Val   Loss: 0.8652 | Dice: 0.2685 | IoU: 0.1640
# ------------------------------
# Epoch 62/200
#   Train Loss: 0.8005 | Dice: 0.3284 | IoU: 0.2031
#   Val   Loss: 0.8102 | Dice: 0.3393 | IoU: 0.2109
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 63/200
#   Train Loss: 0.7585 | Dice: 0.3666 | IoU: 0.2315
#   Val   Loss: 0.8227 | Dice: 0.2934 | IoU: 0.1793
# ------------------------------
# Epoch 64/200
#   Train Loss: 0.7759 | Dice: 0.3483 | IoU: 0.2174
#   Val   Loss: 0.8341 | Dice: 0.2850 | IoU: 0.1749
# ------------------------------
# Epoch 65/200
#   Train Loss: 0.7778 | Dice: 0.3088 | IoU: 0.1907
#   Val   Loss: 0.8773 | Dice: 0.3383 | IoU: 0.2066
# ------------------------------
# Epoch 66/200
#   Train Loss: 0.7937 | Dice: 0.3375 | IoU: 0.2084
#   Val   Loss: 0.8126 | Dice: 0.2844 | IoU: 0.1724
# ------------------------------
# Epoch 67/200
#   Train Loss: 0.7643 | Dice: 0.3597 | IoU: 0.2259
#   Val   Loss: 0.8072 | Dice: 0.3177 | IoU: 0.1945
# ------------------------------
# Epoch 68/200
#   Train Loss: 0.7475 | Dice: 0.3691 | IoU: 0.2320
#   Val   Loss: 0.8015 | Dice: 0.3332 | IoU: 0.2071
# ------------------------------
# Epoch 69/200
#   Train Loss: 0.7500 | Dice: 0.3733 | IoU: 0.2366
#   Val   Loss: 0.7979 | Dice: 0.3340 | IoU: 0.2069
# ------------------------------
# Epoch 70/200
#   Train Loss: 0.7431 | Dice: 0.3950 | IoU: 0.2512
#   Val   Loss: 0.8380 | Dice: 0.2948 | IoU: 0.1811
# ------------------------------
# Epoch 71/200
#   Train Loss: 0.7567 | Dice: 0.3587 | IoU: 0.2263
#   Val   Loss: 0.7954 | Dice: 0.3395 | IoU: 0.2096
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 72/200
#   Train Loss: 0.7502 | Dice: 0.3534 | IoU: 0.2196
#   Val   Loss: 0.8352 | Dice: 0.3481 | IoU: 0.2150
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 73/200
#   Train Loss: 0.7768 | Dice: 0.3587 | IoU: 0.2236
#   Val   Loss: 0.8088 | Dice: 0.3370 | IoU: 0.2075
# ------------------------------
# Epoch 74/200
#   Train Loss: 0.7501 | Dice: 0.3730 | IoU: 0.2357
#   Val   Loss: 0.8234 | Dice: 0.3530 | IoU: 0.2197
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 75/200
#   Train Loss: 0.7543 | Dice: 0.3844 | IoU: 0.2415
#   Val   Loss: 0.8238 | Dice: 0.2853 | IoU: 0.1737
# ------------------------------
# Epoch 76/200
#   Train Loss: 0.7601 | Dice: 0.3532 | IoU: 0.2229
#   Val   Loss: 0.7981 | Dice: 0.3386 | IoU: 0.2079
# ------------------------------
# Epoch 77/200
#   Train Loss: 0.7492 | Dice: 0.3873 | IoU: 0.2437
#   Val   Loss: 0.8057 | Dice: 0.3303 | IoU: 0.2041
# ------------------------------
# Epoch 78/200
#   Train Loss: 0.7457 | Dice: 0.3617 | IoU: 0.2274
#   Val   Loss: 0.8027 | Dice: 0.3438 | IoU: 0.2124
# ------------------------------
# Epoch 79/200
#   Train Loss: 0.7493 | Dice: 0.3918 | IoU: 0.2484
#   Val   Loss: 0.8018 | Dice: 0.3266 | IoU: 0.2020
# ------------------------------
# Epoch 80/200
#   Train Loss: 0.7397 | Dice: 0.3853 | IoU: 0.2452
#   Val   Loss: 0.7968 | Dice: 0.3410 | IoU: 0.2109
# ------------------------------
# Epoch 81/200
#   Train Loss: 0.7338 | Dice: 0.3863 | IoU: 0.2449
#   Val   Loss: 0.8015 | Dice: 0.3269 | IoU: 0.2017
# ------------------------------
# Epoch 82/200
#   Train Loss: 0.7354 | Dice: 0.3718 | IoU: 0.2353
#   Val   Loss: 0.8064 | Dice: 0.3556 | IoU: 0.2208
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 83/200
#   Train Loss: 0.7477 | Dice: 0.3943 | IoU: 0.2508
#   Val   Loss: 0.8068 | Dice: 0.3187 | IoU: 0.1963
# ------------------------------
# Epoch 84/200
#   Train Loss: 0.7325 | Dice: 0.3894 | IoU: 0.2476
#   Val   Loss: 0.8074 | Dice: 0.3510 | IoU: 0.2166
# ------------------------------
# Epoch 85/200
#   Train Loss: 0.7375 | Dice: 0.3934 | IoU: 0.2493
#   Val   Loss: 0.8111 | Dice: 0.3137 | IoU: 0.1936
# ------------------------------
# Epoch 86/200
#   Train Loss: 0.7390 | Dice: 0.3767 | IoU: 0.2397
#   Val   Loss: 0.7942 | Dice: 0.3446 | IoU: 0.2133
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 87/200
#   Train Loss: 0.7311 | Dice: 0.3943 | IoU: 0.2509
#   Val   Loss: 0.8042 | Dice: 0.3357 | IoU: 0.2074
# ------------------------------
# Epoch 88/200
#   Train Loss: 0.7296 | Dice: 0.3928 | IoU: 0.2501
#   Val   Loss: 0.7977 | Dice: 0.3436 | IoU: 0.2130
# ------------------------------
# Epoch 89/200
#   Train Loss: 0.7287 | Dice: 0.3896 | IoU: 0.2484
#   Val   Loss: 0.7932 | Dice: 0.3478 | IoU: 0.2154
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 90/200
#   Train Loss: 0.7297 | Dice: 0.4080 | IoU: 0.2613
#   Val   Loss: 0.8029 | Dice: 0.3342 | IoU: 0.2068
# ------------------------------
# Epoch 91/200
#   Train Loss: 0.7337 | Dice: 0.3949 | IoU: 0.2515
#   Val   Loss: 0.7954 | Dice: 0.3407 | IoU: 0.2108
# ------------------------------
# Epoch 92/200
#   Train Loss: 0.7253 | Dice: 0.3984 | IoU: 0.2545
#   Val   Loss: 0.8025 | Dice: 0.3235 | IoU: 0.1999
# ------------------------------
# Epoch 93/200
#   Train Loss: 0.7279 | Dice: 0.3879 | IoU: 0.2470
#   Val   Loss: 0.8043 | Dice: 0.3526 | IoU: 0.2179
# ------------------------------
# Epoch 94/200
#   Train Loss: 0.7384 | Dice: 0.3760 | IoU: 0.2372
#   Val   Loss: 0.7891 | Dice: 0.3341 | IoU: 0.2067
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 95/200
#   Train Loss: 0.7465 | Dice: 0.4071 | IoU: 0.2600
#   Val   Loss: 0.7925 | Dice: 0.3284 | IoU: 0.2024
# ------------------------------
# Epoch 96/200
#   Train Loss: 0.7511 | Dice: 0.3399 | IoU: 0.2118
#   Val   Loss: 0.7906 | Dice: 0.3401 | IoU: 0.2088
# ------------------------------
# Epoch 97/200
#   Train Loss: 0.7357 | Dice: 0.4096 | IoU: 0.2611
#   Val   Loss: 0.7987 | Dice: 0.3413 | IoU: 0.2122
# ------------------------------
# Epoch 98/200
#   Train Loss: 0.7304 | Dice: 0.3981 | IoU: 0.2554
#   Val   Loss: 0.7984 | Dice: 0.3211 | IoU: 0.1976
# ------------------------------
# Epoch 99/200
#   Train Loss: 0.7434 | Dice: 0.3489 | IoU: 0.2167
#   Val   Loss: 0.7955 | Dice: 0.3468 | IoU: 0.2125
# ------------------------------
# Epoch 100/200
#   Train Loss: 0.7662 | Dice: 0.3527 | IoU: 0.2182
#   Val   Loss: 0.8153 | Dice: 0.3534 | IoU: 0.2190
# ------------------------------
# Epoch 101/200
#   Train Loss: 0.7281 | Dice: 0.4004 | IoU: 0.2561
#   Val   Loss: 0.8087 | Dice: 0.3143 | IoU: 0.1934
# ------------------------------
# Epoch 102/200
#   Train Loss: 0.7311 | Dice: 0.3812 | IoU: 0.2416
#   Val   Loss: 0.7855 | Dice: 0.3474 | IoU: 0.2141
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 103/200
#   Train Loss: 0.7240 | Dice: 0.4107 | IoU: 0.2626
#   Val   Loss: 0.7943 | Dice: 0.3301 | IoU: 0.2036
# ------------------------------
# Epoch 104/200
#   Train Loss: 0.7298 | Dice: 0.3700 | IoU: 0.2338
#   Val   Loss: 0.7923 | Dice: 0.3493 | IoU: 0.2160
# ------------------------------
# Epoch 105/200
#   Train Loss: 0.7250 | Dice: 0.4196 | IoU: 0.2695
#   Val   Loss: 0.7927 | Dice: 0.3323 | IoU: 0.2049
# ------------------------------
# Epoch 106/200
#   Train Loss: 0.7428 | Dice: 0.3521 | IoU: 0.2211
#   Val   Loss: 0.7967 | Dice: 0.3556 | IoU: 0.2201
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 107/200
#   Train Loss: 0.7349 | Dice: 0.4245 | IoU: 0.2729
#   Val   Loss: 0.7937 | Dice: 0.3334 | IoU: 0.2059
# ------------------------------
# Epoch 108/200
#   Train Loss: 0.7307 | Dice: 0.3685 | IoU: 0.2331
#   Val   Loss: 0.7880 | Dice: 0.3435 | IoU: 0.2120
# ------------------------------
# Epoch 109/200
#   Train Loss: 0.7257 | Dice: 0.4082 | IoU: 0.2601
#   Val   Loss: 0.7928 | Dice: 0.3454 | IoU: 0.2131
# ------------------------------
# Epoch 110/200
#   Train Loss: 0.7244 | Dice: 0.3884 | IoU: 0.2474
#   Val   Loss: 0.7952 | Dice: 0.3459 | IoU: 0.2145
# ------------------------------
# Epoch 111/200
#   Train Loss: 0.7259 | Dice: 0.4156 | IoU: 0.2663
#   Val   Loss: 0.7884 | Dice: 0.3417 | IoU: 0.2109
# ------------------------------
# Epoch 112/200
#   Train Loss: 0.7285 | Dice: 0.3733 | IoU: 0.2358
#   Val   Loss: 0.7903 | Dice: 0.3376 | IoU: 0.2089
# ------------------------------
# Epoch 113/200
#   Train Loss: 0.7204 | Dice: 0.3899 | IoU: 0.2486
#   Val   Loss: 0.7883 | Dice: 0.3524 | IoU: 0.2179
# ------------------------------
# Epoch 114/200
#   Train Loss: 0.7309 | Dice: 0.4232 | IoU: 0.2716
#   Val   Loss: 0.8000 | Dice: 0.3382 | IoU: 0.2091
# ------------------------------
# Epoch 115/200
#   Train Loss: 0.7251 | Dice: 0.3749 | IoU: 0.2377
#   Val   Loss: 0.7924 | Dice: 0.3372 | IoU: 0.2088
# ------------------------------
# Epoch 116/200
#   Train Loss: 0.7213 | Dice: 0.4097 | IoU: 0.2629
#   Val   Loss: 0.7853 | Dice: 0.3561 | IoU: 0.2202
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 117/200
#   Train Loss: 0.7193 | Dice: 0.4125 | IoU: 0.2646
#   Val   Loss: 0.7957 | Dice: 0.3328 | IoU: 0.2052
# ------------------------------
# Epoch 118/200
#   Train Loss: 0.7224 | Dice: 0.3902 | IoU: 0.2476
#   Val   Loss: 0.8004 | Dice: 0.3492 | IoU: 0.2164
# ------------------------------
# Epoch 119/200
#   Train Loss: 0.7189 | Dice: 0.4078 | IoU: 0.2616
#   Val   Loss: 0.7906 | Dice: 0.3503 | IoU: 0.2171
# ------------------------------
# Epoch 120/200
#   Train Loss: 0.7203 | Dice: 0.4211 | IoU: 0.2713
#   Val   Loss: 0.7862 | Dice: 0.3532 | IoU: 0.2192
# ------------------------------
# Epoch 121/200
#   Train Loss: 0.7137 | Dice: 0.4080 | IoU: 0.2614
#   Val   Loss: 0.7984 | Dice: 0.3354 | IoU: 0.2072
# ------------------------------
# Epoch 122/200
#   Train Loss: 0.7242 | Dice: 0.3785 | IoU: 0.2403
#   Val   Loss: 0.7912 | Dice: 0.3548 | IoU: 0.2201
# ------------------------------
# Epoch 123/200
#   Train Loss: 0.7163 | Dice: 0.4305 | IoU: 0.2775
#   Val   Loss: 0.7970 | Dice: 0.3610 | IoU: 0.2238
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 124/200
#   Train Loss: 0.7176 | Dice: 0.4244 | IoU: 0.2738
#   Val   Loss: 0.8041 | Dice: 0.3343 | IoU: 0.2073
# ------------------------------
# Epoch 125/200
#   Train Loss: 0.7205 | Dice: 0.3858 | IoU: 0.2459
#   Val   Loss: 0.7870 | Dice: 0.3532 | IoU: 0.2186
# ------------------------------
# Epoch 126/200
#   Train Loss: 0.7166 | Dice: 0.4202 | IoU: 0.2696
#   Val   Loss: 0.7910 | Dice: 0.3558 | IoU: 0.2204
# ------------------------------
# Epoch 127/200
#   Train Loss: 0.7134 | Dice: 0.4140 | IoU: 0.2660
#   Val   Loss: 0.7931 | Dice: 0.3468 | IoU: 0.2154
# ------------------------------
# Epoch 128/200
#   Train Loss: 0.7134 | Dice: 0.4053 | IoU: 0.2597
#   Val   Loss: 0.7886 | Dice: 0.3488 | IoU: 0.2159
# ------------------------------
# Epoch 129/200
#   Train Loss: 0.7120 | Dice: 0.4054 | IoU: 0.2593
#   Val   Loss: 0.7914 | Dice: 0.3559 | IoU: 0.2207
# ------------------------------
# Epoch 130/200
#   Train Loss: 0.7131 | Dice: 0.4287 | IoU: 0.2767
#   Val   Loss: 0.7949 | Dice: 0.3578 | IoU: 0.2225
# ------------------------------
# Epoch 131/200
#   Train Loss: 0.7191 | Dice: 0.3924 | IoU: 0.2504
#   Val   Loss: 0.7927 | Dice: 0.3419 | IoU: 0.2121
# ------------------------------
# Epoch 132/200
#   Train Loss: 0.7135 | Dice: 0.4093 | IoU: 0.2624
#   Val   Loss: 0.7906 | Dice: 0.3614 | IoU: 0.2246
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 133/200
#   Train Loss: 0.7105 | Dice: 0.4155 | IoU: 0.2673
#   Val   Loss: 0.7889 | Dice: 0.3456 | IoU: 0.2145
# ------------------------------
# Epoch 134/200
#   Train Loss: 0.7102 | Dice: 0.4064 | IoU: 0.2610
#   Val   Loss: 0.7859 | Dice: 0.3601 | IoU: 0.2240
# ------------------------------
# Epoch 135/200
#   Train Loss: 0.7146 | Dice: 0.4273 | IoU: 0.2757
#   Val   Loss: 0.7912 | Dice: 0.3591 | IoU: 0.2234
# ------------------------------
# Epoch 136/200
#   Train Loss: 0.7103 | Dice: 0.4103 | IoU: 0.2631
#   Val   Loss: 0.7898 | Dice: 0.3505 | IoU: 0.2179
# ------------------------------
# Epoch 137/200
#   Train Loss: 0.7128 | Dice: 0.4204 | IoU: 0.2709
#   Val   Loss: 0.7900 | Dice: 0.3650 | IoU: 0.2277
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 138/200
#   Train Loss: 0.7066 | Dice: 0.4179 | IoU: 0.2696
#   Val   Loss: 0.7906 | Dice: 0.3447 | IoU: 0.2136
# ------------------------------
# Epoch 139/200
#   Train Loss: 0.7124 | Dice: 0.4066 | IoU: 0.2596
#   Val   Loss: 0.7895 | Dice: 0.3611 | IoU: 0.2237
# ------------------------------
# Epoch 140/200
#   Train Loss: 0.7066 | Dice: 0.4259 | IoU: 0.2746
#   Val   Loss: 0.7985 | Dice: 0.3591 | IoU: 0.2240
# ------------------------------
# Epoch 141/200
#   Train Loss: 0.7072 | Dice: 0.4167 | IoU: 0.2689
#   Val   Loss: 0.7913 | Dice: 0.3568 | IoU: 0.2224
# ------------------------------
# Epoch 142/200
#   Train Loss: 0.7059 | Dice: 0.4203 | IoU: 0.2710
#   Val   Loss: 0.7835 | Dice: 0.3624 | IoU: 0.2252
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 143/200
#   Train Loss: 0.7043 | Dice: 0.4248 | IoU: 0.2737
#   Val   Loss: 0.7866 | Dice: 0.3620 | IoU: 0.2255
# ------------------------------
# Epoch 144/200
#   Train Loss: 0.7029 | Dice: 0.4214 | IoU: 0.2719
#   Val   Loss: 0.7947 | Dice: 0.3614 | IoU: 0.2257
# ------------------------------
# Epoch 145/200
#   Train Loss: 0.7028 | Dice: 0.4228 | IoU: 0.2731
#   Val   Loss: 0.7887 | Dice: 0.3594 | IoU: 0.2240
# ------------------------------
# Epoch 146/200
#   Train Loss: 0.7021 | Dice: 0.4153 | IoU: 0.2673
#   Val   Loss: 0.7846 | Dice: 0.3605 | IoU: 0.2247
# ------------------------------
# Epoch 147/200
#   Train Loss: 0.7030 | Dice: 0.4209 | IoU: 0.2716
#   Val   Loss: 0.7858 | Dice: 0.3701 | IoU: 0.2314
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 148/200
#   Train Loss: 0.7024 | Dice: 0.4289 | IoU: 0.2776
#   Val   Loss: 0.7891 | Dice: 0.3674 | IoU: 0.2297
# ------------------------------
# Epoch 149/200
#   Train Loss: 0.6993 | Dice: 0.4341 | IoU: 0.2815
#   Val   Loss: 0.7897 | Dice: 0.3717 | IoU: 0.2321
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 150/200
#   Train Loss: 0.6994 | Dice: 0.4341 | IoU: 0.2811
#   Val   Loss: 0.7848 | Dice: 0.3643 | IoU: 0.2273
# ------------------------------
# Epoch 151/200
#   Train Loss: 0.6991 | Dice: 0.4240 | IoU: 0.2741
#   Val   Loss: 0.7860 | Dice: 0.3662 | IoU: 0.2295
# ------------------------------
# Epoch 152/200
#   Train Loss: 0.7022 | Dice: 0.4105 | IoU: 0.2646
#   Val   Loss: 0.7849 | Dice: 0.3661 | IoU: 0.2289
# ------------------------------
# Epoch 153/200
#   Train Loss: 0.7002 | Dice: 0.4408 | IoU: 0.2869
#   Val   Loss: 0.7873 | Dice: 0.3803 | IoU: 0.2379
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 154/200
#   Train Loss: 0.6989 | Dice: 0.4494 | IoU: 0.2930
#   Val   Loss: 0.7858 | Dice: 0.3691 | IoU: 0.2309
# ------------------------------
# Epoch 155/200
#   Train Loss: 0.6956 | Dice: 0.4245 | IoU: 0.2743
#   Val   Loss: 0.7884 | Dice: 0.3598 | IoU: 0.2251
# ------------------------------
# Epoch 156/200
#   Train Loss: 0.6962 | Dice: 0.4257 | IoU: 0.2761
#   Val   Loss: 0.7809 | Dice: 0.3872 | IoU: 0.2443
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 157/200
#   Train Loss: 0.6954 | Dice: 0.4519 | IoU: 0.2959
#   Val   Loss: 0.7844 | Dice: 0.3742 | IoU: 0.2342
# ------------------------------
# Epoch 158/200
#   Train Loss: 0.6934 | Dice: 0.4285 | IoU: 0.2770
#   Val   Loss: 0.7861 | Dice: 0.3687 | IoU: 0.2301
# ------------------------------
# Epoch 159/200
#   Train Loss: 0.6901 | Dice: 0.4358 | IoU: 0.2825
#   Val   Loss: 0.7835 | Dice: 0.3870 | IoU: 0.2435
# ------------------------------
# Epoch 160/200
#   Train Loss: 0.6924 | Dice: 0.4571 | IoU: 0.2994
#   Val   Loss: 0.7778 | Dice: 0.3765 | IoU: 0.2363
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 161/200
#   Train Loss: 0.6910 | Dice: 0.4240 | IoU: 0.2746
#   Val   Loss: 0.7768 | Dice: 0.3715 | IoU: 0.2330
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 162/200
#   Train Loss: 0.6893 | Dice: 0.4434 | IoU: 0.2894
#   Val   Loss: 0.7699 | Dice: 0.3976 | IoU: 0.2513
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 163/200
#   Train Loss: 0.6870 | Dice: 0.4594 | IoU: 0.3015
#   Val   Loss: 0.7683 | Dice: 0.3794 | IoU: 0.2386
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 164/200
#   Train Loss: 0.6877 | Dice: 0.4274 | IoU: 0.2771
#   Val   Loss: 0.7674 | Dice: 0.3913 | IoU: 0.2477
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 165/200
#   Train Loss: 0.6824 | Dice: 0.4577 | IoU: 0.3011
#   Val   Loss: 0.7683 | Dice: 0.4042 | IoU: 0.2571
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 166/200
#   Train Loss: 0.6786 | Dice: 0.4589 | IoU: 0.3015
#   Val   Loss: 0.7667 | Dice: 0.3887 | IoU: 0.2452
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 167/200
#   Train Loss: 0.6793 | Dice: 0.4412 | IoU: 0.2874
#   Val   Loss: 0.7606 | Dice: 0.3994 | IoU: 0.2534
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 168/200
#   Train Loss: 0.6760 | Dice: 0.4596 | IoU: 0.3026
#   Val   Loss: 0.7592 | Dice: 0.4102 | IoU: 0.2621
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 169/200
#   Train Loss: 0.6748 | Dice: 0.4531 | IoU: 0.2976
#   Val   Loss: 0.7542 | Dice: 0.4049 | IoU: 0.2580
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 170/200
#   Train Loss: 0.6726 | Dice: 0.4651 | IoU: 0.3066
#   Val   Loss: 0.7496 | Dice: 0.4179 | IoU: 0.2669
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 171/200
#   Train Loss: 0.6708 | Dice: 0.4688 | IoU: 0.3093
#   Val   Loss: 0.7548 | Dice: 0.4040 | IoU: 0.2568
# ------------------------------
# Epoch 172/200
#   Train Loss: 0.6683 | Dice: 0.4634 | IoU: 0.3054
#   Val   Loss: 0.7564 | Dice: 0.4159 | IoU: 0.2661
# ------------------------------
# Epoch 173/200
#   Train Loss: 0.6681 | Dice: 0.4659 | IoU: 0.3079
#   Val   Loss: 0.7528 | Dice: 0.4151 | IoU: 0.2660
# ------------------------------
# Epoch 174/200
#   Train Loss: 0.6650 | Dice: 0.4754 | IoU: 0.3157
#   Val   Loss: 0.7500 | Dice: 0.4215 | IoU: 0.2706
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 175/200
#   Train Loss: 0.6641 | Dice: 0.4712 | IoU: 0.3121
#   Val   Loss: 0.7485 | Dice: 0.4133 | IoU: 0.2642
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 176/200
#   Train Loss: 0.6631 | Dice: 0.4698 | IoU: 0.3109
#   Val   Loss: 0.7458 | Dice: 0.4208 | IoU: 0.2697
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 177/200
#   Train Loss: 0.6598 | Dice: 0.4741 | IoU: 0.3143
#   Val   Loss: 0.7459 | Dice: 0.4186 | IoU: 0.2680
# ------------------------------
# Epoch 178/200
#   Train Loss: 0.6594 | Dice: 0.4752 | IoU: 0.3154
#   Val   Loss: 0.7452 | Dice: 0.4246 | IoU: 0.2730
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 179/200
#   Train Loss: 0.6576 | Dice: 0.4735 | IoU: 0.3143
#   Val   Loss: 0.7431 | Dice: 0.4225 | IoU: 0.2715
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 180/200
#   Train Loss: 0.6554 | Dice: 0.4783 | IoU: 0.3182
#   Val   Loss: 0.7397 | Dice: 0.4305 | IoU: 0.2776
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 181/200
#   Train Loss: 0.6551 | Dice: 0.4860 | IoU: 0.3245
#   Val   Loss: 0.7363 | Dice: 0.4300 | IoU: 0.2770
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 182/200
#   Train Loss: 0.6530 | Dice: 0.4767 | IoU: 0.3166
#   Val   Loss: 0.7370 | Dice: 0.4272 | IoU: 0.2748
# ------------------------------
# Epoch 183/200
#   Train Loss: 0.6519 | Dice: 0.4811 | IoU: 0.3204
#   Val   Loss: 0.7381 | Dice: 0.4337 | IoU: 0.2801
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 184/200
#   Train Loss: 0.6521 | Dice: 0.4908 | IoU: 0.3286
#   Val   Loss: 0.7361 | Dice: 0.4331 | IoU: 0.2797
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 185/200
#   Train Loss: 0.6508 | Dice: 0.4768 | IoU: 0.3172
#   Val   Loss: 0.7384 | Dice: 0.4244 | IoU: 0.2730
# ------------------------------
# Epoch 186/200
#   Train Loss: 0.6512 | Dice: 0.4809 | IoU: 0.3205
#   Val   Loss: 0.7357 | Dice: 0.4367 | IoU: 0.2825
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 187/200
#   Train Loss: 0.6506 | Dice: 0.4929 | IoU: 0.3303
#   Val   Loss: 0.7320 | Dice: 0.4356 | IoU: 0.2815
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 188/200
#   Train Loss: 0.6486 | Dice: 0.4847 | IoU: 0.3235
#   Val   Loss: 0.7314 | Dice: 0.4306 | IoU: 0.2776
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 189/200
#   Train Loss: 0.6490 | Dice: 0.4786 | IoU: 0.3185
#   Val   Loss: 0.7312 | Dice: 0.4322 | IoU: 0.2789
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 190/200
#   Train Loss: 0.6469 | Dice: 0.4847 | IoU: 0.3235
#   Val   Loss: 0.7308 | Dice: 0.4360 | IoU: 0.2820
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 191/200
#   Train Loss: 0.6470 | Dice: 0.4902 | IoU: 0.3281
#   Val   Loss: 0.7301 | Dice: 0.4378 | IoU: 0.2833
# ✅ Nouveau meilleur modèle loss sauvegardé
# ✅ Nouveau meilleur modèle dice sauvegardé
# ------------------------------
# Epoch 192/200
#   Train Loss: 0.6459 | Dice: 0.4911 | IoU: 0.3289
#   Val   Loss: 0.7294 | Dice: 0.4372 | IoU: 0.2829
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 193/200
#   Train Loss: 0.6464 | Dice: 0.4895 | IoU: 0.3276
#   Val   Loss: 0.7291 | Dice: 0.4360 | IoU: 0.2819
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 194/200
#   Train Loss: 0.6461 | Dice: 0.4874 | IoU: 0.3258
#   Val   Loss: 0.7290 | Dice: 0.4354 | IoU: 0.2814
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 195/200
#   Train Loss: 0.6456 | Dice: 0.4857 | IoU: 0.3244
#   Val   Loss: 0.7290 | Dice: 0.4347 | IoU: 0.2809
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 196/200
#   Train Loss: 0.6462 | Dice: 0.4847 | IoU: 0.3236
#   Val   Loss: 0.7290 | Dice: 0.4346 | IoU: 0.2808
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 197/200
#   Train Loss: 0.6460 | Dice: 0.4849 | IoU: 0.3237
#   Val   Loss: 0.7290 | Dice: 0.4348 | IoU: 0.2810
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 198/200
#   Train Loss: 0.6454 | Dice: 0.4852 | IoU: 0.3240
#   Val   Loss: 0.7290 | Dice: 0.4350 | IoU: 0.2811
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 199/200
#   Train Loss: 0.6462 | Dice: 0.4854 | IoU: 0.3242
#   Val   Loss: 0.7290 | Dice: 0.4351 | IoU: 0.2812
# ✅ Nouveau meilleur modèle loss sauvegardé
# ------------------------------
# Epoch 200/200
#   Train Loss: 0.6455 | Dice: 0.4855 | IoU: 0.3243
#   Val   Loss: 0.7290 | Dice: 0.4351 | IoU: 0.2812

# %%
with open(save_dir / "UNet_v3_1_train_history.json", "w") as f:
    json.dump(train_history, f, indent=4)

with open(save_dir / "UNet_v3_1__val_history.json", "w") as f:
    json.dump(val_history, f, indent=4)

print("Historiques sauvegardés en JSON")
# Out:
# Historiques sauvegardés en JSON

# %% [markdown]
# # Validation tests

# %% [markdown]
# #### Load the best model

# %%
model = torch.load(save_dir / "dice_best_model_full.pth")
# Out:
# /tmp/ipykernel_3772575/448777230.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(save_dir / "dice_best_model_full.pth")

# %% [markdown]
# #### Images

# %%
model.eval()
total_correct = 0
total_pixels = 0

# 📁 Dossier pour sauvegarder les prédictions
pred_dir = save_dir / "predictions"
pred_dir.mkdir(parents=True, exist_ok=True)

with torch.no_grad():
    img_index = 0  # compteur global des images

    for imgs, masks in val_loader:
        imgs = imgs.to(device)
        masks = masks.to(device)

        outputs = model(imgs)
        preds = torch.argmax(F.softmax(outputs, dim=1), dim=1)

        # Boucle sur chaque image du batch
        for i in range(len(imgs)):
            pred = preds[i]
            mask = masks[i]

            # ===== Calcul de l’accuracy de cette image =====
            correct_pixels = (pred == mask).sum().item()
            total_pixels_img = mask.numel()
            acc_img = correct_pixels / total_pixels_img

            print(f"🖼️ Image {img_index+1} — Accuracy : {acc_img:.4f}")

            # ===== Création de la figure =====
            fig, ax = plt.subplots(1, 3, figsize=(10, 4))
            ax[0].imshow(imgs[i].cpu().permute(1, 2, 0))
            ax[0].set_title("Original picture")
            ax[1].imshow(mask.cpu(), cmap="gray")
            ax[1].set_title("Real mask")
            ax[2].imshow(pred.cpu(), cmap="gray")
            ax[2].set_title("Predicted mask")
            for a in ax:
                a.axis("off")
            plt.tight_layout()

            # 📌 Sauvegarde dans Models/<model_name>/predictions/
            save_path = pred_dir / f"val_img_{img_index:03d}.png"
            plt.savefig(save_path, dpi=150, bbox_inches='tight')

            # ✅ Affichage immédiat dans notebook
            plt.show()

            # ===== Accumulateur global =====
            total_correct += correct_pixels
            total_pixels += total_pixels_img
            img_index += 1

# ===== Accuracy globale =====
val_acc = total_correct / total_pixels
print(f"\n✅ Accuracy moyenne sur le jeu de validation : {val_acc:.4f}")
# Out:
# 🖼️ Image 1 — Accuracy : 0.8995
# 🖼️ Image 2 — Accuracy : 0.9043
# 🖼️ Image 3 — Accuracy : 0.8709
# 🖼️ Image 4 — Accuracy : 0.9199
# 🖼️ Image 5 — Accuracy : 0.8332
# ✅ Accuracy moyenne sur le jeu de validation : 0.8856

# %% [markdown]
# #### Curves

# %%
# --- Création du dossier d'enregistrement ---
curves_dir = save_dir / "curves"
curves_dir.mkdir(parents=True, exist_ok=True)

def plot_metric(train_history, val_history, key, title=None, mark_best_on="val_loss", save_folder=curves_dir):
    """
    key:        nom de la métrique dans les dicts (ex: "loss", "dice", "auc")
    mark_best_on:
        - "val_loss" → marquer l'epoch où val_loss est minimal
        - "val_<key>" → marquer la meilleure valeur de cette métrique (max)
    """

    train = train_history.get(key, [])
    val   = val_history.get(key, [])

    if len(val) == 0:
        print(f"⚠️ Impossible de tracer '{key}' (pas de valeurs validation trouvées)")
        return

    epochs = range(1, len(val)+1)

    plt.figure(figsize=(7,5))
    plt.plot(epochs, train, label=f"Train {key}", linewidth=2)
    plt.plot(epochs, val,   label=f"Val {key}", linewidth=2)

    # ========= Marqueur du "best" =========
    if mark_best_on == "val_loss" and "loss" in val_history:
        best_e = int(np.argmin(val_history["loss"])) + 1
        best_v = val[best_e-1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")
    elif mark_best_on == f"val_{key}" and len(val) > 0:
        best_e = int(np.nanargmax(val)) + 1
        best_v = val[best_e-1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")

    plt.xlabel("Epoch")
    plt.ylabel(key)
    plt.title(title or f"{key} (train vs val)")
    plt.grid(True)
    plt.legend()

    # ========= SAVE =========
    save_path = save_folder / f"{key}.png"
    plt.savefig(save_path, dpi=200, bbox_inches="tight")
    print(f"💾 Courbe sauvegardée : {save_path}")

    plt.show()   # continue à afficher


# ======== TRAÇAGE ========

plot_metric(train_history, val_history, "loss", title="Loss curves", mark_best_on="val_loss")
plot_metric(train_history, val_history, "dice", title="Dice (artery+vein avg)", mark_best_on="val_dice")
plot_metric(train_history, val_history, "auc",  title="AUC (artery+vein avg)",  mark_best_on="val_auc")
# Out:
# 💾 Courbe sauvegardée : Models/My_UNet_v3_1/curves/loss.png
# 💾 Courbe sauvegardée : Models/My_UNet_v3_1/curves/dice.png
# 💾 Courbe sauvegardée : Models/My_UNet_v3_1/curves/auc.png

# %% [markdown]
# #### Summary of the metrics

# %%
# =========================
#   CONFIG CLASSES
# =========================
ARTERY_CLASS = 1
VEIN_CLASS   = 2
VESSEL_CLASSES = [ARTERY_CLASS, VEIN_CLASS]
assert NUM_CLASSES >= 3, "NUM_CLASSES doit inclure background + artery + vein"


# =========================
#  UTILS: métriques par classe
# =========================
def compute_per_class_metrics_from_confmat(sums, c):
    TP, FP, FN, TN = sums["TP"][c], sums["FP"][c], sums["FN"][c], sums["TN"][c]
    eps = 1e-7

    acc  = (TP + TN) / max(TP + TN + FP + FN, eps)
    prec = TP / max(TP + FP, eps)
    rec  = TP / max(TP + FN, eps)
    spec = TN / max(TN + FP, eps)
    dice = (2 * TP) / max(2 * TP + FP + FN, eps)
    iou  = TP / max(TP + FP + FN, eps)

    return {
        "accuracy":   float(acc),
        "precision":  float(prec),
        "recall":     float(rec),      # Sensitivity
        "specificity":float(spec),
        "dice":       float(dice),
        "iou":        float(iou),
    }

def compute_auc_for_class(buffers, c):
    pack = buffers.get(c, None)
    if pack is None or len(pack["y_true"]) == 0:
        return float("nan")

    y_true  = np.concatenate(pack["y_true"])
    y_score = np.concatenate(pack["y_score"])

    pos = (y_true == 1).sum()
    neg = (y_true == 0).sum()
    if pos == 0 or neg == 0:
        return float("nan")

    try:
        return float(roc_auc_score(y_true, y_score))
    except:
        return float("nan")


# =========================
#   ÉVALUATION
# =========================
model.eval()
conf_sums_val = init_confmat_sums(num_classes=NUM_CLASSES)
auc_buf_val   = init_auc_buffers(include_classes=VESSEL_CLASSES)

with torch.no_grad():
    for imgs, masks in val_loader:
        imgs  = imgs.to(device)
        masks = masks.to(device)

        outputs = model(imgs)
        preds = outputs.argmax(dim=1)

        update_confmat_sums(conf_sums_val, preds, masks, NUM_CLASSES)
        update_auc_buffers(auc_buf_val, outputs, masks)


# =========================
#   MÉTRIQUES PAR CLASSE
# =========================
results = {}

for cls, name in zip(VESSEL_CLASSES, ["Artery", "Vein"]):
    m = compute_per_class_metrics_from_confmat(conf_sums_val, cls)
    m["auc"] = compute_auc_for_class(auc_buf_val, cls)
    results[name] = m


# =========================
#   MOYENNES ARTERY + VEIN
# =========================
avg_metrics = {metric: np.nanmean([results["Artery"][metric], results["Vein"][metric]])
               for metric in results["Artery"].keys()}

results["Average (A+V)"] = avg_metrics


# =========================
#   AFFICHAGE TABLEAU (4 décimales)
# =========================
df = pd.DataFrame(results).T
df = df.round(4)  # <= Arrondi propre à 4 décimales

print("\n=== Résultats de validation ===\n")
display(df.style.format("{:.4f}"))
# Out:
# === Résultats de validation ===
# <style type="text/css">
# </style>
# <table id="T_27440">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27440_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_27440_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_27440_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_27440_level0_col3" class="col_heading level0 col3" >specificity</th>
#       <th id="T_27440_level0_col4" class="col_heading level0 col4" >dice</th>
#       <th id="T_27440_level0_col5" class="col_heading level0 col5" >iou</th>
#       <th id="T_27440_level0_col6" class="col_heading level0 col6" >auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27440_level0_row0" class="row_heading level0 row0" >Artery</th>
#       <td id="T_27440_row0_col0" class="data row0 col0" >0.9323</td>
#       <td id="T_27440_row0_col1" class="data row0 col1" >0.5050</td>
#       <td id="T_27440_row0_col2" class="data row0 col2" >0.5239</td>
#       <td id="T_27440_row0_col3" class="data row0 col3" >0.9623</td>
#       <td id="T_27440_row0_col4" class="data row0 col4" >0.5143</td>
#       <td id="T_27440_row0_col5" class="data row0 col5" >0.3462</td>
#       <td id="T_27440_row0_col6" class="data row0 col6" >0.9278</td>
#     </tr>
#     <tr>
#       <th id="T_27440_level0_row1" class="row_heading level0 row1" >Vein</th>
#       <td id="T_27440_row1_col0" class="data row1 col0" >0.9154</td>
#       <td id="T_27440_row1_col1" class="data row1 col1" >0.3256</td>
#       <td id="T_27440_row1_col2" class="data row1 col2" >0.4058</td>
#       <td id="T_27440_row1_col3" class="data row1 col3" >0.9473</td>
#       <td id="T_27440_row1_col4" class="data row1 col4" >0.3613</td>
#       <td id="T_27440_row1_col5" class="data row1 col5" >0.2205</td>
#       <td id="T_27440_row1_col6" class="data row1 col6" >0.8559</td>
#     </tr>
#     <tr>
#       <th id="T_27440_level0_row2" class="row_heading level0 row2" >Average (A+V)</th>
#       <td id="T_27440_row2_col0" class="data row2 col0" >0.9239</td>
#       <td id="T_27440_row2_col1" class="data row2 col1" >0.4153</td>
#       <td id="T_27440_row2_col2" class="data row2 col2" >0.4648</td>
#       <td id="T_27440_row2_col3" class="data row2 col3" >0.9548</td>
#       <td id="T_27440_row2_col4" class="data row2 col4" >0.4378</td>
#       <td id="T_27440_row2_col5" class="data row2 col5" >0.2833</td>
#       <td id="T_27440_row2_col6" class="data row2 col6" >0.8918</td>
#     </tr>
#   </tbody>
# </table>

# %%
# =========================
#   CONFIG CLASSES
# =========================
ARTERY_CLASS = 1
VEIN_CLASS   = 2
VESSEL_CLASSES = [ARTERY_CLASS, VEIN_CLASS]
assert NUM_CLASSES >= 3, "NUM_CLASSES must include background + artery + vein"

# =========================
#   PER-IMAGE METRIC HELPERS
# =========================
def dice_per_image(pred, target, cls):
    eps = 1e-7
    p = (pred == cls).float()
    t = (target == cls).float()
    inter = (p * t).sum()
    denom = p.sum() + t.sum()
    return float((2.0 * inter) / (denom + eps))

def iou_per_image(pred, target, cls):
    eps = 1e-7
    p = (pred == cls)
    t = (target == cls)
    inter = (p & t).sum().item()
    union = (p | t).sum().item()
    return float(inter / (union + eps))

def auc_per_image_from_logits(logits, target, cls):
    # logits: (C,H,W) for a single image
    probs = F.softmax(logits, dim=0)
    y_score = probs[cls].reshape(-1).cpu().numpy()
    y_true  = (target == cls).reshape(-1).cpu().numpy().astype(np.uint8)
    pos = (y_true == 1).sum()
    neg = (y_true == 0).sum()
    if pos == 0 or neg == 0:
        return float("nan")
    try:
        return float(roc_auc_score(y_true, y_score))
    except Exception:
        return float("nan")

# =========================
#   COLLECT PER-IMAGE METRICS
# =========================
model.eval()

artery_dice_list, vein_dice_list, avg_dice_list = [], [], []
artery_iou_list,  vein_iou_list,  avg_iou_list  = [], [], []
artery_auc_list,  vein_auc_list,  avg_auc_list  = [], [], []

with torch.no_grad():
    for imgs, masks in val_loader:
        imgs  = imgs.to(device)
        masks = masks.to(device)

        logits = model(imgs)          # (N,C,H,W)
        preds  = logits.argmax(dim=1) # (N,H,W)

        for i in range(imgs.size(0)):
            p   = preds[i]
            gt  = masks[i]
            log = logits[i]

            # Dice
            a_d = dice_per_image(p, gt, ARTERY_CLASS)
            v_d = dice_per_image(p, gt, VEIN_CLASS)
            artery_dice_list.append(a_d)
            vein_dice_list.append(v_d)
            avg_dice_list.append(np.nanmean([a_d, v_d]))

            # IoU
            a_i = iou_per_image(p, gt, ARTERY_CLASS)
            v_i = iou_per_image(p, gt, VEIN_CLASS)
            artery_iou_list.append(a_i)
            vein_iou_list.append(v_i)
            avg_iou_list.append(np.nanmean([a_i, v_i]))

            # AUC
            a_auc = auc_per_image_from_logits(log, gt, ARTERY_CLASS)
            v_auc = auc_per_image_from_logits(log, gt, VEIN_CLASS)
            artery_auc_list.append(a_auc)
            vein_auc_list.append(v_auc)
            avg_auc_list.append(np.nanmean([a_auc, v_auc]))

# =========================
#   BAR PLOTS (3 rows × 3 cols)
#   One bar per image; red dashed = mean
# =========================
def plot_bars_one_metric(ax, values, title):
    values = np.array(values, dtype=float)
    n = len(values)
    x = np.arange(1, n+1)

    ax.bar(x, values, color="#1f77b4", edgecolor="black", alpha=0.9)

    m = np.nanmean(values)
    ax.axhline(m, color="red", linestyle="--", linewidth=2, label=f"mean = {m:.3f}")

    ax.set_ylim(0, 1)            # metrics in [0,1]
    ax.set_xlim(0.5, n + 0.5)
    ax.set_xlabel("Validation image index")
    ax.set_ylabel("Score")
    ax.set_title(title)
    # lighten x ticks if many images
    if n > 30:
        ax.set_xticks(np.linspace(1, n, 10, dtype=int))
    ax.grid(axis="y", alpha=0.3)
    ax.legend(loc="upper right")

fig, axes = plt.subplots(3, 3, figsize=(20, 12), constrained_layout=True)

# Row 1: Dice
plot_bars_one_metric(axes[0,0], artery_dice_list, "Dice – Artery")
plot_bars_one_metric(axes[0,1], vein_dice_list,   "Dice – Vein")
plot_bars_one_metric(axes[0,2], avg_dice_list,    "Dice – Average (A+V)")

# Row 2: IoU
plot_bars_one_metric(axes[1,0], artery_iou_list, "IoU – Artery")
plot_bars_one_metric(axes[1,1], vein_iou_list,   "IoU – Vein")
plot_bars_one_metric(axes[1,2], avg_iou_list,    "IoU – Average (A+V)")

# Row 3: AUC
plot_bars_one_metric(axes[2,0], artery_auc_list, "AUC – Artery")
plot_bars_one_metric(axes[2,1], vein_auc_list,   "AUC – Vein")
plot_bars_one_metric(axes[2,2], avg_auc_list,    "AUC – Average (A+V)")

plt.show()
